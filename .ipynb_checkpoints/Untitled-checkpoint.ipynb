# %%
#Experiment: SE0
from  searchengine import *
from pre_rec import precision_recall
import codecs
from hazm import *

experiment = "N,T,R"
SE = SearchEngine("./Poems","index_whoosh")
SE.Create_Index(experiment)


with open("RelevanceAssesment/RelevanceAssesment.txt") as f:
    lines = f.readlines()
test_file_names = lines[0::3]
Relevantdocs = lines[1::3]


sum_precision = 0
sum_recall = 0

for i in range(len(test_file_names)):
    print("processing file "+str(i))
    file = test_file_names[i]
    with codecs.open("Queries/"+file.split("\n")[0], 'r', "utf-8") as f:
        query = f.read().replace("\n", " ")
        if "N" in experiment:
                #print("normalize")
            normalizer = Normalizer()
            query = normalizer.normalize(query)
        if "T"  in experiment:
            #print("tokenize")
            query = word_tokenize(query)
        if "R" in experiment:
            stopwords = []
            with codecs.open("Stopwords/Stopwords.txt", 'r', "utf-8") as f:
                lines = f.readlines()
            for line in lines:
                stopwords.append(line.split('\n')[0])
            #print("Remove StopWords")
            query_temp = []
            for word in query:
                if not word in stopwords:
                    query_temp.append(word)
            print(len(query))
            print("chaged to")
            print(len(query_temp))
            query = query_temp
    query = " ".join(query)
    results = SE.Search(query)
    pre,rec = precision_recall(results, Relevantdocs[i].split("\n")[0])
    sum_precision += pre
    sum_recall += rec
experiment_precision = sum_precision / len(test_file_names)
experiment_recall = sum_recall / len(test_file_names)
# Out:
# 6808
# 0.0
# 0.0146886016451
# 0.0293772032902
# 0.0440658049354
# 0.0587544065805
# 0.0734430082256
# 0.0881316098707
# 0.102820211516
# 0.117508813161
# 0.132197414806
# 0.146886016451
# 0.161574618096
# 0.176263219741
# 0.190951821387
# 0.205640423032
# 0.220329024677
# 0.235017626322
# 0.249706227967
# 0.264394829612
# 0.279083431257
# 0.293772032902
# 0.308460634548
# 0.323149236193
# 0.337837837838
# 0.352526439483
# 0.367215041128
# 0.381903642773
# 0.396592244418
# 0.411280846063
# 0.425969447709
# 0.440658049354
# 0.455346650999
# 0.470035252644
# 0.484723854289
# 0.499412455934
# 0.514101057579
# 0.528789659224
# 0.54347826087
# 0.558166862515
# 0.57285546416
# 0.587544065805
# 0.60223266745
# 0.616921269095
# 0.63160987074
# 0.646298472385
# 0.660987074031
# 0.675675675676
# 0.690364277321
# 0.705052878966
# 0.719741480611
# 0.734430082256
# 0.749118683901
# 0.763807285546
# 0.778495887192
# 0.793184488837
# 0.807873090482
# 0.822561692127
# 0.837250293772
# 0.851938895417
# 0.866627497062
# 0.881316098707
# 0.896004700353
# 0.910693301998
# 0.925381903643
# 0.940070505288
# 0.954759106933
# 0.969447708578
# 0.984136310223
# 0.998824911868
# indexing has been finished
# processing file 0
# 75
# chaged to
# 47
# <Top 0 Results for And([Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0637\u0628\u06cc\u0628'), Term('content', u'\u0628\u06cc\u0645\u0627\u0631'), Term('content', u'\u062d\u0627\u0644'), Term('content', u'\u0628\u0628\u06cc\u0646\u062f'), Term('content', u'\u062e\u0644\u0648\u062a'), Term('content', u'\u0637\u0644\u0628\u06cc\u062f\u0646'), Term('content', u'\u0648\u0644\u06cc'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u062f\u0631\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0631\u0646\u062c'), Term('content', u'\u06a9\u0646\u06cc\u0632\u06a9'), Term('content', u'\u0645\u0644\u0627\u0642\u0627\u062a'), Term('content', u'\u062e\u0648\u0627\u0628\u0634'), Term('content', u'\u0646\u0645\u0648\u062f\u0646\u062f'), Term('content', u'\u0638\u0627\u0647\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0639\u062c\u0632'), Term('content', u'\u062d\u06a9\u06cc\u0645\u0627\u0646'), Term('content', u'\u0645\u0639\u0627\u0644\u062c\u0647'), Term('content', u'\u0631\u0648\u06cc'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u062f\u0631\u06af\u0627\u0647'), Term('content', u'\u0627\u0644\u0647'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0648\u0644\u06cc\u06cc'), Term('content', u'\u0631\u0627\u0639\u0627\u0634\u0642'), Term('content', u'\u0631\u0646\u062c\u0648\u0631'), Term('content', u'\u062a\u062f\u0628\u06cc\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0635\u062d\u062a')]) runtime=0.0199770927429>
# processing file 1
# 27
# chaged to
# 19
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0632\u0647\u0631'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u0632\u0631\u06af\u0631'), Term('content', u'\u0627\u0634\u0627\u0631\u062a'), Term('content', u'\u0627\u0644\u0647\u06cc'), Term('content', u'\u0647\u0648\u0627\u06cc'), Term('content', u'\u0646\u0641\u0633'), Term('content', u'\u062a\u0627\u0645\u0644'), Term('content', u'\u0641\u0627\u0633\u062f'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0631\u0633\u0648\u0644\u0627\u0646'), Term('content', u'\u0633\u0645\u0631\u0642\u0646\u062f'), Term('content', u'\u0622\u0648\u0631\u062f\u0646')]) runtime=0.012099981308>
# processing file 2
# 27
# chaged to
# 19
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0632\u0647\u0631'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u0632\u0631\u06af\u0631'), Term('content', u'\u0627\u0634\u0627\u0631\u062a'), Term('content', u'\u0627\u0644\u0647\u06cc'), Term('content', u'\u0647\u0648\u0627\u06cc'), Term('content', u'\u0646\u0641\u0633'), Term('content', u'\u062a\u0627\u0645\u0644'), Term('content', u'\u0641\u0627\u0633\u062f'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0631\u0633\u0648\u0644\u0627\u0646'), Term('content', u'\u0633\u0645\u0631\u0642\u0646\u062f'), Term('content', u'\u0622\u0648\u0631\u062f\u0646')]) runtime=0.0112850666046>
# processing file 3
# 10
# chaged to
# 7
# <Top 0 Results for And([Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u0628\u0642\u0627\u0644'), Term('content', u'\u0637\u0648\u0637\u06cc'), Term('content', u'\u0631\u0648\u063a\u0646'), Term('content', u'\u0631\u06cc\u062e\u062a\u0646'), Term('content', u'\u062f\u06a9\u0627\u0646')]) runtime=0.00289511680603>
# processing file 4
# 67
# chaged to
# 51
# <Top 0 Results for And([Term('content', u'\u062f\u0627\u0633\u062a\u0627\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u062c\u0647\u0648\u062f'), Term('content', u'\u0646\u0635\u0631\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u0645\u06cc'), Term('content', u'\u06a9\u0634\u062a'), Term('content', u'\u0628\u0647\u0631'), Term('content', u'\u062a\u0639\u0635\u0628'), Term('content', u'\u0622\u0645\u0648\u062e\u062a\u0646'), Term('content', u'\u0648\u0632\u06cc\u0631'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u062a\u0644\u0628\u06cc\u0633'), Term('content', u'\u0628\u0627\u0646\u0635\u0627\u0631\u06cc'), Term('content', u'\u0642\u0628\u0648\u0644'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0646\u0635\u0627\u0631\u06cc'), Term('content', u'\u0645\u062a\u0627\u0628\u0639\u062a'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u062d\u0633\u062f'), Term('content', u'\u0641\u0647\u0645'), Term('content', u'\u062d\u0627\u0630\u0642\u0627\u0646'), Term('content', u'\u067e\u06cc\u063a\u0627\u0645'), Term('content', u'\u0634\u0627\u0647'), Term('content', u'\u067e\u0646\u0647\u0627\u0646'), Term('content', u'\u062f\u0648\u0627\u0632\u062f\u0647'), Term('content', u'\u0633\u0628\u0637'), Term('content', u'\u062a\u062e\u0644\u06cc\u0637'), Term('content', u'\u0627\u062d\u06a9\u0627\u0645'), Term('content', u'\u0627\u0646\u062c\u06cc\u0644'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u0627\u062e\u062a\u0644\u0627\u0641\u0627\u062a'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0631\u0648\u0634'), Term('content', u'\u0646\u06cc'), Term('content', u'\u062d\u0642\u06cc\u0642\u062a'), Term('content', u'\u0631\u0627\u0647')]) runtime=0.0263078212738>
# processing file 5
# 59
# chaged to
# 46
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u062e\u0633\u0627\u0631\u062a'), Term('content', u'\u0648\u0632\u06cc\u0631'), Term('content', u'\u062f\u0631\u06cc\u0646'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u062f\u06cc\u06af\u0631'), Term('content', u'\u0627\u0646\u06af\u06cc\u062e\u062a\u0646'), Term('content', u'\u0627\u0636\u0644\u0627\u0644'), Term('content', u'\u0642\u0648\u0645'), Term('content', u'\u062f\u0641\u0639'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0645\u0631\u06cc\u062f\u0627\u0646'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u062e\u0644\u0648\u062a'), Term('content', u'\u0628\u0634\u06a9\u0646'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u0646\u0645\u06cc'), Term('content', u'\u0634\u06a9\u0646\u0645'), Term('content', u'\u0627\u0639\u062a\u0631\u0627\u0636'), Term('content', u'\u0646\u0648\u0645\u06cc\u062f'), Term('content', u'\u0631\u0641\u0636'), Term('content', u'\u0648\u0644\u06cc'), Term('content', u'\u0639\u0647\u062f'), Term('content', u'\u0633\u0627\u062e\u062a\u0646'), Term('content', u'\u06cc\u06a9'), Term('content', u'\u0627\u0645\u06cc\u0631'), Term('content', u'\u062c\u062f\u0627\u062c\u062f\u0627'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u062e\u0648\u06cc\u0634\u062a\u0646')]) runtime=0.0196561813354>
# processing file 6
# 70
# chaged to
# 51
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u062a\u0648\u06a9\u0644'), Term('content', u'\u062a\u0631\u06a9'), Term('content', u'\u062c\u0647\u062f'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0646\u062e\u0686\u06cc\u0631\u0627\u0646'), Term('content', u'\u0628\u0634\u06cc\u0631'), Term('content', u'\u062a\u0631\u062c\u06cc\u062d'), Term('content', u'\u0646\u0647\u0627\u062f\u0646'), Term('content', u'\u0627\u06a9\u062a\u0633\u0627\u0628'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u062a\u0633\u0644\u06cc\u0645'), Term('content', u'\u0627\u062c\u062a\u0647\u0627\u062f'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0641\u0648\u0627\u06cc\u062f'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0645\u0642\u0631\u0631'), Term('content', u'\u0634\u062f\u0646')]) runtime=0.0146188735962>
# processing file 7
# 74
# chaged to
# 56
# <Top 0 Results for And([Term('content', u'\u0627\u0646\u06a9\u0627\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0646\u062e\u0686\u06cc\u0631\u0627\u0646'), Term('content', u'\u062e\u0631\u06af\u0648\u0634'), Term('content', u'\u062a\u0627\u062e\u06cc\u0631'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0627\u0639\u062a\u0631\u0627\u0636'), Term('content', u'\u0633\u062e\u0646'), Term('content', u'\u0630\u06a9\u0631'), Term('content', u'\u062f\u0627\u0646\u0634'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0641\u0636\u06cc\u0644\u062a'), Term('content', u'\u0645\u0646\u0627\u0641\u0639'), Term('content', u'\u062f\u0627\u0646\u0633\u062a\u0646'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0637\u0644\u0628\u06cc\u062f\u0646'), Term('content', u'\u0627\u0646\u062f\u06cc\u0634\u0647'), Term('content', u'\u0645\u0646\u0639'), Term('content', u'\u0631\u0627\u0632'), Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u0632\u06cc\u0627\u0641\u062a'), Term('content', u'\u062a\u0627\u0648\u06cc\u0644'), Term('content', u'\u0631\u06a9\u06cc\u06a9'), Term('content', u'\u0645\u06af\u0633'), Term('content', u'\u062a\u0648\u0644\u06cc\u062f\u0646'), Term('content', u'\u062f\u06cc\u0631'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0639\u0630\u0631')]) runtime=0.0209109783173>
# processing file 8
# 61
# chaged to
# 43
# <Top 0 Results for And([Term('content', u'\u067e\u0627'), Term('content', u'\u0648\u0627\u067e\u0633'), Term('content', u'\u06a9\u0634\u06cc\u062f\u0646'), Term('content', u'\u062e\u0631\u06af\u0648\u0634'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u0646\u0632\u062f\u06cc\u06a9'), Term('content', u'\u0686\u0627\u0647'), Term('content', u'\u0631\u0633\u06cc\u062f'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u067e\u0627\u06cc'), Term('content', u'\u0646\u0638\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0639\u06a9\u0633'), Term('content', u'\u0645\u0698\u062f\u0647'), Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u0646\u062e\u0686\u06cc\u0631\u0627\u0646'), Term('content', u'\u0641\u062a\u0627\u062f'), Term('content', u'\u062c\u0645\u0639'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u06af\u0631\u062f'), Term('content', u'\u062b\u0646\u0627'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u067e\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0628\u062f\u06cc\u0646'), Term('content', u'\u0634\u0627\u062f'), Term('content', u'\u0645\u0634\u0648\u06cc\u062f')]) runtime=0.0374038219452>
# processing file 9
# 23
# chaged to
# 17
# <Top 0 Results for And([Term('content', u'\u0647\u062f\u0647\u062f'), Term('content', u'\u0633\u0644\u06cc\u0645\u0627\u0646'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u0642\u0636\u0627'), Term('content', u'\u0686\u0634\u0645\u0647\u0627\u06cc'), Term('content', u'\u0631\u0648\u0634\u0646'), Term('content', u'\u0628\u0633\u062a\u0647_\u0634\u0648\u062f'), Term('content', u'\u0637\u0639\u0646\u0647'), Term('content', u'\u0632\u0627\u063a'), Term('content', u'\u062f\u0639\u0648\u06cc'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646')]) runtime=0.00763201713562>
# processing file 10
# 76
# chaged to
# 51
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0628\u0627\u0632\u0631\u06af\u0627\u0646'), Term('content', u'\u0637\u0648\u0637\u06cc'), Term('content', u'\u0645\u062d\u0628\u0648\u0633'), Term('content', u'\u067e\u06cc\u063a\u0627\u0645'), Term('content', u'\u062f\u0627\u062f'), Term('content', u'\u0637\u0648\u0637\u06cc\u0627\u0646'), Term('content', u'\u0647\u0646\u062f\u0648\u0633\u062a\u0627\u0646'), Term('content', u'\u0647\u0646\u06af\u0627\u0645'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u062a\u062c\u0627\u0631\u062a'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u062e\u0648\u0627\u062c\u0647'), Term('content', u'\u062f\u0634\u062a'), Term('content', u'\u0631\u0633\u0627\u0646\u06cc\u062f\u0646'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0622\u0646\u0686'), Term('content', u'\u062f\u06cc\u062f'), Term('content', u'\u0634\u0646\u06cc\u062f\u0646'), Term('content', u'\u062d\u0631\u06a9\u062a'), Term('content', u'\u0645\u0631\u062f\u0646'), Term('content', u'\u0642\u0641\u0635'), Term('content', u'\u0646\u0648\u062d\u0647'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0628\u0631\u0648\u0646'), Term('content', u'\u0627\u0646\u062f\u0627\u062e\u062a\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u062a\u0627\u062c\u0631'), Term('content', u'\u0642\u0641\u0633'), Term('content', u'\u067e\u0631\u06cc\u062f\u0646'), Term('content', u'\u0645\u0631\u062f\u0647'), Term('content', u'\u0648\u062f\u0627\u0639'), Term('content', u'\u06a9\u0631\u062f\u0646')]) runtime=0.0278069972992>
# processing file 11
# 54
# chaged to
# 36
# <Top 0 Results for And([Term('content', u'\u06a9\u0628\u0648\u062f\u06cc'), Term('content', u'\u0632\u062f\u0646'), Term('content', u'\u0642\u0632\u0648\u06cc\u0646\u06cc'), Term('content', u'\u0634\u0627\u0646\u0647'), Term('content', u'\u06af\u0627\u0647'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u067e\u0634\u06cc\u0645\u0627\u0646'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u0632\u062e\u0645'), Term('content', u'\u0633\u0648\u0632\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u06af\u0631\u06af'), Term('content', u'\u0631\u0648\u0628\u0627\u0647'), Term('content', u'\u062e\u062f\u0645\u062a'), Term('content', u'\u0634\u06a9\u0627\u0631'), Term('content', u'\u0627\u0645\u062a\u062d\u0627\u0646'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0622\u06cc'), Term('content', u'\u0628\u062e\u0634'), Term('content', u'\u0635\u06cc\u062f\u0647\u0627'), Term('content', u'\u0645\u06cc\u0627\u0646'), Term('content', u'\u0627\u062f\u0628'), Term('content', u'\u0642\u0633\u0645\u062a'), Term('content', u'\u0628\u06cc'), Term('content', u'\u0627\u062f\u0628\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0647_\u0628\u0648\u062f')]) runtime=0.0209560394287>
# processing file 12
# 113
# chaged to
# 84
# <Top 0 Results for And([Term('content', u'\u062e\u062f\u0648'), Term('content', u'\u0627\u0646\u062f\u0627\u062e\u062a\u0646'), Term('content', u'\u062e\u0635\u0645'), Term('content', u'\u0631\u0648\u06cc'), Term('content', u'\u0627\u0645\u06cc\u0631'), Term('content', u'\u0627\u0644\u0645\u0624\u0645\u0646\u06cc\u0646'), Term('content', u'\u0639\u0644\u06cc'), Term('content', u'\u06a9\u0631\u0645'), Term('content', u'\u0627\u0644\u0644\u0647'), Term('content', u'\u0648\u062c\u0647\u0647'), Term('content', u'\u0627\u0645\u06cc\u0631\u0627\u0644\u0645\u0624\u0645\u0646\u06cc\u0646'), Term('content', u'\u0634\u0645\u0634\u06cc\u0631'), Term('content', u'\u062f\u0633\u062a'), Term('content', u'\u0633\u0624\u0627\u0644'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u06a9\u0627\u0641\u0631'), Term('content', u'\u0645\u0646\u06cc'), Term('content', u'\u0645\u0638\u0641\u0631'), Term('content', u'\u0634\u062f\u06cc'), Term('content', u'\u0627\u0646\u062f\u0627\u062e\u062a\u06cc'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u0627\u0641\u06a9\u0646\u062f\u0646'), Term('content', u'\u0628\u0648\u062f\u0647_\u0627\u0633\u062a'), Term('content', u'\u062d\u0627\u0644\u062a'), Term('content', u'\u067e\u06cc\u063a\u0627\u0645\u0628\u0631'), Term('content', u'\u0635\u0644\u06cc'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0633\u0644\u0645'), Term('content', u'\u06af\u0648\u0634'), Term('content', u'\u0631\u06a9\u0627\u0628\u062f\u0627\u0631'), Term('content', u'\u0627\u0644\u0645\u0648\u0645\u0646\u06cc\u0646'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u062e\u0648\u0627\u0647\u062f_\u0628\u0648\u062f\u0646'), Term('content', u'\u062e\u0628\u0631\u062a'), Term('content', u'\u06a9\u0631\u062f\u0645'), Term('content', u'\u0628\u0627\u0632\u06af\u0634\u062a\u0646'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u0645\u0633\u0627\u0645\u062d\u062a'), Term('content', u'\u062e\u0648\u0646\u06cc'), Term('content', u'\u062e\u0648\u06cc\u0634'), Term('content', u'\u0627\u0641\u062a\u0627\u062f\u0646'), Term('content', u'\u0628\u0627\u0631\u06cc'), Term('content', u'\u0645\u0631\u0627'), Term('content', u'\u0628\u06a9\u0634'), Term('content', u'\u0627\u0632\u06cc\u0646'), Term('content', u'\u0642\u0636\u0627'), Term('content', u'\u0628\u0631\u0647\u0627\u0646')]) runtime=0.0392479896545>
# processing file 13
# 11
# chaged to
# 9
# <Top 0 Results for And([Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0645\u0635\u0637\u0641\u06cc'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u0639\u06cc\u0627\u062f\u062a'), Term('content', u'\u0635\u062d\u0627\u0628\u06cc'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0641\u0627\u06cc\u062f\u0647')]) runtime=0.0039439201355>
# processing file 14
# 80
# chaged to
# 53
# <Top 0 Results for And([Term('content', u'\u0635\u06cc\u062f'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u062e\u0631'), Term('content', u'\u062a\u0634\u0646\u0647'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u06a9\u0648\u0634\u0634'), Term('content', u'\u0631\u0641\u062a'), Term('content', u'\u0686\u0634\u0645\u0647'), Term('content', u'\u0622\u0628'), Term('content', u'\u062e\u0648\u0631\u062f'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062c\u06af\u0631\u0628\u0646\u062f'), Term('content', u'\u062f\u0644'), Term('content', u'\u06af\u0631\u062f\u0647'), Term('content', u'\u0631\u0648\u0628\u0627\u0647'), Term('content', u'\u062e\u0648\u0631\u062f\u0647_\u0628\u0648\u062f'), Term('content', u'\u0644\u0637\u06cc\u0641\u062a\u0631\u0633\u062a'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u062c\u06af\u0631'), Term('content', u'\u0646\u06cc\u0627\u0641\u062a'), Term('content', u'\u0631\u0648\u0628\u0647'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f'), Term('content', u'\u06a9\u0648'), Term('content', u'\u06af\u0641\u062a'), Term('content', u'\u0628\u0648\u062f\u06cc'), Term('content', u'\u0622\u0646\u0686\u0646\u0627\u0646'), Term('content', u'\u0633\u06cc\u0627\u0633\u062a\u06cc'), Term('content', u'\u062f\u06cc\u062f\u0647_\u0628\u0648\u062f'), Term('content', u'\u0631\u0648\u0632'), Term('content', u'\u0647\u0632\u0627\u0631'), Term('content', u'\u062d\u06cc\u0644\u0647'), Term('content', u'\u062c\u0627\u0646'), Term('content', u'\u0628\u0631\u062f\u0647'), Term('content', u'\u0622\u0645\u062f\u06cc'), Term('content', u'\u0644\u0648\u06a9\u0646\u0627'), Term('content', u'\u0646\u0633\u0645\u0639'), Term('content', u'\u0646\u0639\u0642\u0644'), Term('content', u'\u0645\u0627\u06a9\u0646\u0627'), Term('content', u'\u0641\u06cc'), Term('content', u'\u0627\u0635\u062d\u0627\u0628'), Term('content', u'\u0627\u0644\u0633\u0639\u06cc\u0631')]) runtime=0.0775048732758>
# processing file 15
# 44
# chaged to
# 27
# <Top 0 Results for And([Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u0632\u0646'), Term('content', u'\u06af\u0641\u062a'), Term('content', u'\u0634\u0648\u0647\u0631'), Term('content', u'\u06af\u0648\u0634\u062a'), Term('content', u'\u06af\u0631\u0628\u0647'), Term('content', u'\u062e\u0648\u0631\u062f'), Term('content', u'\u062a\u0631\u0627\u0632\u0648'), Term('content', u'\u06a9\u0634\u06cc\u062f'), Term('content', u'\u0646\u06cc\u0645'), Term('content', u'\u0645\u0646'), Term('content', u'\u0628\u0631\u0622\u0645\u062f'), Term('content', u'\u0627\u0641\u0632\u0648\u0646'), Term('content', u'\u06af\u0648\u0634\u062a\u0633\u062a'), Term('content', u'\u06a9\u0648')]) runtime=0.0320188999176>
# processing file 16
# 151
# chaged to
# 100
# <Top 0 Results for And([Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u063a\u0645\u0627\u0632'), Term('content', u'\u0646\u0645\u0648\u062f\u0646'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u06a9\u0646\u06cc\u0632\u06a9'), Term('content', u'\u0645\u0635\u0648\u0631'), Term('content', u'\u06a9\u0627\u063a\u0630'), Term('content', u'\u0639\u0627\u0634\u0642'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u062e\u0644\u06cc\u0641\u0647'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0627\u0645\u06cc\u0631\u06cc'), Term('content', u'\u0633\u067e\u0627\u0647'), Term('content', u'\u06af\u0631\u0627\u0646'), Term('content', u'\u0628\u062f\u0631'), Term('content', u'\u0645\u0648\u0635\u0644'), Term('content', u'\u0642\u062a\u0644'), Term('content', u'\u0648\u06cc\u0631\u0627\u0646\u06cc'), Term('content', u'\u0628\u0633\u06cc\u0627\u0631'), Term('content', u'\u0628\u0647\u0631'), Term('content', u'\u063a\u0631\u0636'), Term('content', u'\u0627\u06cc\u062b\u0627\u0631'), Term('content', u'\u0635\u0627\u062d\u0628'), Term('content', u'\u0628\u062f\u06cc\u0646'), Term('content', u'\u062e\u0648\u0646'), Term('content', u'\u0631\u06cc\u0632'), Term('content', u'\u0645\u0633\u0644\u0645\u0627\u0646\u0627\u0646'), Term('content', u'\u0628\u06cc\u0634\u062a\u0631'), Term('content', u'\u0646\u0634\u0648\u062f'), Term('content', u'\u067e\u0634\u06cc\u0645\u0627\u0646'), Term('content', u'\u0633\u0631\u0644\u0634\u06a9\u0631'), Term('content', u'\u062e\u06cc\u0627\u0646\u062a'), Term('content', u'\u0633\u0648\u06af\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0646\u06af\u0648\u06cc\u062f'), Term('content', u'\u0622\u0646\u0686'), Term('content', u'\u0631\u0641\u062a'), Term('content', u'\u062d\u062c\u062a'), Term('content', u'\u0645\u0646\u06a9\u0631\u0627\u0646'), Term('content', u'\u0622\u062e\u0631\u062a'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0636\u0639\u0641'), Term('content', u'\u0632\u06cc\u0631\u0627'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u062f\u06cc\u0646'), Term('content', u'\u0645\u06cc'), Term('content', u'\u06af\u0631\u062f\u062f'), Term('content', u'\u063a\u06cc\u0631'), Term('content', u'\u0646\u0645\u06cc'), Term('content', u'\u0628\u06cc\u0646\u06cc\u0645'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u062e\u0648\u0628'), Term('content', u'\u0631\u0648\u06cc'), Term('content', u'\u0628\u0631\u0627\u06cc'), Term('content', u'\u062c\u0645\u0627\u0639'), Term('content', u'\u062e\u0646\u062f\u0647'), Term('content', u'\u06af\u0631\u0641\u062a\u0646'), Term('content', u'\u0634\u0647\u0648\u062a'), Term('content', u'\u0642\u0648\u062a'), Term('content', u'\u0627\u0645\u06cc\u0631'), Term('content', u'\u0641\u0647\u0645'), Term('content', u'\u0641\u0627\u0634'), Term('content', u'\u0631\u0627\u0632'), Term('content', u'\u0632\u062e\u0645'), Term('content', u'\u0634\u0645\u0634\u06cc\u0631'), Term('content', u'\u0627\u06a9\u0631\u0627\u0647'), Term('content', u'\u0631\u0627\u0633\u062a'), Term('content', u'\u06af\u0648'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u0628\u06a9\u0634\u0645\u062a')]) runtime=0.0409770011902>
# processing file 17
# 24
# chaged to
# 18
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0647\u062f\u0647\u062f'), Term('content', u'\u0633\u0644\u06cc\u0645\u0627\u0646'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u0642\u0636\u0627'), Term('content', u'\u0686\u0634\u0645\u0647\u0627\u06cc'), Term('content', u'\u0631\u0648\u0634\u0646'), Term('content', u'\u0628\u0633\u062a\u0647_\u0634\u0648\u062f'), Term('content', u'\u0637\u0639\u0646\u0647'), Term('content', u'\u0632\u0627\u063a'), Term('content', u'\u062f\u0639\u0648\u06cc'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646')]) runtime=0.0141370296478>
# processing file 18
# 19
# chaged to
# 16
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u062e\u0648\u0631\u0646\u062f\u06af\u0627\u0646'), Term('content', u'\u067e\u06cc\u0644'), Term('content', u'\u0628\u0686\u0647'), Term('content', u'\u062d\u0631\u0635'), Term('content', u'\u062a\u0631\u06a9'), Term('content', u'\u0646\u0635\u06cc\u062d\u062a'), Term('content', u'\u0646\u0627\u0635\u062d'), Term('content', u'\u0628\u0642\u06cc\u0647'), Term('content', u'\u0645\u062a\u0639\u0631\u0636\u0627\u0646'), Term('content', u'\u0628\u0686\u06af\u0627\u0646'), Term('content', u'\u0628\u0627\u0632\u06af\u0634\u062a\u0646'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a')]) runtime=0.00972700119019>
# processing file 19
# 46
# chaged to
# 33
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0627\u0647\u0644'), Term('content', u'\u0633\u0628\u0627'), Term('content', u'\u0637\u0627\u063a\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0646\u0639\u0645\u062a'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0634\u0648\u0645\u06cc'), Term('content', u'\u0637\u063a\u06cc\u0627\u0646'), Term('content', u'\u06a9\u0641\u0631\u0627\u0646'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0641\u0636\u06cc\u0644\u062a'), Term('content', u'\u0634\u06a9\u0631'), Term('content', u'\u0648\u0641\u0627'), Term('content', u'\u062c\u0645\u0639'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0622\u0641\u062a'), Term('content', u'\u0635\u0628\u0627\u062d\u06cc'), Term('content', u'\u0635\u0648\u0645\u0639\u0647'), Term('content', u'\u0639\u06cc\u0633\u06cc'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u0634\u0641\u0627'), Term('content', u'\u062f\u0639\u0627\u06cc'), Term('content', u'\u0628\u0627\u0642\u06cc')]) runtime=0.015371799469>
# processing file 20
# 28
# chaged to
# 18
# <Top 0 Results for And([Term('content', u'\u067e\u0630\u06cc\u0631\u0627'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0633\u062e\u0646'), Term('content', u'\u0628\u0627\u0637\u0644'), Term('content', u'\u062f\u0644'), Term('content', u'\u0628\u0627\u0637\u0644\u0627\u0646'), Term('content', u'\u062c\u0633\u062a\u0646'), Term('content', u'\u062f\u0631\u062e\u062a'), Term('content', u'\u0645\u06cc\u0648\u0647'), Term('content', u'\u062e\u0648\u0631\u062f'), Term('content', u'\u0646\u0645\u06cc\u0631\u062f'), Term('content', u'\u0634\u0631\u062d'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u06cc\u062e'), Term('content', u'\u0637\u0627\u0644\u0628'), Term('content', u'\u0645\u0642\u0644\u062f')]) runtime=0.0205061435699>
# processing file 21
# 36
# chaged to
# 24
# <Top 0 Results for And([Term('content', u'\u0628\u0642\u06cc\u0647'), Term('content', u'\u062f\u0627\u0633\u062a\u0627\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u062e\u0648\u0627\u062c\u0647'), Term('content', u'\u062f\u0639\u0648\u062a'), Term('content', u'\u0631\u0648\u0633\u062a\u0627\u06cc\u06cc'), Term('content', u'\u062f\u0647'), Term('content', u'\u0631\u0648\u0627\u0646'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0642\u0648\u0645\u0634'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0627\u062f\u06cc\u062f\u0647'), Term('content', u'\u0646\u0627\u0634\u0646\u0627\u062e\u062a\u0647'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646')]) runtime=0.0110909938812>
# processing file 22
# 134
# chaged to
# 91
# <Top 0 Results for And([Term('content', u'\u0628\u0642\u06cc\u0647'), Term('content', u'\u0639\u0645\u0627\u0631\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0633\u0644\u06cc\u0645\u0627\u0646'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u0645\u0633\u062c\u062f'), Term('content', u'\u0627\u0642\u0635\u06cc'), Term('content', u'\u062a\u0639\u0644\u06cc\u0645'), Term('content', u'\u0648\u062d\u06cc'), Term('content', u'\u062e\u062f\u0627'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u062d\u06a9\u0645\u062a\u0647\u0627\u06cc\u06cc'), Term('content', u'\u062f\u0627\u0646\u062f'), Term('content', u'\u0645\u0639\u0627\u0648\u0646\u062a'), Term('content', u'\u0645\u0644\u0627\u06cc\u06a9\u0647'), Term('content', u'\u062f\u06cc\u0648'), Term('content', u'\u067e\u0631\u06cc'), Term('content', u'\u0622\u062f\u0645\u06cc'), Term('content', u'\u0622\u0634\u06a9\u0627\u0631\u0627'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0645\u0642\u0627\u0645'), Term('content', u'\u062a\u0634\u0628\u0647'), Term('content', u'\u06a9\u0627\u0631\u0647\u0627\u06cc'), Term('content', u'\u0641\u0631\u0642'), Term('content', u'\u0638\u0627\u0647\u0631'), Term('content', u'\u0645\u06cc\u0627\u0646'), Term('content', u'\u062f\u0648'), Term('content', u'\u062e\u0648\u06cc\u0634\u062a\u0646'), Term('content', u'\u0628\u0646'), Term('content', u'\u062f\u0627\u0648\u062f'), Term('content', u'\u0646\u0627\u0645'), Term('content', u'\u062f\u0631\u0622\u0645\u062f\u0646'), Term('content', u'\u0631\u0648\u0632'), Term('content', u'\u0628\u0639\u062f'), Term('content', u'\u062a\u0645\u0627\u0645'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0639\u0628\u0627\u062f\u062a'), Term('content', u'\u0627\u0631\u0634\u0627\u062f'), Term('content', u'\u0639\u0627\u0628\u062f\u0627\u0646'), Term('content', u'\u0645\u0639\u062a\u06a9\u0641\u0627\u0646'), Term('content', u'\u0631\u0633\u062a\u0646'), Term('content', u'\u0639\u0642\u0627\u0642\u06cc\u0631'), Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u062e\u0631\u0648\u0628'), Term('content', u'\u06af\u0648\u0634\u0647'), Term('content', u'\u063a\u0645\u06af\u06cc\u0646'), Term('content', u'\u0633\u062e\u0646'), Term('content', u'\u062e\u0627\u0635\u06cc\u062a'), Term('content', u'\u0628\u06af\u0641\u062a'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u062d\u0635\u0648\u0644'), Term('content', u'\u0639\u0644\u0645'), Term('content', u'\u0645\u0627\u0644'), Term('content', u'\u062c\u0627\u0647'), Term('content', u'\u0628\u062f\u06af\u0648\u0647\u0631\u0627\u0646'), Term('content', u'\u0641\u0636\u06cc\u062d\u062a'), Term('content', u'\u0627\u0648\u0633\u062a'), Term('content', u'\u0634\u0645\u0634\u06cc\u0631\u06cc\u0633\u062a'), Term('content', u'\u0627\u0641\u062a\u0627\u062f\u0633\u062a'), Term('content', u'\u062f\u0633\u062a'), Term('content', u'\u0631\u0627\u0647'), Term('content', u'\u0632\u0646')]) runtime=0.0472939014435>
# processing file 23
# 110
# chaged to
# 89
# <Top 0 Results for And([Term('content', u'\u0639\u0634\u0631\u062a'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0645\u0631\u063a\u0632\u0627\u0631'), Term('content', u'\u0633\u06cc\u0627\u0633\u062a'), Term('content', u'\u0647\u0631\u0645\u0632'), Term('content', u'\u0634\u0641\u06cc\u0639'), Term('content', u'\u0627\u0646\u06af\u06cc\u062e\u062a\u0646'), Term('content', u'\u067e\u06cc\u0631\u0627\u0646'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0646\u06cc\u0627\u06cc'), Term('content', u'\u062e\u0648\u06cc\u0634'), Term('content', u'\u0627\u0646\u0648\u0634\u06cc\u0631\u0648\u0627\u0646'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u0627\u067e\u0648\u0631'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u0634\u0628\u062f\u06cc\u0632'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0627\u0631\u0645\u0646'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u0646\u0645\u0648\u062f\u0646'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u0627\u0648\u0644'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0633\u0648\u0645'), Term('content', u'\u067e\u06cc\u062f\u0627'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u062a\u0631\u062a\u06cc\u0628'), Term('content', u'\u06a9\u0648\u0634\u06a9'), Term('content', u'\u0628\u0631\u0627\u06cc'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u0645\u0647\u06cc\u0646'), Term('content', u'\u0628\u0627\u0646\u0648'), Term('content', u'\u0645\u062c\u0644\u0633'), Term('content', u'\u0628\u0632\u0645'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062f\u06cc\u06af\u0631'), Term('content', u'\u0622\u06af\u0627\u0647\u06cc'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u062a\u062e\u062a'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0628\u062c\u0627\u06cc'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u06af\u0631\u06cc\u062e\u062a\u0646'), Term('content', u'\u0628\u0647\u0631\u0627\u0645'), Term('content', u'\u0686\u0648\u0628\u06cc\u0646')]) runtime=0.0306661128998>
# processing file 24
# 143
# chaged to
# 103
# <Top 0 Results for And([Term('content', u'\u06af\u0631\u06cc\u062e\u062a\u0646'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u0645\u0647\u06cc\u0646'), Term('content', u'\u0628\u0627\u0646\u0648'), Term('content', u'\u0645\u062f\u0627\u06cc\u0646'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0686\u0634\u0645\u0647'), Term('content', u'\u0633\u0627\u0631'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0645\u0634\u06af\u0648\u06cc'), Term('content', u'\u0628\u0647\u0645'), Term('content', u'\u0634\u06a9\u0627\u0631\u06af\u0627\u0647'), Term('content', u'\u0627\u0646\u062f\u0631\u0632'), Term('content', u'\u0633\u0648\u06af\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0628\u0647\u0627\u0631'), Term('content', u'\u0639\u06cc\u0634'), Term('content', u'\u0634\u06cc\u0631\u06a9\u0634\u062a\u0646'), Term('content', u'\u0628\u0632\u0645\u06af\u0627\u0647'), Term('content', u'\u0627\u0641\u0633\u0627\u0646\u0647'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0634\u0627\u067e\u0648\u0631'), Term('content', u'\u062f\u062e\u062a\u0631\u0627\u0646'), Term('content', u'\u0633\u0631\u0627\u0626\u06cc'), Term('content', u'\u062f\u0647'), Term('content', u'\u062f\u062e\u062a\u0631'), Term('content', u'\u0645\u0631\u0627\u062f'), Term('content', u'\u0637\u0644\u0628\u06cc\u062f\u0646'), Term('content', u'\u0645\u0627\u0646\u0639'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u062e\u0634\u0645'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0631\u0648\u0645'), Term('content', u'\u067e\u06cc\u0648\u0646\u062f'), Term('content', u'\u0645\u0631\u06cc\u0645'), Term('content', u'\u062c\u0646\u06af'), Term('content', u'\u0628\u0647\u0631\u0627\u0645'), Term('content', u'\u062a\u062e\u062a'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0645\u062f\u0627\u0626\u0646'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0646\u0627\u0644\u06cc\u062f\u0646'), Term('content', u'\u062c\u062f\u0627\u0626\u06cc'), Term('content', u'\u0648\u0635\u06cc\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647\u06cc'), Term('content', u'\u062c\u0627\u06cc'), Term('content', u'\u0622\u06af\u0647\u06cc'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u0686\u0648\u0628\u06cc\u0646'), Term('content', u'\u0628\u0632\u0645'), Term('content', u'\u0622\u0631\u0627\u0626\u06cc'), Term('content', u'\u0634\u0641\u0627\u0639\u062a'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0637\u0644\u0628')]) runtime=0.0227830410004>
# processing file 25
# 50
# chaged to
# 39
# <Top 0 Results for And([Term('content', u'\u0632\u0627\u0631\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0641\u0631\u0647\u0627\u062f'), Term('content', u'\u0639\u0634\u0642'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u0622\u06af\u0627\u0647\u06cc'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0631\u0627\u06cc'), Term('content', u'\u0632\u062f\u0646'), Term('content', u'\u06a9\u0627\u0631'), Term('content', u'\u0645\u0646\u0627\u0638\u0631\u0647'), Term('content', u'\u06a9\u0648\u0647'), Term('content', u'\u06a9\u0646\u062f\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0628\u06cc\u0633\u062a\u0648\u0646'), Term('content', u'\u0633\u0642\u0637'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0633\u0628'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0645\u06a9\u0631')]) runtime=0.0244331359863>
# processing file 26
# 64
# chaged to
# 53
# <Top 0 Results for And([Term('content', u'\u0628\u0627\u0632\u06af\u0634\u062a\u0646'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0642\u0635\u0631'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u067e\u0634\u06cc\u0645\u0627\u0646'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u063a\u0632\u0644'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0646\u06a9\u06cc\u0633\u0627'), Term('content', u'\u0632\u0628\u0627\u0646'), Term('content', u'\u0633\u0631\u0648\u062f'), Term('content', u'\u0628\u0627\u0631\u0628\u062f'), Term('content', u'\u0646\u06cc\u06a9\u0633\u0627'), Term('content', u'\u0628\u06cc\u0631\u0648\u0646'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062e\u0631\u06af\u0627\u0647')]) runtime=0.0104711055756>
# processing file 27
# 35
# chaged to
# 27
# <Top 0 Results for And([Term('content', u'\u0639\u0627\u0634\u0642'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u06cc\u06a9\u062f\u06cc\u06af\u0631'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0639\u0634\u0642'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u062e\u0648\u0627\u0633\u062a\u0627\u0631\u06cc'), Term('content', u'\u0632\u0627\u0631\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u062e\u0627\u0646\u0647'), Term('content', u'\u06a9\u0639\u0628\u0647'), Term('content', u'\u067e\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646')]) runtime=0.0196070671082>
# processing file 28
# 24
# chaged to
# 20
# <Top 0 Results for And([Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0648\u0641\u0644'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u062c\u0646\u06af'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0642\u0628\u06cc\u0644\u0647'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0639\u062a\u0627\u0628'), Term('content', u'\u0645\u0635\u0627\u0641'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0631\u0647\u0627\u0646\u06cc\u062f\u0646'), Term('content', u'\u0622\u0647\u0648\u0627\u0646')]) runtime=0.0100860595703>
# processing file 29
# 102
# chaged to
# 82
# <Top 0 Results for And([Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0627\u0628\u0646'), Term('content', u'\u0633\u0644\u0627\u0645'), Term('content', u'\u0622\u06af\u0627\u0647\u06cc'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u0634\u0648\u0647\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0641\u0631\u0632\u0646\u062f'), Term('content', u'\u0648\u062f\u0627\u0639'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u0627\u0646\u0633'), Term('content', u'\u0648\u062d\u0648\u0634'), Term('content', u'\u0633\u0628\u0627\u0639'), Term('content', u'\u0646\u06cc\u0627\u06cc\u0634'), Term('content', u'\u062f\u0631\u06af\u0627\u0647'), Term('content', u'\u062e\u062f\u0627\u06cc'), Term('content', u'\u062a\u0639\u0627\u0644\u06cc'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0627\u0645\u0647'), Term('content', u'\u067e\u0627\u0633\u062e'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0633\u0644\u06cc\u0645'), Term('content', u'\u0639\u0627\u0645\u0631\u06cc'), Term('content', u'\u062e\u0627\u0644'), Term('content', u'\u0645\u0627\u062f\u0631'), Term('content', u'\u0648\u0641\u0627\u062a'), Term('content', u'\u062e\u0648\u0627\u0646\u062f\u0646'), Term('content', u'\u063a\u0632\u0644'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u0622\u0634\u0646\u0627'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0628\u063a\u062f\u0627\u062f\u06cc'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u062e\u0632\u0627\u0646'), Term('content', u'\u06af\u0630\u0634\u062a\u0646'), Term('content', u'\u0631\u0648\u0636\u0647')]) runtime=0.012629032135>
# processing file 30
# 58
# chaged to
# 45
# <Top 0 Results for And([Term('content', u'\u0634\u06a9\u0627\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0628\u0647\u0631\u0627\u0645'), Term('content', u'\u062f\u0627\u063a'), Term('content', u'\u06af\u0648\u0631\u0627\u0646'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0627\u0698\u062f\u0647\u0627'), Term('content', u'\u06af\u0646\u062c'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0647\u0641\u062a'), Term('content', u'\u067e\u06cc\u06a9\u0631'), Term('content', u'\u062e\u0648\u0631\u0646\u0642'), Term('content', u'\u0622\u06af\u0627\u0647\u06cc'), Term('content', u'\u0648\u0641\u0627\u062a'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u0644\u0634\u06af\u0631'), Term('content', u'\u06a9\u0634\u06cc\u062f\u0646'), Term('content', u'\u0627\u06cc\u0631\u0627\u0646'), Term('content', u'\u0646\u0627\u0645\u0647'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u06af\u0648\u0631'), Term('content', u'\u067e\u0627\u0633\u062e'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0627\u06cc\u0631\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u0628\u0631\u06af\u0631\u0641\u062a\u0646'), Term('content', u'\u062a\u0627\u062c'), Term('content', u'\u0645\u06cc\u0627\u0646'), Term('content', u'\u062f\u0648'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u062a\u062e\u062a'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u062c\u0627\u06cc')]) runtime=0.0353980064392>
# processing file 31
# 116
# chaged to
# 99
# <Top 0 Results for And([Term('content', u'\u062e\u0648\u0627\u0633\u062a\u0646'), Term('content', u'\u0628\u0647\u0631\u0627\u0645'), Term('content', u'\u062f\u062e\u062a\u0631'), Term('content', u'\u0634\u0627\u0647\u0627\u0646'), Term('content', u'\u0647\u0641\u062a'), Term('content', u'\u0627\u0642\u0644\u06cc\u0645'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0628\u0632\u0645'), Term('content', u'\u0632\u0645\u0633\u062a\u0627\u0646'), Term('content', u'\u0633\u0627\u062e\u062a\u0646'), Term('content', u'\u06af\u0646\u0628\u062f'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0631\u0648\u0632'), Term('content', u'\u0634\u0646\u0628\u0647'), Term('content', u'\u0633\u06cc\u0627\u0647'), Term('content', u'\u0627\u0641\u0633\u0627\u0646\u0647'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0627\u0648\u0644'), Term('content', u'\u06cc\u06a9\u0634\u0646\u0628\u0647'), Term('content', u'\u0632\u0631\u062f'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u062f\u0648\u0634\u0646\u0628\u0647'), Term('content', u'\u0633\u0628\u0632'), Term('content', u'\u0633\u0648\u0645'), Term('content', u'\u0633\u0647'), Term('content', u'\u0633\u0631\u062e'), Term('content', u'\u0686\u0647\u0627\u0631\u0645'), Term('content', u'\u0686\u0647\u0627\u0631\u0634\u0646\u0628\u0647'), Term('content', u'\u067e\u06cc\u0631\u0648\u0632\u0647'), Term('content', u'\u0631\u0646\u06af'), Term('content', u'\u067e\u0646\u062c\u0645'), Term('content', u'\u067e\u0646\u062c\u0634\u0646\u0628\u0647'), Term('content', u'\u0635\u0646\u062f\u0644\u06cc'), Term('content', u'\u0634\u0634\u0645'), Term('content', u'\u0622\u062f\u06cc\u0646\u0647'), Term('content', u'\u0633\u067e\u06cc\u062f'), Term('content', u'\u0647\u0641\u062a\u0645')]) runtime=0.0175368785858>
# ...
# processing file 37
# 93
# chaged to
# 70
# <Top 0 Results for And([Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0632\u06cc\u0628\u0627\u06cc\u06cc'), Term('content', u'\u0632\u0644\u06cc\u062e\u0627'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u0628\u06cc\u062f\u0627\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0646\u0647\u0641\u062a\u0646'), Term('content', u'\u0627\u0646\u062f\u0648\u0647'), Term('content', u'\u067e\u0631\u0633\u062a\u0627\u0631\u0627\u0646'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u062f\u0627\u06cc\u0647'), Term('content', u'\u062d\u0627\u0644'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0633\u0648\u0645'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0631\u0633\u0648\u0644\u0627\u0646'), Term('content', u'\u0634\u0627\u0647\u0627\u0646'), Term('content', u'\u0686\u0646\u062f\u06cc\u0646'), Term('content', u'\u06a9\u0634\u0648\u0631'), Term('content', u'\u062e\u0648\u0627\u0633\u062a\u06af\u0627\u0631\u06cc'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0631\u0633\u0648\u0644'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u062c\u0627\u0646\u0628'), Term('content', u'\u0639\u0632\u06cc\u0632'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0634\u06a9\u0627\u0641'), Term('content', u'\u062e\u06cc\u0645\u0647'), Term('content', u'\u062f\u0631\u0622\u0645\u062f\u0646'), Term('content', u'\u0646\u062b\u0627\u0631'), Term('content', u'\u0627\u0641\u0634\u0627\u0646\u062f\u0646'), Term('content', u'\u0645\u0635\u0631\u06cc\u0627\u0646'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0639\u0645\u0631'), Term('content', u'\u06af\u0630\u0631\u0627\u0646\u062f\u0646'), Term('content', u'\u0645\u0641\u0627\u0631\u0642\u062a')]) runtime=0.0222220420837>
# processing file 38
# 58
# chaged to
# 37
# <Top 0 Results for And([Term('content', u'\u0622\u063a\u0627\u0632'), Term('content', u'\u062d\u0633\u062f\u0628\u0631\u062f\u0646'), Term('content', u'\u0628\u0631\u0627\u062f\u0631\u0627\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0622\u0641\u062a\u0627\u0628'), Term('content', u'\u0645\u0627\u0647'), Term('content', u'\u06cc\u0627\u0632\u062f\u0647'), Term('content', u'\u0633\u062a\u0627\u0631\u0647'), Term('content', u'\u0633\u062c\u062f\u0647'), Term('content', u'\u0645\u06cc'), Term('content', u'\u0628\u0631\u0646\u062f'), Term('content', u'\u062f\u0631\u062e\u0648\u0627\u0633\u062a'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0635\u062d\u0631\u0627'), Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u062c\u0627\u0647'), Term('content', u'\u0627\u0641\u06af\u0646\u062f\u0646\u0634'), Term('content', u'\u0628\u06cc\u0631\u0648\u0646'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u06a9\u0627\u0631\u0648\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u0686\u0627\u0647'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u062a\u0645\u0646\u0627'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u0628\u0627\u0646\u06cc')]) runtime=0.0239260196686>
# processing file 39
# 117
# chaged to
# 88
# <Top 0 Results for And([Term('content', u'\u0634\u0631\u062d'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0645\u062d\u0646\u062a'), Term('content', u'\u0631\u0627\u0647'), Term('content', u'\u0632\u062d\u0645\u062a'), Term('content', u'\u0686\u0627\u0647'), Term('content', u'\u0628\u0631\u0627\u06cc'), Term('content', u'\u0632\u0644\u06cc\u062e\u0627'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u062e\u0631\u06cc\u062f\u0646'), Term('content', u'\u0627\u0636\u0639\u0627\u0641'), Term('content', u'\u062d\u0631\u0627\u062c'), Term('content', u'\u062e\u062f\u0645\u062a\u06af\u0627\u0631\u06cc'), Term('content', u'\u0646\u0645\u0648\u062f\u0646'), Term('content', u'\u0645\u0637\u0627\u0644\u0628\u0647'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0648\u0635\u0627\u0644'), Term('content', u'\u0627\u0633\u062a\u063a\u0646\u0627'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0628\u0627\u063a'), Term('content', u'\u0639\u0631\u0636\u0647'), Term('content', u'\u06a9\u0646\u06cc\u0632\u0627\u0646'), Term('content', u'\u062c\u0645\u0627\u0644'), Term('content', u'\u062e\u0648\u06cc\u0634'), Term('content', u'\u06cc\u06a9\u062a\u0627\u067e\u0631\u0633\u062a'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u062a\u0636\u0631\u0639'), Term('content', u'\u062f\u0627\u06cc\u0647'), Term('content', u'\u0631\u0627\u0647\u0646\u0645\u0627\u06cc\u06cc'), Term('content', u'\u0633\u0627\u062e\u062a\u0646'), Term('content', u'\u0639\u0645\u0627\u0631\u062a'), Term('content', u'\u0648\u0635\u0641'), Term('content', u'\u0622\u0631\u0627\u06cc\u0634'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0639\u0632\u06cc\u0632'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0647\u0645\u0627\u0646'), Term('content', u'\u062f\u0645'), Term('content', u'\u0633\u0627\u0644'), Term('content', u'\u06af\u0648\u0627\u0647\u06cc'), Term('content', u'\u0637\u0641\u0644'), Term('content', u'\u0634\u06cc\u0631\u062e\u0648\u0627\u0631\u0647'), Term('content', u'\u0628\u06cc'), Term('content', u'\u06af\u0646\u0627\u0647\u06cc'), Term('content', u'\u0632\u0628\u0627\u0646'), Term('content', u'\u0637\u0639\u0646\u0647'), Term('content', u'\u06af\u0634\u0627\u062f\u0646'), Term('content', u'\u0632\u0646\u0627\u0646'), Term('content', u'\u062a\u06cc\u063a'), Term('content', u'\u063a\u06cc\u0631\u062a'), Term('content', u'\u0639\u0634\u0642'), Term('content', u'\u062f\u0633\u062a'), Term('content', u'\u0628\u0631\u06cc\u062f\u0646')]) runtime=0.043751001358>
# processing file 40
# 69
# chaged to
# 50
# <Top 0 Results for And([Term('content', u'\u0632\u0646\u062f\u0627\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u0627\u062d\u0633\u0627\u0646'), Term('content', u'\u0632\u0646\u062f\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u062a\u0639\u0628\u06cc\u0631'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0634\u0627\u0647'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0628\u06cc\u0631\u0648\u0646'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0648\u0641\u0627\u062a'), Term('content', u'\u0639\u0632\u06cc\u0632'), Term('content', u'\u062a\u0646\u0647\u0627\u06cc\u06cc'), Term('content', u'\u0632\u0644\u06cc\u062e\u0627'), Term('content', u'\u0627\u0628\u062a\u0644\u0627\u06cc'), Term('content', u'\u0645\u062d\u0646\u062a'), Term('content', u'\u0641\u0631\u0627\u0642'), Term('content', u'\u0628\u0639\u062f'), Term('content', u'\u0627\u0644\u062a\u0641\u0627\u062a'), Term('content', u'\u0646\u06a9\u0631\u062f\u0646'), Term('content', u'\u06a9\u0641\u0631'), Term('content', u'\u0648\u06cc'), Term('content', u'\u062a\u0648\u062d\u06cc\u062f'), Term('content', u'\u0639\u0642\u062f'), Term('content', u'\u0646\u06a9\u0627\u062d'), Term('content', u'\u0628\u0633\u062a\u0646'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0647\u0644\u0627\u06a9'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0645\u0641\u0627\u0631\u0642\u062a')]) runtime=0.0220608711243>
# processing file 41
# 49
# chaged to
# 35
# <Top 0 Results for And([Term('content', u'\u0646\u0627\u0645\u0647'), Term('content', u'\u0646\u0648\u0634\u062a\u0646'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u0628\u06cc\u0645\u0627\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0634\u0648\u0647\u0631'), Term('content', u'\u0648\u0641\u0627\u062a'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0634\u06a9\u0633\u062a\u0646'), Term('content', u'\u06a9\u0627\u0633\u0647'), Term('content', u'\u0631\u0642\u0635'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0630\u0648\u0642'), Term('content', u'\u062f\u06cc\u06af\u0631\u0627\u0646\u0634'), Term('content', u'\u0645\u06cc\u0644\u06cc'), Term('content', u'\u0627\u0646\u062a\u0638\u0627\u0631'), Term('content', u'\u0627\u06cc\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0622\u0634\u06cc\u0627\u0646'), Term('content', u'\u0645\u0631\u063a'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u0648\u0635\u0641'), Term('content', u'\u062e\u0632\u0627\u0646')]) runtime=0.0155189037323>
# processing file 42
# 7
# chaged to
# 5
# <Top 0 Results for And([Term('content', u'\u0627\u062e\u062a\u0644\u0627\u0641'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0686\u06af\u0648\u0646\u06af\u06cc'), Term('content', u'\u0634\u06a9\u0644'), Term('content', u'\u067e\u06cc\u0644')]) runtime=0.00280690193176>
# processing file 43
# 56
# chaged to
# 39
# <Top 0 Results for And([Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u0641\u0631\u0639\u0648\u0646'), Term('content', u'\u0645\u0648\u0633\u06cc'), Term('content', u'\u0648\u062d\u06cc'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u0645\u0647\u0644\u062a'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0633\u0627\u062d\u0631\u0627\u0646'), Term('content', u'\u062c\u0645\u0639'), Term('content', u'\u0645\u062f\u0627\u06cc\u0646'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u062e\u0648\u0627\u0646\u062f\u0646'), Term('content', u'\u062f\u0648'), Term('content', u'\u0633\u0627\u062d\u0631'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u06af\u0648\u0631'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0631\u0648\u0627\u0646'), Term('content', u'\u062d\u0642\u06cc\u0642\u062a'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0645\u0631\u062f\u0647'), Term('content', u'\u0641\u0631\u0632\u0646\u062f\u0627\u0646')]) runtime=0.016627073288>
# processing file 44
# 46
# chaged to
# 32
# <Top 0 Results for And([Term('content', u'\u0631\u0646\u062c\u0648\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0648\u0633\u062a\u0627\u062f'), Term('content', u'\u0648\u0647\u0645'), Term('content', u'\u062c\u0627\u0645\u0647'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u0627\u0641\u062a\u0627\u062f\u0646'), Term('content', u'\u0627\u0633\u062a\u0627\u062f'), Term('content', u'\u0646\u0627\u0644\u06cc\u062f\u0646'), Term('content', u'\u0631\u0646\u062c\u0648\u0631\u06cc'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u0627\u0641\u06a9\u0646\u062f\u0646'), Term('content', u'\u06a9\u0648\u062f\u06a9\u0627\u0646'), Term('content', u'\u0642\u0631\u0622\u0646'), Term('content', u'\u062e\u0648\u0627\u0646\u062f\u0646'), Term('content', u'\u062f\u0631\u062f'), Term('content', u'\u0627\u0641\u0632\u0627\u06cc\u062f'), Term('content', u'\u062e\u0644\u0627\u0635'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0645\u06a9\u062a\u0628'), Term('content', u'\u0628\u062f\u06cc\u0646'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0645\u0627\u062f\u0631\u0627\u0646'), Term('content', u'\u0639\u06cc\u0627\u062f\u062a')]) runtime=0.0150859355927>
# processing file 45
# 16
# chaged to
# 13
# <Top 0 Results for And([Term('content', u'\u0627\u0645\u062a\u062d\u0627\u0646'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u062e\u0648\u0627\u062c\u0647'), Term('content', u'\u0644\u0642\u0645\u0627\u0646'), Term('content', u'\u0632\u06cc\u0631\u06a9\u06cc'), Term('content', u'\u0638\u0627\u0647\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0641\u0636\u0644'), Term('content', u'\u06a9\u0646\u0646\u062f\u06af\u0627\u0646')]) runtime=0.00493788719177>
# processing file 46
# 27
# chaged to
# 24
# <Top 0 Results for And([Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062f\u0648\u0633\u062a\u0627\u0646'), Term('content', u'\u0628\u06cc\u0645\u0627\u0631\u0633\u062a\u0627\u0646'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u067e\u0631\u0633\u0634'), Term('content', u'\u0630\u0627\u0627\u0644\u0646\u0648\u0646'), Term('content', u'\u0645\u0635\u0631\u06cc'), Term('content', u'\u0631\u062d\u0645\u0629'), Term('content', u'\u0627\u0644\u0644\u0647'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0641\u0647\u0645'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0645\u0631\u06cc\u062f\u0627\u0646'), Term('content', u'\u062f\u06cc\u0648\u0627\u0646\u0647'), Term('content', u'\u0646\u0634\u062f'), Term('content', u'\u0642\u0627\u0635\u062f'), Term('content', u'\u06a9\u0631\u062f\u0647_\u0627\u0633\u062a'), Term('content', u'\u0631\u062c\u0648\u0639'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a')]) runtime=0.0106511116028>

# %%
with open("RelevanceAssesment/RelevanceAssesment.txt") as f:
    lines = f.readlines()
test_file_names = lines[0::3]
Relevantdocs = lines[1::3]


sum_precision = 0
sum_recall = 0

for i in range(len(test_file_names)):
    print("processing file "+str(i))
    file = test_file_names[i]
    with codecs.open("Queries/"+file.split("\n")[0], 'r', "utf-8") as f:
        query = f.read().replace("\n", " ")
        
        
        if "N" in experiment:
                #print("normalize")
                normalizer = Normalizer()
                query = normalizer.normalize(query)
        if "T"  in experiment:
            #print("tokenize")
            query = word_tokenize(query)
        if "R" in experiment:
                stopwords = []
                with codecs.open("Stopwords/Stopwords.txt", 'r', "utf-8") as f:
                    lines = f.readlines()
                for line in lines:
                    stopwords.append(line.split('\n')[0])
                #print("Remove StopWords")
                query_temp = []
                for word in query:
                    if not word in stopwords:
                        query_temp.append(word)
                print(query)
                print("chaged to")
                print(query_temp)
                query = query_temp
    results = SE.Search(query)
    pre,rec = precision_recall(results, Relevantdocs[i].split("\n")[0])
    sum_precision += pre
    sum_recall += rec
experiment_precision = sum_precision / len(test_file_names)
experiment_recall = sum_recall / len(test_file_names)
# Out:
# processing file 0
# [u'\u0628\u0631\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0622\u0646', u'\u0637\u0628\u06cc\u0628', u'\u0631\u0627', u'\u0628\u0631', u'\u0628\u06cc\u0645\u0627\u0631', u'\u062a\u0627', u'\u062d\u0627\u0644', u'\u0627\u0648', u'\u0631\u0627', u'\u0628\u0628\u06cc\u0646\u062f', u'\u062e\u0644\u0648\u062a', u'\u0637\u0644\u0628\u06cc\u062f\u0646', u'\u0622\u0646', u'\u0648\u0644\u06cc', u'\u0627\u0632', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u062c\u0647\u062a', u'\u062f\u0631\u06cc\u0627\u0641\u062a\u0646', u'\u0631\u0646\u062c', u'\u06a9\u0646\u06cc\u0632\u06a9', u'\u0628\u0631\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0622\u0646', u'\u0637\u0628\u06cc\u0628', u'\u0631\u0627', u'\u0628\u0631', u'\u0628\u06cc\u0645\u0627\u0631', u'\u062a\u0627', u'\u062d\u0627\u0644', u'\u0627\u0648', u'\u0631\u0627', u'\u0628\u0628\u06cc\u0646\u062f', u'\u0645\u0644\u0627\u0642\u0627\u062a', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0628\u0627', u'\u0622\u0646', u'\u0648\u0644\u06cc', u'\u06a9\u0647', u'\u062f\u0631', u'\u062e\u0648\u0627\u0628\u0634', u'\u0646\u0645\u0648\u062f\u0646\u062f', u'\u0638\u0627\u0647\u0631', u'\u0634\u062f\u0646', u'\u0639\u062c\u0632', u'\u062d\u06a9\u06cc\u0645\u0627\u0646', u'\u0627\u0632', u'\u0645\u0639\u0627\u0644\u062c\u0647\u0654', u'\u06a9\u0646\u06cc\u0632\u06a9', u'\u0648', u'\u0631\u0648\u06cc', u'\u0622\u0648\u0631\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0628\u0647', u'\u062f\u0631\u06af\u0627\u0647', u'\u0627\u0644\u0647', u'\u0648', u'\u062f\u0631', u'\u062e\u0648\u0627\u0628', u'\u062f\u06cc\u062f\u0646', u'\u0627\u0648', u'\u0648\u0644\u06cc\u06cc', u'\u0631\u0627\u0639\u0627\u0634\u0642', u'\u0634\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0628\u0631', u'\u06a9\u0646\u06cc\u0632\u06a9', u'\u0631\u0646\u062c\u0648\u0631', u'\u0648', u'\u062a\u062f\u0628\u06cc\u0631', u'\u06a9\u0631\u062f\u0646', u'\u062f\u0631', u'\u0635\u062d\u062a', u'\u0627\u0648']
# chaged to
# [u'\u0628\u0631\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0637\u0628\u06cc\u0628', u'\u0628\u06cc\u0645\u0627\u0631', u'\u062d\u0627\u0644', u'\u0628\u0628\u06cc\u0646\u062f', u'\u062e\u0644\u0648\u062a', u'\u0637\u0644\u0628\u06cc\u062f\u0646', u'\u0648\u0644\u06cc', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u062c\u0647\u062a', u'\u062f\u0631\u06cc\u0627\u0641\u062a\u0646', u'\u0631\u0646\u062c', u'\u06a9\u0646\u06cc\u0632\u06a9', u'\u0628\u0631\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0637\u0628\u06cc\u0628', u'\u0628\u06cc\u0645\u0627\u0631', u'\u062d\u0627\u0644', u'\u0628\u0628\u06cc\u0646\u062f', u'\u0645\u0644\u0627\u0642\u0627\u062a', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u0648\u0644\u06cc', u'\u062e\u0648\u0627\u0628\u0634', u'\u0646\u0645\u0648\u062f\u0646\u062f', u'\u0638\u0627\u0647\u0631', u'\u0634\u062f\u0646', u'\u0639\u062c\u0632', u'\u062d\u06a9\u06cc\u0645\u0627\u0646', u'\u0645\u0639\u0627\u0644\u062c\u0647\u0654', u'\u06a9\u0646\u06cc\u0632\u06a9', u'\u0631\u0648\u06cc', u'\u0622\u0648\u0631\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u062f\u0631\u06af\u0627\u0647', u'\u0627\u0644\u0647', u'\u062e\u0648\u0627\u0628', u'\u062f\u06cc\u062f\u0646', u'\u0648\u0644\u06cc\u06cc', u'\u0631\u0627\u0639\u0627\u0634\u0642', u'\u0634\u062f\u0646', u'\u067e\u0627\u062f\u0634\u0627\u0647', u'\u06a9\u0646\u06cc\u0632\u06a9', u'\u0631\u0646\u062c\u0648\u0631', u'\u062a\u062f\u0628\u06cc\u0631', u'\u06a9\u0631\u062f\u0646', u'\u0635\u062d\u062a']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a7172e14be2a> in <module>()
#      37                 print("chaged to")
#      38                 print(query_temp)
# ---> 39                 query = file_query_temp
#      40     results = SE.Search(query)
#      41     pre,rec = precision_recall(results, Relevantdocs[i].split("\n")[0])
#
# NameError: name 'file_query_temp' is not defined

# %%
experiment_precision
# Out:
# 0

# %%
#Experiment: SE0
from  searchengine import *
from pre_rec import precision_recall
import codecs

experiment = "N,T"
SE = SearchEngine("./Poems","index_whoosh")
SE.Create_Index(experiment)

result = SE.Search("")
# Out:
# 6808
# 0.0
# normalize
# tokenize
# 0.000146886016451
# normalize
# tokenize
# 0.000293772032902
# normalize
# tokenize
# 0.000440658049354
# normalize
# tokenize
# 0.000587544065805
# normalize
# tokenize
# 0.000734430082256
# normalize
# tokenize
# 0.000881316098707
# normalize
# tokenize
# 0.00102820211516
# normalize
# tokenize
# 0.00117508813161
# normalize
# tokenize
# 0.00132197414806
# normalize
# tokenize
# 0.00146886016451
# normalize
# tokenize
# 0.00161574618096
# normalize
# tokenize
# 0.00176263219741
# normalize
# tokenize
# 0.00190951821387
# normalize
# tokenize
# 0.00205640423032
# normalize
# tokenize
# 0.00220329024677
# normalize
# tokenize
# 0.00235017626322
# normalize
# tokenize
# 0.00249706227967
# normalize
# tokenize
# 0.00264394829612
# normalize
# tokenize
# 0.00279083431257
# normalize
# tokenize
# 0.00293772032902
# normalize
# tokenize
# 0.00308460634548
# normalize
# tokenize
# 0.00323149236193
# normalize
# tokenize
# 0.00337837837838
# normalize
# tokenize
# 0.00352526439483
# normalize
# tokenize
# 0.00367215041128
# normalize
# tokenize
# 0.00381903642773
# normalize
# tokenize
# 0.00396592244418
# normalize
# tokenize
# 0.00411280846063
# normalize
# tokenize
# 0.00425969447709
# normalize
# tokenize
# 0.00440658049354
# normalize
# tokenize
# 0.00455346650999
# normalize
# tokenize
# 0.00470035252644
# normalize
# tokenize
# 0.00484723854289
# normalize
# tokenize
# 0.00499412455934
# normalize
# tokenize
# 0.00514101057579
# normalize
# tokenize
# 0.00528789659224
# normalize
# tokenize
# 0.0054347826087
# normalize
# tokenize
# 0.00558166862515
# normalize
# tokenize
# 0.0057285546416
# normalize
# tokenize
# 0.00587544065805
# normalize
# tokenize
# 0.0060223266745
# normalize
# tokenize
# 0.00616921269095
# normalize
# tokenize
# 0.0063160987074
# normalize
# tokenize
# 0.00646298472385
# normalize
# tokenize
# 0.00660987074031
# normalize
# tokenize
# 0.00675675675676
# normalize
# tokenize
# 0.00690364277321
# normalize
# tokenize
# 0.00705052878966
# normalize
# tokenize
# 0.00719741480611
# normalize
# tokenize
# 0.00734430082256
# normalize
# tokenize
# 0.00749118683901
# normalize
# tokenize
# 0.00763807285546
# normalize
# tokenize
# 0.00778495887192
# normalize
# tokenize
# 0.00793184488837
# normalize
# tokenize
# 0.00807873090482
# normalize
# tokenize
# 0.00822561692127
# normalize
# tokenize
# 0.00837250293772
# normalize
# tokenize
# 0.00851938895417
# normalize
# tokenize
# 0.00866627497062
# normalize
# tokenize
# 0.00881316098707
# normalize
# tokenize
# 0.00896004700353
# normalize
# tokenize
# 0.00910693301998
# normalize
# tokenize
# 0.00925381903643
# normalize
# tokenize
# 0.00940070505288
# normalize
# tokenize
# 0.00954759106933
# normalize
# tokenize
# 0.00969447708578
# normalize
# tokenize
# 0.00984136310223
# normalize
# tokenize
# 0.00998824911868
# normalize
# tokenize
# 0.0101351351351
# normalize
# tokenize
# 0.0102820211516
# normalize
# tokenize
# 0.010428907168
# normalize
# tokenize
# 0.0105757931845
# normalize
# tokenize
# 0.0107226792009
# normalize
# tokenize
# 0.0108695652174
# normalize
# tokenize
# 0.0110164512338
# normalize
# tokenize
# 0.0111633372503
# normalize
# tokenize
# 0.0113102232667
# normalize
# tokenize
# 0.0114571092832
# normalize
# tokenize
# 0.0116039952996
# normalize
# tokenize
# 0.0117508813161
# normalize
# tokenize
# 0.0118977673325
# normalize
# tokenize
# 0.012044653349
# normalize
# tokenize
# 0.0121915393655
# normalize
# tokenize
# 0.0123384253819
# normalize
# tokenize
# 0.0124853113984
# normalize
# tokenize
# 0.0126321974148
# normalize
# tokenize
# 0.0127790834313
# normalize
# tokenize
# 0.0129259694477
# normalize
# tokenize
# 0.0130728554642
# normalize
# tokenize
# 0.0132197414806
# normalize
# tokenize
# 0.0133666274971
# normalize
# tokenize
# 0.0135135135135
# normalize
# tokenize
# 0.01366039953
# normalize
# tokenize
# 0.0138072855464
# normalize
# tokenize
# 0.0139541715629
# normalize
# tokenize
# 0.0141010575793
# normalize
# tokenize
# 0.0142479435958
# normalize
# tokenize
# 0.0143948296122
# normalize
# tokenize
# 0.0145417156287
# normalize
# tokenize
# 0.0146886016451
# normalize
# tokenize
# 0.0148354876616
# normalize
# tokenize
# 0.014982373678
# normalize
# tokenize
# 0.0151292596945
# normalize
# tokenize
# 0.0152761457109
# normalize
# tokenize
# 0.0154230317274
# normalize
# tokenize
# 0.0155699177438
# normalize
# tokenize
# 0.0157168037603
# normalize
# tokenize
# 0.0158636897767
# normalize
# tokenize
# 0.0160105757932
# normalize
# tokenize
# 0.0161574618096
# normalize
# tokenize
# 0.0163043478261
# normalize
# tokenize
# 0.0164512338425
# normalize
# tokenize
# 0.016598119859
# normalize
# tokenize
# 0.0167450058754
# normalize
# tokenize
# 0.0168918918919
# normalize
# tokenize
# 0.0170387779083
# normalize
# tokenize
# 0.0171856639248
# normalize
# tokenize
# 0.0173325499412
# normalize
# tokenize
# 0.0174794359577
# normalize
# tokenize
# 0.0176263219741
# normalize
# tokenize
# 0.0177732079906
# normalize
# tokenize
# 0.0179200940071
# normalize
# tokenize
# 0.0180669800235
# normalize
# tokenize
# 0.01821386604
# normalize
# tokenize
# 0.0183607520564
# normalize
# tokenize
# 0.0185076380729
# normalize
# tokenize
# 0.0186545240893
# normalize
# tokenize
# 0.0188014101058
# normalize
# tokenize
# 0.0189482961222
# normalize
# tokenize
# 0.0190951821387
# normalize
# tokenize
# 0.0192420681551
# normalize
# tokenize
# 0.0193889541716
# normalize
# tokenize
# 0.019535840188
# normalize
# tokenize
# 0.0196827262045
# normalize
# tokenize
# 0.0198296122209
# normalize
# tokenize
# 0.0199764982374
# normalize
# tokenize
# 0.0201233842538
# normalize
# tokenize
# 0.0202702702703
# normalize
# tokenize
# 0.0204171562867
# normalize
# tokenize
# 0.0205640423032
# normalize
# tokenize
# 0.0207109283196
# normalize
# tokenize
# 0.0208578143361
# normalize
# tokenize
# 0.0210047003525
# normalize
# tokenize
# 0.021151586369
# normalize
# tokenize
# 0.0212984723854
# normalize
# tokenize
# 0.0214453584019
# normalize
# tokenize
# 0.0215922444183
# normalize
# tokenize
# 0.0217391304348
# normalize
# tokenize
# 0.0218860164512
# normalize
# tokenize
# 0.0220329024677
# normalize
# tokenize
# 0.0221797884841
# normalize
# tokenize
# 0.0223266745006
# normalize
# tokenize
# 0.022473560517
# normalize
# tokenize
# 0.0226204465335
# normalize
# tokenize
# 0.0227673325499
# normalize
# tokenize
# 0.0229142185664
# normalize
# tokenize
# 0.0230611045828
# normalize
# tokenize
# 0.0232079905993
# normalize
# tokenize
# 0.0233548766157
# normalize
# tokenize
# 0.0235017626322
# normalize
# tokenize
# 0.0236486486486
# normalize
# tokenize
# 0.0237955346651
# normalize
# tokenize
# 0.0239424206816
# normalize
# tokenize
# 0.024089306698
# normalize
# tokenize
# 0.0242361927145
# normalize
# tokenize
# 0.0243830787309
# normalize
# tokenize
# 0.0245299647474
# normalize
# tokenize
# 0.0246768507638
# normalize
# tokenize
# 0.0248237367803
# normalize
# tokenize
# 0.0249706227967
# normalize
# tokenize
# 0.0251175088132
# normalize
# tokenize
# 0.0252643948296
# normalize
# tokenize
# 0.0254112808461
# normalize
# tokenize
# 0.0255581668625
# normalize
# tokenize
# 0.025705052879
# normalize
# tokenize
# 0.0258519388954
# normalize
# tokenize
# 0.0259988249119
# normalize
# tokenize
# 0.0261457109283
# normalize
# tokenize
# 0.0262925969448
# normalize
# tokenize
# 0.0264394829612
# normalize
# tokenize
# 0.0265863689777
# normalize
# tokenize
# 0.0267332549941
# normalize
# tokenize
# 0.0268801410106
# normalize
# tokenize
# 0.027027027027
# normalize
# tokenize
# 0.0271739130435
# normalize
# tokenize
# 0.0273207990599
# normalize
# tokenize
# 0.0274676850764
# normalize
# tokenize
# 0.0276145710928
# normalize
# tokenize
# 0.0277614571093
# normalize
# tokenize
# 0.0279083431257
# normalize
# tokenize
# 0.0280552291422
# normalize
# tokenize
# 0.0282021151586
# normalize
# tokenize
# 0.0283490011751
# normalize
# tokenize
# 0.0284958871915
# normalize
# tokenize
# 0.028642773208
# normalize
# tokenize
# 0.0287896592244
# normalize
# tokenize
# 0.0289365452409
# normalize
# tokenize
# 0.0290834312573
# normalize
# tokenize
# 0.0292303172738
# normalize
# tokenize
# 0.0293772032902
# normalize
# tokenize
# 0.0295240893067
# normalize
# tokenize
# 0.0296709753231
# normalize
# tokenize
# 0.0298178613396
# normalize
# tokenize
# 0.0299647473561
# normalize
# tokenize
# 0.0301116333725
# normalize
# tokenize
# 0.030258519389
# normalize
# tokenize
# 0.0304054054054
# normalize
# tokenize
# 0.0305522914219
# normalize
# tokenize
# 0.0306991774383
# normalize
# tokenize
# 0.0308460634548
# normalize
# tokenize
# 0.0309929494712
# normalize
# tokenize
# 0.0311398354877
# normalize
# tokenize
# 0.0312867215041
# normalize
# tokenize
# 0.0314336075206
# normalize
# tokenize
# 0.031580493537
# normalize
# tokenize
# 0.0317273795535
# normalize
# tokenize
# 0.0318742655699
# normalize
# tokenize
# 0.0320211515864
# normalize
# tokenize
# 0.0321680376028
# normalize
# tokenize
# 0.0323149236193
# normalize
# tokenize
# 0.0324618096357
# normalize
# tokenize
# 0.0326086956522
# normalize
# tokenize
# 0.0327555816686
# normalize
# tokenize
# 0.0329024676851
# normalize
# tokenize
# 0.0330493537015
# normalize
# tokenize
# 0.033196239718
# normalize
# tokenize
# 0.0333431257344
# normalize
# tokenize
# 0.0334900117509
# normalize
# tokenize
# 0.0336368977673
# normalize
# tokenize
# 0.0337837837838
# normalize
# tokenize
# 0.0339306698002
# normalize
# tokenize
# 0.0340775558167
# normalize
# tokenize
# 0.0342244418331
# normalize
# tokenize
# 0.0343713278496
# normalize
# tokenize
# 0.034518213866
# normalize
# tokenize
# 0.0346650998825
# normalize
# tokenize
# 0.0348119858989
# normalize
# tokenize
# 0.0349588719154
# normalize
# tokenize
# 0.0351057579318
# normalize
# tokenize
# 0.0352526439483
# normalize
# tokenize
# 0.0353995299647
# normalize
# tokenize
# 0.0355464159812
# normalize
# tokenize
# 0.0356933019976
# normalize
# tokenize
# 0.0358401880141
# normalize
# tokenize
# 0.0359870740306
# normalize
# tokenize
# 0.036133960047
# normalize
# tokenize
# 0.0362808460635
# normalize
# tokenize
# 0.0364277320799
# normalize
# tokenize
# 0.0365746180964
# normalize
# tokenize
# 0.0367215041128
# normalize
# tokenize
# 0.0368683901293
# normalize
# tokenize
# 0.0370152761457
# normalize
# tokenize
# 0.0371621621622
# normalize
# tokenize
# 0.0373090481786
# normalize
# tokenize
# 0.0374559341951
# normalize
# tokenize
# 0.0376028202115
# normalize
# tokenize
# 0.037749706228
# normalize
# tokenize
# 0.0378965922444
# normalize
# tokenize
# 0.0380434782609
# normalize
# tokenize
# 0.0381903642773
# normalize
# tokenize
# 0.0383372502938
# normalize
# tokenize
# 0.0384841363102
# normalize
# tokenize
# 0.0386310223267
# normalize
# tokenize
# 0.0387779083431
# normalize
# tokenize
# 0.0389247943596
# normalize
# tokenize
# 0.039071680376
# normalize
# tokenize
# 0.0392185663925
# normalize
# tokenize
# 0.0393654524089
# normalize
# tokenize
# 0.0395123384254
# normalize
# tokenize
# 0.0396592244418
# normalize
# tokenize
# 0.0398061104583
# normalize
# tokenize
# 0.0399529964747
# normalize
# tokenize
# 0.0400998824912
# normalize
# tokenize
# 0.0402467685076
# normalize
# tokenize
# 0.0403936545241
# normalize
# tokenize
# 0.0405405405405
# normalize
# tokenize
# 0.040687426557
# normalize
# tokenize
# 0.0408343125734
# normalize
# tokenize
# 0.0409811985899
# normalize
# tokenize
# 0.0411280846063
# normalize
# tokenize
# 0.0412749706228
# normalize
# tokenize
# 0.0414218566392
# normalize
# tokenize
# 0.0415687426557
# normalize
# tokenize
# 0.0417156286722
# normalize
# tokenize
# 0.0418625146886
# normalize
# tokenize
# 0.0420094007051
# normalize
# tokenize
# 0.0421562867215
# normalize
# tokenize
# 0.042303172738
# normalize
# tokenize
# 0.0424500587544
# normalize
# tokenize
# 0.0425969447709
# normalize
# tokenize
# 0.0427438307873
# normalize
# tokenize
# 0.0428907168038
# normalize
# tokenize
# 0.0430376028202
# normalize
# tokenize
# 0.0431844888367
# normalize
# tokenize
# 0.0433313748531
# normalize
# tokenize
# 0.0434782608696
# normalize
# tokenize
# 0.043625146886
# normalize
# tokenize
# 0.0437720329025
# normalize
# tokenize
# 0.0439189189189
# normalize
# tokenize
# 0.0440658049354
# normalize
# tokenize
# 0.0442126909518
# normalize
# tokenize
# 0.0443595769683
# normalize
# tokenize
# 0.0445064629847
# normalize
# tokenize
# 0.0446533490012
# normalize
# tokenize
# 0.0448002350176
# normalize
# tokenize
# 0.0449471210341
# normalize
# tokenize
# 0.0450940070505
# normalize
# tokenize
# 0.045240893067
# normalize
# tokenize
# 0.0453877790834
# normalize
# tokenize
# 0.0455346650999
# normalize
# tokenize
# 0.0456815511163
# normalize
# tokenize
# 0.0458284371328
# normalize
# tokenize
# 0.0459753231492
# normalize
# tokenize
# 0.0461222091657
# normalize
# tokenize
# 0.0462690951821
# normalize
# tokenize
# 0.0464159811986
# normalize
# tokenize
# 0.046562867215
# normalize
# tokenize
# 0.0467097532315
# normalize
# tokenize
# 0.0468566392479
# normalize
# tokenize
# 0.0470035252644
# normalize
# tokenize
# 0.0471504112808
# normalize
# tokenize
# 0.0472972972973
# normalize
# tokenize
# 0.0474441833137
# normalize
# tokenize
# 0.0475910693302
# normalize
# tokenize
# 0.0477379553467
# normalize
# tokenize
# 0.0478848413631
# normalize
# tokenize
# 0.0480317273796
# normalize
# tokenize
# 0.048178613396
# normalize
# tokenize
# 0.0483254994125
# normalize
# tokenize
# 0.0484723854289
# normalize
# tokenize
# 0.0486192714454
# normalize
# tokenize
# 0.0487661574618
# normalize
# tokenize
# 0.0489130434783
# normalize
# tokenize
# 0.0490599294947
# normalize
# tokenize
# 0.0492068155112
# normalize
# tokenize
# 0.0493537015276
# normalize
# tokenize
# 0.0495005875441
# normalize
# tokenize
# 0.0496474735605
# normalize
# tokenize
# 0.049794359577
# normalize
# tokenize
# 0.0499412455934
# normalize
# tokenize
# 0.0500881316099
# normalize
# tokenize
# 0.0502350176263
# normalize
# tokenize
# 0.0503819036428
# normalize
# tokenize
# 0.0505287896592
# normalize
# tokenize
# 0.0506756756757
# normalize
# tokenize
# 0.0508225616921
# normalize
# tokenize
# 0.0509694477086
# normalize
# tokenize
# 0.051116333725
# normalize
# tokenize
# 0.0512632197415
# normalize
# tokenize
# 0.0514101057579
# normalize
# tokenize
# 0.0515569917744
# normalize
# tokenize
# 0.0517038777908
# normalize
# tokenize
# 0.0518507638073
# normalize
# tokenize
# 0.0519976498237
# normalize
# tokenize
# 0.0521445358402
# normalize
# tokenize
# 0.0522914218566
# normalize
# tokenize
# 0.0524383078731
# normalize
# tokenize
# 0.0525851938895
# normalize
# tokenize
# 0.052732079906
# normalize
# tokenize
# 0.0528789659224
# normalize
# tokenize
# 0.0530258519389
# normalize
# tokenize
# 0.0531727379553
# normalize
# tokenize
# 0.0533196239718
# normalize
# tokenize
# 0.0534665099882
# normalize
# tokenize
# 0.0536133960047
# normalize
# tokenize
# 0.0537602820212
# normalize
# tokenize
# 0.0539071680376
# normalize
# tokenize
# 0.0540540540541
# normalize
# tokenize
# 0.0542009400705
# normalize
# tokenize
# 0.054347826087
# normalize
# tokenize
# 0.0544947121034
# normalize
# tokenize
# 0.0546415981199
# normalize
# tokenize
# 0.0547884841363
# normalize
# tokenize
# 0.0549353701528
# normalize
# tokenize
# 0.0550822561692
# normalize
# tokenize
# 0.0552291421857
# normalize
# tokenize
# 0.0553760282021
# normalize
# tokenize
# 0.0555229142186
# normalize
# tokenize
# 0.055669800235
# normalize
# tokenize
# 0.0558166862515
# normalize
# tokenize
# 0.0559635722679
# normalize
# tokenize
# 0.0561104582844
# normalize
# tokenize
# 0.0562573443008
# normalize
# tokenize
# 0.0564042303173
# normalize
# tokenize
# 0.0565511163337
# normalize
# tokenize
# 0.0566980023502
# normalize
# tokenize
# 0.0568448883666
# normalize
# tokenize
# 0.0569917743831
# normalize
# tokenize
# 0.0571386603995
# normalize
# tokenize
# 0.057285546416
# normalize
# tokenize
# 0.0574324324324
# normalize
# tokenize
# 0.0575793184489
# normalize
# tokenize
# 0.0577262044653
# normalize
# tokenize
# 0.0578730904818
# normalize
# tokenize
# 0.0580199764982
# normalize
# tokenize
# 0.0581668625147
# normalize
# tokenize
# 0.0583137485311
# normalize
# tokenize
# 0.0584606345476
# normalize
# tokenize
# 0.058607520564
# normalize
# tokenize
# 0.0587544065805
# normalize
# tokenize
# 0.0589012925969
# normalize
# tokenize
# 0.0590481786134
# normalize
# tokenize
# 0.0591950646298
# normalize
# tokenize
# 0.0593419506463
# normalize
# tokenize
# 0.0594888366627
# normalize
# tokenize
# 0.0596357226792
# normalize
# tokenize
# 0.0597826086957
# normalize
# tokenize
# 0.0599294947121
# normalize
# tokenize
# 0.0600763807286
# normalize
# tokenize
# 0.060223266745
# normalize
# tokenize
# 0.0603701527615
# normalize
# tokenize
# 0.0605170387779
# normalize
# tokenize
# 0.0606639247944
# normalize
# tokenize
# 0.0608108108108
# normalize
# tokenize
# 0.0609576968273
# normalize
# tokenize
# 0.0611045828437
# normalize
# tokenize
# 0.0612514688602
# normalize
# tokenize
# 0.0613983548766
# normalize
# tokenize
# 0.0615452408931
# normalize
# tokenize
# 0.0616921269095
# normalize
# tokenize
# 0.061839012926
# normalize
# tokenize
# 0.0619858989424
# normalize
# tokenize
# 0.0621327849589
# normalize
# tokenize
# 0.0622796709753
# normalize
# tokenize
# 0.0624265569918
# normalize
# tokenize
# 0.0625734430082
# normalize
# tokenize
# 0.0627203290247
# normalize
# tokenize
# 0.0628672150411
# normalize
# tokenize
# 0.0630141010576
# normalize
# tokenize
# 0.063160987074
# normalize
# tokenize
# 0.0633078730905
# normalize
# tokenize
# 0.0634547591069
# normalize
# tokenize
# 0.0636016451234
# normalize
# tokenize
# 0.0637485311398
# normalize
# tokenize
# 0.0638954171563
# normalize
# tokenize
# 0.0640423031727
# normalize
# tokenize
# 0.0641891891892
# normalize
# tokenize
# 0.0643360752056
# normalize
# tokenize
# 0.0644829612221
# normalize
# tokenize
# 0.0646298472385
# normalize
# tokenize
# 0.064776733255
# normalize
# tokenize
# 0.0649236192714
# normalize
# tokenize
# 0.0650705052879
# normalize
# tokenize
# 0.0652173913043
# normalize
# tokenize
# 0.0653642773208
# normalize
# tokenize
# 0.0655111633373
# normalize
# tokenize
# 0.0656580493537
# normalize
# tokenize
# 0.0658049353702
# normalize
# tokenize
# 0.0659518213866
# normalize
# tokenize
# 0.0660987074031
# normalize
# tokenize
# 0.0662455934195
# normalize
# tokenize
# 0.066392479436
# normalize
# tokenize
# 0.0665393654524
# normalize
# tokenize
# 0.0666862514689
# normalize
# tokenize
# 0.0668331374853
# normalize
# tokenize
# 0.0669800235018
# normalize
# tokenize
# 0.0671269095182
# normalize
# tokenize
# 0.0672737955347
# normalize
# tokenize
# 0.0674206815511
# normalize
# tokenize
# 0.0675675675676
# normalize
# tokenize
# 0.067714453584
# normalize
# tokenize
# 0.0678613396005
# normalize
# tokenize
# 0.0680082256169
# normalize
# tokenize
# 0.0681551116334
# normalize
# tokenize
# 0.0683019976498
# normalize
# tokenize
# 0.0684488836663
# normalize
# tokenize
# 0.0685957696827
# normalize
# tokenize
# 0.0687426556992
# normalize
# tokenize
# 0.0688895417156
# normalize
# tokenize
# 0.0690364277321
# normalize
# tokenize
# 0.0691833137485
# normalize
# tokenize
# 0.069330199765
# normalize
# tokenize
# 0.0694770857814
# normalize
# tokenize
# 0.0696239717979
# normalize
# tokenize
# 0.0697708578143
# normalize
# tokenize
# 0.0699177438308
# normalize
# tokenize
# 0.0700646298472
# normalize
# tokenize
# 0.0702115158637
# normalize
# tokenize
# 0.0703584018801
# normalize
# tokenize
# 0.0705052878966
# normalize
# tokenize
# 0.070652173913
# normalize
# tokenize
# 0.0707990599295
# normalize
# tokenize
# 0.0709459459459
# normalize
# tokenize
# 0.0710928319624
# normalize
# tokenize
# 0.0712397179788
# normalize
# tokenize
# 0.0713866039953
# normalize
# tokenize
# 0.0715334900118
# normalize
# tokenize
# 0.0716803760282
# normalize
# tokenize
# 0.0718272620447
# normalize
# tokenize
# 0.0719741480611
# normalize
# tokenize
# 0.0721210340776
# normalize
# tokenize
# 0.072267920094
# normalize
# tokenize
# 0.0724148061105
# normalize
# tokenize
# 0.0725616921269
# normalize
# tokenize
# 0.0727085781434
# normalize
# tokenize
# 0.0728554641598
# normalize
# tokenize
# 0.0730023501763
# normalize
# tokenize
# 0.0731492361927
# normalize
# tokenize
# 0.0732961222092
# normalize
# tokenize
# 0.0734430082256
# normalize
# tokenize
# 0.0735898942421
# normalize
# tokenize
# 0.0737367802585
# normalize
# tokenize
# 0.073883666275
# normalize
# tokenize
# 0.0740305522914
# normalize
# tokenize
# 0.0741774383079
# normalize
# tokenize
# 0.0743243243243
# normalize
# tokenize
# 0.0744712103408
# normalize
# tokenize
# 0.0746180963572
# normalize
# tokenize
# 0.0747649823737
# normalize
# tokenize
# 0.0749118683901
# normalize
# tokenize
# 0.0750587544066
# normalize
# tokenize
# 0.075205640423
# normalize
# tokenize
# 0.0753525264395
# normalize
# tokenize
# 0.0754994124559
# normalize
# tokenize
# 0.0756462984724
# normalize
# tokenize
# 0.0757931844888
# normalize
# tokenize
# 0.0759400705053
# normalize
# tokenize
# 0.0760869565217
# normalize
# tokenize
# 0.0762338425382
# normalize
# tokenize
# 0.0763807285546
# normalize
# tokenize
# 0.0765276145711
# normalize
# tokenize
# 0.0766745005875
# normalize
# tokenize
# 0.076821386604
# normalize
# tokenize
# 0.0769682726204
# normalize
# tokenize
# 0.0771151586369
# normalize
# tokenize
# 0.0772620446533
# normalize
# tokenize
# 0.0774089306698
# normalize
# tokenize
# 0.0775558166863
# normalize
# tokenize
# 0.0777027027027
# normalize
# tokenize
# 0.0778495887192
# normalize
# tokenize
# 0.0779964747356
# normalize
# tokenize
# 0.0781433607521
# normalize
# tokenize
# 0.0782902467685
# normalize
# tokenize
# 0.078437132785
# normalize
# tokenize
# 0.0785840188014
# normalize
# tokenize
# 0.0787309048179
# normalize
# tokenize
# 0.0788777908343
# normalize
# tokenize
# 0.0790246768508
# normalize
# tokenize
# 0.0791715628672
# normalize
# tokenize
# 0.0793184488837
# normalize
# tokenize
# 0.0794653349001
# normalize
# tokenize
# 0.0796122209166
# normalize
# tokenize
# 0.079759106933
# normalize
# tokenize
# 0.0799059929495
# normalize
# tokenize
# 0.0800528789659
# normalize
# tokenize
# 0.0801997649824
# normalize
# tokenize
# 0.0803466509988
# normalize
# tokenize
# 0.0804935370153
# normalize
# tokenize
# 0.0806404230317
# normalize
# tokenize
# 0.0807873090482
# normalize
# tokenize
# 0.0809341950646
# normalize
# tokenize
# 0.0810810810811
# normalize
# tokenize
# 0.0812279670975
# normalize
# tokenize
# 0.081374853114
# normalize
# tokenize
# 0.0815217391304
# normalize
# tokenize
# 0.0816686251469
# normalize
# tokenize
# 0.0818155111633
# normalize
# tokenize
# 0.0819623971798
# normalize
# tokenize
# 0.0821092831962
# normalize
# tokenize
# 0.0822561692127
# normalize
# tokenize
# 0.0824030552291
# normalize
# tokenize
# 0.0825499412456
# normalize
# tokenize
# 0.082696827262
# normalize
# tokenize
# 0.0828437132785
# normalize
# tokenize
# 0.0829905992949
# normalize
# tokenize
# 0.0831374853114
# normalize
# tokenize
# 0.0832843713278
# normalize
# tokenize
# 0.0834312573443
# normalize
# tokenize
# 0.0835781433608
# normalize
# tokenize
# 0.0837250293772
# normalize
# tokenize
# 0.0838719153937
# normalize
# tokenize
# 0.0840188014101
# normalize
# tokenize
# 0.0841656874266
# normalize
# tokenize
# 0.084312573443
# normalize
# tokenize
# 0.0844594594595
# normalize
# tokenize
# 0.0846063454759
# normalize
# tokenize
# 0.0847532314924
# normalize
# tokenize
# 0.0849001175088
# normalize
# tokenize
# 0.0850470035253
# normalize
# tokenize
# 0.0851938895417
# normalize
# tokenize
# 0.0853407755582
# normalize
# tokenize
# 0.0854876615746
# normalize
# tokenize
# 0.0856345475911
# normalize
# tokenize
# 0.0857814336075
# normalize
# tokenize
# 0.085928319624
# normalize
# tokenize
# 0.0860752056404
# normalize
# tokenize
# 0.0862220916569
# normalize
# tokenize
# 0.0863689776733
# normalize
# tokenize
# 0.0865158636898
# normalize
# tokenize
# 0.0866627497062
# normalize
# tokenize
# 0.0868096357227
# normalize
# tokenize
# 0.0869565217391
# normalize
# tokenize
# 0.0871034077556
# normalize
# tokenize
# 0.087250293772
# normalize
# tokenize
# 0.0873971797885
# normalize
# tokenize
# 0.0875440658049
# normalize
# tokenize
# 0.0876909518214
# normalize
# tokenize
# 0.0878378378378
# normalize
# tokenize
# 0.0879847238543
# normalize
# tokenize
# 0.0881316098707
# normalize
# tokenize
# 0.0882784958872
# normalize
# tokenize
# 0.0884253819036
# normalize
# tokenize
# 0.0885722679201
# normalize
# tokenize
# 0.0887191539365
# normalize
# tokenize
# 0.088866039953
# normalize
# tokenize
# 0.0890129259694
# normalize
# tokenize
# 0.0891598119859
# normalize
# tokenize
# 0.0893066980024
# normalize
# tokenize
# 0.0894535840188
# normalize
# tokenize
# 0.0896004700353
# normalize
# tokenize
# 0.0897473560517
# normalize
# tokenize
# 0.0898942420682
# normalize
# tokenize
# 0.0900411280846
# normalize
# tokenize
# 0.0901880141011
# normalize
# tokenize
# 0.0903349001175
# normalize
# tokenize
# 0.090481786134
# normalize
# tokenize
# 0.0906286721504
# normalize
# tokenize
# 0.0907755581669
# normalize
# tokenize
# 0.0909224441833
# normalize
# tokenize
# 0.0910693301998
# normalize
# tokenize
# 0.0912162162162
# normalize
# tokenize
# 0.0913631022327
# normalize
# tokenize
# 0.0915099882491
# normalize
# tokenize
# 0.0916568742656
# normalize
# tokenize
# 0.091803760282
# normalize
# tokenize
# 0.0919506462985
# normalize
# tokenize
# 0.0920975323149
# normalize
# tokenize
# 0.0922444183314
# normalize
# tokenize
# 0.0923913043478
# normalize
# tokenize
# 0.0925381903643
# normalize
# tokenize
# 0.0926850763807
# normalize
# tokenize
# 0.0928319623972
# normalize
# tokenize
# 0.0929788484136
# normalize
# tokenize
# 0.0931257344301
# normalize
# tokenize
# 0.0932726204465
# normalize
# tokenize
# 0.093419506463
# normalize
# tokenize
# 0.0935663924794
# normalize
# tokenize
# 0.0937132784959
# normalize
# tokenize
# 0.0938601645123
# normalize
# tokenize
# 0.0940070505288
# normalize
# tokenize
# 0.0941539365452
# normalize
# tokenize
# 0.0943008225617
# normalize
# tokenize
# 0.0944477085781
# normalize
# tokenize
# 0.0945945945946
# normalize
# tokenize
# 0.094741480611
# normalize
# tokenize
# 0.0948883666275
# normalize
# tokenize
# 0.0950352526439
# normalize
# tokenize
# 0.0951821386604
# normalize
# tokenize
# 0.0953290246769
# normalize
# tokenize
# 0.0954759106933
# normalize
# tokenize
# 0.0956227967098
# normalize
# tokenize
# 0.0957696827262
# normalize
# tokenize
# 0.0959165687427
# normalize
# tokenize
# 0.0960634547591
# normalize
# tokenize
# 0.0962103407756
# normalize
# tokenize
# 0.096357226792
# normalize
# tokenize
# 0.0965041128085
# normalize
# tokenize
# 0.0966509988249
# normalize
# tokenize
# 0.0967978848414
# normalize
# tokenize
# 0.0969447708578
# normalize
# tokenize
# 0.0970916568743
# normalize
# tokenize
# 0.0972385428907
# normalize
# tokenize
# 0.0973854289072
# normalize
# tokenize
# 0.0975323149236
# normalize
# tokenize
# 0.0976792009401
# normalize
# tokenize
# 0.0978260869565
# normalize
# tokenize
# 0.097972972973
# normalize
# tokenize
# 0.0981198589894
# normalize
# tokenize
# 0.0982667450059
# normalize
# tokenize
# 0.0984136310223
# normalize
# tokenize
# 0.0985605170388
# normalize
# tokenize
# 0.0987074030552
# normalize
# tokenize
# 0.0988542890717
# normalize
# tokenize
# 0.0990011750881
# normalize
# tokenize
# 0.0991480611046
# normalize
# tokenize
# 0.099294947121
# normalize
# tokenize
# 0.0994418331375
# normalize
# tokenize
# 0.0995887191539
# normalize
# tokenize
# 0.0997356051704
# normalize
# tokenize
# 0.0998824911868
# normalize
# tokenize
# 0.100029377203
# normalize
# tokenize
# 0.10017626322
# normalize
# tokenize
# 0.100323149236
# normalize
# tokenize
# 0.100470035253
# normalize
# tokenize
# 0.100616921269
# normalize
# tokenize
# 0.100763807286
# normalize
# tokenize
# 0.100910693302
# normalize
# tokenize
# 0.101057579318
# normalize
# tokenize
# 0.101204465335
# normalize
# tokenize
# 0.101351351351
# normalize
# tokenize
# 0.101498237368
# normalize
# tokenize
# 0.101645123384
# normalize
# tokenize
# 0.101792009401
# normalize
# tokenize
# 0.101938895417
# normalize
# tokenize
# 0.102085781434
# normalize
# tokenize
# 0.10223266745
# normalize
# tokenize
# 0.102379553467
# normalize
# tokenize
# 0.102526439483
# normalize
# tokenize
# 0.102673325499
# normalize
# tokenize
# 0.102820211516
# normalize
# tokenize
# 0.102967097532
# normalize
# tokenize
# 0.103113983549
# normalize
# tokenize
# 0.103260869565
# normalize
# tokenize
# 0.103407755582
# normalize
# tokenize
# 0.103554641598
# normalize
# tokenize
# 0.103701527615
# normalize
# tokenize
# 0.103848413631
# normalize
# tokenize
# 0.103995299647
# normalize
# tokenize
# 0.104142185664
# normalize
# tokenize
# 0.10428907168
# normalize
# tokenize
# 0.104435957697
# normalize
# tokenize
# 0.104582843713
# normalize
# tokenize
# 0.10472972973
# normalize
# tokenize
# 0.104876615746
# normalize
# tokenize
# 0.105023501763
# normalize
# tokenize
# 0.105170387779
# normalize
# tokenize
# 0.105317273796
# normalize
# tokenize
# 0.105464159812
# normalize
# tokenize
# 0.105611045828
# normalize
# tokenize
# 0.105757931845
# normalize
# tokenize
# 0.105904817861
# normalize
# tokenize
# 0.106051703878
# normalize
# tokenize
# 0.106198589894
# normalize
# tokenize
# 0.106345475911
# normalize
# tokenize
# 0.106492361927
# normalize
# tokenize
# 0.106639247944
# normalize
# tokenize
# 0.10678613396
# normalize
# tokenize
# 0.106933019976
# normalize
# tokenize
# 0.107079905993
# normalize
# tokenize
# 0.107226792009
# normalize
# tokenize
# 0.107373678026
# normalize
# tokenize
# 0.107520564042
# normalize
# tokenize
# 0.107667450059
# normalize
# tokenize
# 0.107814336075
# normalize
# tokenize
# 0.107961222092
# normalize
# tokenize
# 0.108108108108
# normalize
# tokenize
# 0.108254994125
# normalize
# tokenize
# 0.108401880141
# normalize
# tokenize
# 0.108548766157
# normalize
# tokenize
# 0.108695652174
# normalize
# tokenize
# 0.10884253819
# normalize
# tokenize
# 0.108989424207
# normalize
# tokenize
# 0.109136310223
# normalize
# tokenize
# 0.10928319624
# normalize
# tokenize
# 0.109430082256
# normalize
# tokenize
# 0.109576968273
# normalize
# tokenize
# 0.109723854289
# normalize
# tokenize
# 0.109870740306
# normalize
# tokenize
# 0.110017626322
# normalize
# tokenize
# 0.110164512338
# normalize
# tokenize
# 0.110311398355
# normalize
# tokenize
# 0.110458284371
# normalize
# tokenize
# 0.110605170388
# normalize
# tokenize
# 0.110752056404
# normalize
# tokenize
# 0.110898942421
# normalize
# tokenize
# 0.111045828437
# normalize
# tokenize
# 0.111192714454
# normalize
# tokenize
# 0.11133960047
# normalize
# tokenize
# 0.111486486486
# normalize
# tokenize
# 0.111633372503
# normalize
# tokenize
# 0.111780258519
# normalize
# tokenize
# 0.111927144536
# normalize
# tokenize
# 0.112074030552
# normalize
# tokenize
# 0.112220916569
# normalize
# tokenize
# 0.112367802585
# normalize
# tokenize
# 0.112514688602
# normalize
# tokenize
# 0.112661574618
# normalize
# tokenize
# 0.112808460635
# normalize
# tokenize
# 0.112955346651
# normalize
# tokenize
# 0.113102232667
# normalize
# tokenize
# 0.113249118684
# normalize
# tokenize
# 0.1133960047
# normalize
# tokenize
# 0.113542890717
# normalize
# tokenize
# 0.113689776733
# normalize
# tokenize
# 0.11383666275
# normalize
# tokenize
# 0.113983548766
# normalize
# tokenize
# 0.114130434783
# normalize
# tokenize
# 0.114277320799
# normalize
# tokenize
# 0.114424206816
# normalize
# tokenize
# 0.114571092832
# normalize
# tokenize
# 0.114717978848
# normalize
# tokenize
# 0.114864864865
# normalize
# tokenize
# 0.115011750881
# normalize
# tokenize
# 0.115158636898
# normalize
# tokenize
# 0.115305522914
# normalize
# tokenize
# 0.115452408931
# normalize
# tokenize
# 0.115599294947
# normalize
# tokenize
# 0.115746180964
# normalize
# tokenize
# 0.11589306698
# normalize
# tokenize
# 0.116039952996
# normalize
# tokenize
# 0.116186839013
# normalize
# tokenize
# 0.116333725029
# normalize
# tokenize
# 0.116480611046
# normalize
# tokenize
# 0.116627497062
# normalize
# tokenize
# 0.116774383079
# normalize
# tokenize
# 0.116921269095
# normalize
# tokenize
# 0.117068155112
# normalize
# tokenize
# 0.117215041128
# normalize
# tokenize
# 0.117361927145
# normalize
# tokenize
# 0.117508813161
# normalize
# tokenize
# 0.117655699177
# normalize
# tokenize
# 0.117802585194
# normalize
# tokenize
# 0.11794947121
# normalize
# tokenize
# 0.118096357227
# normalize
# tokenize
# 0.118243243243
# normalize
# tokenize
# 0.11839012926
# normalize
# tokenize
# 0.118537015276
# normalize
# tokenize
# 0.118683901293
# normalize
# tokenize
# 0.118830787309
# normalize
# tokenize
# 0.118977673325
# normalize
# tokenize
# 0.119124559342
# normalize
# tokenize
# 0.119271445358
# normalize
# tokenize
# 0.119418331375
# normalize
# tokenize
# 0.119565217391
# normalize
# tokenize
# 0.119712103408
# normalize
# tokenize
# 0.119858989424
# normalize
# tokenize
# 0.120005875441
# normalize
# tokenize
# 0.120152761457
# normalize
# tokenize
# 0.120299647474
# normalize
# tokenize
# 0.12044653349
# normalize
# tokenize
# 0.120593419506
# normalize
# tokenize
# 0.120740305523
# normalize
# tokenize
# 0.120887191539
# normalize
# tokenize
# 0.121034077556
# normalize
# tokenize
# 0.121180963572
# normalize
# tokenize
# 0.121327849589
# normalize
# tokenize
# 0.121474735605
# normalize
# tokenize
# 0.121621621622
# normalize
# tokenize
# 0.121768507638
# normalize
# tokenize
# 0.121915393655
# normalize
# tokenize
# 0.122062279671
# normalize
# tokenize
# 0.122209165687
# normalize
# tokenize
# 0.122356051704
# normalize
# tokenize
# 0.12250293772
# normalize
# tokenize
# 0.122649823737
# normalize
# tokenize
# 0.122796709753
# normalize
# tokenize
# 0.12294359577
# normalize
# tokenize
# 0.123090481786
# normalize
# tokenize
# 0.123237367803
# normalize
# tokenize
# 0.123384253819
# normalize
# tokenize
# 0.123531139835
# normalize
# tokenize
# 0.123678025852
# normalize
# tokenize
# 0.123824911868
# normalize
# tokenize
# 0.123971797885
# normalize
# tokenize
# 0.124118683901
# normalize
# tokenize
# 0.124265569918
# normalize
# tokenize
# 0.124412455934
# normalize
# tokenize
# 0.124559341951
# normalize
# tokenize
# 0.124706227967
# normalize
# tokenize
# 0.124853113984
# normalize
# tokenize
# 0.125
# normalize
# tokenize
# 0.125146886016
# normalize
# tokenize
# 0.125293772033
# normalize
# tokenize
# 0.125440658049
# normalize
# tokenize
# 0.125587544066
# normalize
# tokenize
# 0.125734430082
# normalize
# tokenize
# 0.125881316099
# normalize
# tokenize
# 0.126028202115
# normalize
# tokenize
# 0.126175088132
# normalize
# tokenize
# 0.126321974148
# normalize
# tokenize
# 0.126468860165
# normalize
# tokenize
# 0.126615746181
# normalize
# tokenize
# 0.126762632197
# normalize
# tokenize
# 0.126909518214
# normalize
# tokenize
# 0.12705640423
# normalize
# tokenize
# 0.127203290247
# normalize
# tokenize
# 0.127350176263
# normalize
# tokenize
# 0.12749706228
# normalize
# tokenize
# 0.127643948296
# normalize
# tokenize
# 0.127790834313
# normalize
# tokenize
# 0.127937720329
# normalize
# tokenize
# 0.128084606345
# normalize
# tokenize
# 0.128231492362
# normalize
# tokenize
# 0.128378378378
# normalize
# tokenize
# 0.128525264395
# normalize
# tokenize
# 0.128672150411
# normalize
# tokenize
# 0.128819036428
# normalize
# tokenize
# 0.128965922444
# normalize
# tokenize
# 0.129112808461
# normalize
# tokenize
# 0.129259694477
# normalize
# tokenize
# 0.129406580494
# normalize
# tokenize
# 0.12955346651
# normalize
# tokenize
# 0.129700352526
# normalize
# tokenize
# 0.129847238543
# normalize
# tokenize
# 0.129994124559
# normalize
# tokenize
# 0.130141010576
# normalize
# tokenize
# 0.130287896592
# normalize
# tokenize
# 0.130434782609
# normalize
# tokenize
# 0.130581668625
# normalize
# tokenize
# 0.130728554642
# normalize
# tokenize
# 0.130875440658
# normalize
# tokenize
# 0.131022326675
# normalize
# tokenize
# 0.131169212691
# normalize
# tokenize
# 0.131316098707
# normalize
# tokenize
# 0.131462984724
# normalize
# tokenize
# 0.13160987074
# normalize
# tokenize
# 0.131756756757
# normalize
# tokenize
# 0.131903642773
# normalize
# tokenize
# 0.13205052879
# normalize
# tokenize
# 0.132197414806
# normalize
# tokenize
# 0.132344300823
# normalize
# tokenize
# 0.132491186839
# normalize
# tokenize
# 0.132638072855
# normalize
# tokenize
# 0.132784958872
# normalize
# tokenize
# 0.132931844888
# normalize
# tokenize
# 0.133078730905
# normalize
# tokenize
# 0.133225616921
# normalize
# tokenize
# 0.133372502938
# normalize
# tokenize
# 0.133519388954
# normalize
# tokenize
# 0.133666274971
# normalize
# tokenize
# 0.133813160987
# normalize
# tokenize
# 0.133960047004
# normalize
# tokenize
# 0.13410693302
# normalize
# tokenize
# 0.134253819036
# normalize
# tokenize
# 0.134400705053
# normalize
# tokenize
# 0.134547591069
# normalize
# tokenize
# 0.134694477086
# normalize
# tokenize
# 0.134841363102
# normalize
# tokenize
# 0.134988249119
# normalize
# tokenize
# 0.135135135135
# normalize
# tokenize
# 0.135282021152
# normalize
# tokenize
# 0.135428907168
# normalize
# tokenize
# 0.135575793184
# normalize
# tokenize
# 0.135722679201
# normalize
# tokenize
# 0.135869565217
# normalize
# tokenize
# 0.136016451234
# normalize
# tokenize
# 0.13616333725
# normalize
# tokenize
# 0.136310223267
# normalize
# tokenize
# 0.136457109283
# normalize
# tokenize
# 0.1366039953
# normalize
# tokenize
# 0.136750881316
# normalize
# tokenize
# 0.136897767333
# normalize
# tokenize
# 0.137044653349
# normalize
# tokenize
# 0.137191539365
# normalize
# tokenize
# 0.137338425382
# normalize
# tokenize
# 0.137485311398
# normalize
# tokenize
# 0.137632197415
# normalize
# tokenize
# 0.137779083431
# normalize
# tokenize
# 0.137925969448
# normalize
# tokenize
# 0.138072855464
# normalize
# tokenize
# 0.138219741481
# normalize
# tokenize
# 0.138366627497
# normalize
# tokenize
# 0.138513513514
# normalize
# tokenize
# 0.13866039953
# normalize
# tokenize
# 0.138807285546
# normalize
# tokenize
# 0.138954171563
# normalize
# tokenize
# 0.139101057579
# normalize
# tokenize
# 0.139247943596
# normalize
# tokenize
# 0.139394829612
# normalize
# tokenize
# 0.139541715629
# normalize
# tokenize
# 0.139688601645
# normalize
# tokenize
# 0.139835487662
# normalize
# tokenize
# 0.139982373678
# normalize
# tokenize
# 0.140129259694
# normalize
# tokenize
# 0.140276145711
# normalize
# tokenize
# 0.140423031727
# normalize
# tokenize
# 0.140569917744
# normalize
# tokenize
# 0.14071680376
# normalize
# tokenize
# 0.140863689777
# normalize
# tokenize
# 0.141010575793
# normalize
# tokenize
# 0.14115746181
# normalize
# tokenize
# 0.141304347826
# normalize
# tokenize
# 0.141451233843
# normalize
# tokenize
# 0.141598119859
# normalize
# tokenize
# 0.141745005875
# normalize
# tokenize
# 0.141891891892
# normalize
# tokenize
# 0.142038777908
# normalize
# tokenize
# 0.142185663925
# normalize
# tokenize
# 0.142332549941
# normalize
# tokenize
# 0.142479435958
# normalize
# tokenize
# 0.142626321974
# normalize
# tokenize
# 0.142773207991
# normalize
# tokenize
# 0.142920094007
# normalize
# tokenize
# 0.143066980024
# normalize
# tokenize
# 0.14321386604
# normalize
# tokenize
# 0.143360752056
# normalize
# tokenize
# 0.143507638073
# normalize
# tokenize
# 0.143654524089
# normalize
# tokenize
# 0.143801410106
# normalize
# tokenize
# 0.143948296122
# normalize
# tokenize
# 0.144095182139
# normalize
# tokenize
# 0.144242068155
# normalize
# tokenize
# 0.144388954172
# normalize
# tokenize
# 0.144535840188
# normalize
# tokenize
# 0.144682726204
# normalize
# tokenize
# 0.144829612221
# normalize
# tokenize
# 0.144976498237
# normalize
# tokenize
# 0.145123384254
# normalize
# tokenize
# 0.14527027027
# normalize
# tokenize
# 0.145417156287
# normalize
# tokenize
# 0.145564042303
# normalize
# tokenize
# 0.14571092832
# normalize
# tokenize
# 0.145857814336
# normalize
# tokenize
# 0.146004700353
# normalize
# tokenize
# 0.146151586369
# normalize
# tokenize
# 0.146298472385
# normalize
# tokenize
# 0.146445358402
# normalize
# tokenize
# 0.146592244418
# normalize
# tokenize
# 0.146739130435
# normalize
# tokenize
# 0.146886016451
# normalize
# tokenize
# 0.147032902468
# normalize
# tokenize
# 0.147179788484
# normalize
# tokenize
# 0.147326674501
# normalize
# tokenize
# 0.147473560517
# normalize
# tokenize
# 0.147620446533
# normalize
# tokenize
# 0.14776733255
# normalize
# tokenize
# 0.147914218566
# normalize
# tokenize
# 0.148061104583
# normalize
# tokenize
# 0.148207990599
# normalize
# tokenize
# 0.148354876616
# normalize
# tokenize
# 0.148501762632
# normalize
# tokenize
# 0.148648648649
# normalize
# tokenize
# 0.148795534665
# normalize
# tokenize
# 0.148942420682
# normalize
# tokenize
# 0.149089306698
# normalize
# tokenize
# 0.149236192714
# normalize
# tokenize
# 0.149383078731
# normalize
# tokenize
# 0.149529964747
# normalize
# tokenize
# 0.149676850764
# normalize
# tokenize
# 0.14982373678
# normalize
# tokenize
# 0.149970622797
# normalize
# tokenize
# 0.150117508813
# normalize
# tokenize
# 0.15026439483
# normalize
# tokenize
# 0.150411280846
# normalize
# tokenize
# 0.150558166863
# normalize
# tokenize
# 0.150705052879
# normalize
# tokenize
# 0.150851938895
# normalize
# tokenize
# 0.150998824912
# normalize
# tokenize
# 0.151145710928
# normalize
# tokenize
# 0.151292596945
# normalize
# tokenize
# 0.151439482961
# normalize
# tokenize
# 0.151586368978
# normalize
# tokenize
# 0.151733254994
# normalize
# tokenize
# 0.151880141011
# normalize
# tokenize
# 0.152027027027
# normalize
# tokenize
# 0.152173913043
# normalize
# tokenize
# 0.15232079906
# normalize
# tokenize
# 0.152467685076
# normalize
# tokenize
# 0.152614571093
# normalize
# tokenize
# 0.152761457109
# normalize
# tokenize
# 0.152908343126
# normalize
# tokenize
# 0.153055229142
# normalize
# tokenize
# 0.153202115159
# normalize
# tokenize
# 0.153349001175
# normalize
# tokenize
# 0.153495887192
# normalize
# tokenize
# 0.153642773208
# normalize
# tokenize
# 0.153789659224
# normalize
# tokenize
# 0.153936545241
# normalize
# tokenize
# 0.154083431257
# normalize
# tokenize
# 0.154230317274
# normalize
# tokenize
# 0.15437720329
# normalize
# tokenize
# 0.154524089307
# normalize
# tokenize
# 0.154670975323
# normalize
# tokenize
# 0.15481786134
# normalize
# tokenize
# 0.154964747356
# normalize
# tokenize
# 0.155111633373
# normalize
# tokenize
# 0.155258519389
# normalize
# tokenize
# 0.155405405405
# normalize
# tokenize
# 0.155552291422
# normalize
# tokenize
# 0.155699177438
# normalize
# tokenize
# 0.155846063455
# normalize
# tokenize
# 0.155992949471
# normalize
# tokenize
# 0.156139835488
# normalize
# tokenize
# 0.156286721504
# normalize
# tokenize
# 0.156433607521
# normalize
# tokenize
# 0.156580493537
# normalize
# tokenize
# 0.156727379553
# normalize
# tokenize
# 0.15687426557
# normalize
# tokenize
# 0.157021151586
# normalize
# tokenize
# 0.157168037603
# normalize
# tokenize
# 0.157314923619
# normalize
# tokenize
# 0.157461809636
# normalize
# tokenize
# 0.157608695652
# normalize
# tokenize
# 0.157755581669
# normalize
# tokenize
# 0.157902467685
# normalize
# tokenize
# 0.158049353702
# normalize
# tokenize
# 0.158196239718
# normalize
# tokenize
# 0.158343125734
# normalize
# tokenize
# 0.158490011751
# normalize
# tokenize
# 0.158636897767
# normalize
# tokenize
# 0.158783783784
# normalize
# tokenize
# 0.1589306698
# normalize
# tokenize
# 0.159077555817
# normalize
# tokenize
# 0.159224441833
# normalize
# tokenize
# 0.15937132785
# normalize
# tokenize
# 0.159518213866
# normalize
# tokenize
# 0.159665099882
# normalize
# tokenize
# 0.159811985899
# normalize
# tokenize
# 0.159958871915
# normalize
# tokenize
# 0.160105757932
# normalize
# tokenize
# 0.160252643948
# normalize
# tokenize
# 0.160399529965
# normalize
# tokenize
# 0.160546415981
# normalize
# tokenize
# 0.160693301998
# normalize
# tokenize
# 0.160840188014
# normalize
# tokenize
# 0.160987074031
# normalize
# tokenize
# 0.161133960047
# normalize
# tokenize
# 0.161280846063
# normalize
# tokenize
# 0.16142773208
# normalize
# tokenize
# 0.161574618096
# normalize
# tokenize
# 0.161721504113
# normalize
# tokenize
# 0.161868390129
# normalize
# tokenize
# 0.162015276146
# normalize
# tokenize
# 0.162162162162
# normalize
# tokenize
# 0.162309048179
# normalize
# tokenize
# 0.162455934195
# normalize
# tokenize
# 0.162602820212
# normalize
# tokenize
# 0.162749706228
# normalize
# tokenize
# 0.162896592244
# normalize
# tokenize
# 0.163043478261
# normalize
# tokenize
# 0.163190364277
# normalize
# tokenize
# 0.163337250294
# normalize
# tokenize
# 0.16348413631
# normalize
# tokenize
# 0.163631022327
# normalize
# tokenize
# 0.163777908343
# normalize
# tokenize
# 0.16392479436
# normalize
# tokenize
# 0.164071680376
# normalize
# tokenize
# 0.164218566392
# normalize
# tokenize
# 0.164365452409
# normalize
# tokenize
# 0.164512338425
# normalize
# tokenize
# 0.164659224442
# normalize
# tokenize
# 0.164806110458
# normalize
# tokenize
# 0.164952996475
# normalize
# tokenize
# 0.165099882491
# normalize
# tokenize
# 0.165246768508
# normalize
# tokenize
# 0.165393654524
# normalize
# tokenize
# 0.165540540541
# normalize
# tokenize
# 0.165687426557
# normalize
# tokenize
# 0.165834312573
# normalize
# tokenize
# 0.16598119859
# normalize
# tokenize
# 0.166128084606
# normalize
# tokenize
# 0.166274970623
# normalize
# tokenize
# 0.166421856639
# normalize
# tokenize
# 0.166568742656
# normalize
# tokenize
# 0.166715628672
# normalize
# tokenize
# 0.166862514689
# normalize
# tokenize
# 0.167009400705
# normalize
# tokenize
# 0.167156286722
# normalize
# tokenize
# 0.167303172738
# normalize
# tokenize
# 0.167450058754
# normalize
# tokenize
# 0.167596944771
# normalize
# tokenize
# 0.167743830787
# normalize
# tokenize
# 0.167890716804
# normalize
# tokenize
# 0.16803760282
# normalize
# tokenize
# 0.168184488837
# normalize
# tokenize
# 0.168331374853
# normalize
# tokenize
# 0.16847826087
# normalize
# tokenize
# 0.168625146886
# normalize
# tokenize
# 0.168772032902
# normalize
# tokenize
# 0.168918918919
# normalize
# tokenize
# 0.169065804935
# normalize
# tokenize
# 0.169212690952
# normalize
# tokenize
# 0.169359576968
# normalize
# tokenize
# 0.169506462985
# normalize
# tokenize
# 0.169653349001
# normalize
# tokenize
# 0.169800235018
# normalize
# tokenize
# 0.169947121034
# normalize
# tokenize
# 0.170094007051
# normalize
# tokenize
# 0.170240893067
# normalize
# tokenize
# 0.170387779083
# normalize
# tokenize
# 0.1705346651
# normalize
# tokenize
# 0.170681551116
# normalize
# tokenize
# 0.170828437133
# normalize
# tokenize
# 0.170975323149
# normalize
# tokenize
# 0.171122209166
# normalize
# tokenize
# 0.171269095182
# normalize
# tokenize
# 0.171415981199
# normalize
# tokenize
# 0.171562867215
# normalize
# tokenize
# 0.171709753231
# normalize
# tokenize
# 0.171856639248
# normalize
# tokenize
# 0.172003525264
# normalize
# tokenize
# 0.172150411281
# normalize
# tokenize
# 0.172297297297
# normalize
# tokenize
# 0.172444183314
# normalize
# tokenize
# 0.17259106933
# normalize
# tokenize
# 0.172737955347
# normalize
# tokenize
# 0.172884841363
# normalize
# tokenize
# 0.17303172738
# normalize
# tokenize
# 0.173178613396
# normalize
# tokenize
# 0.173325499412
# normalize
# tokenize
# 0.173472385429
# normalize
# tokenize
# 0.173619271445
# normalize
# tokenize
# 0.173766157462
# normalize
# tokenize
# 0.173913043478
# normalize
# tokenize
# 0.174059929495
# normalize
# tokenize
# 0.174206815511
# normalize
# tokenize
# 0.174353701528
# normalize
# tokenize
# 0.174500587544
# normalize
# tokenize
# 0.174647473561
# normalize
# tokenize
# 0.174794359577
# normalize
# tokenize
# 0.174941245593
# normalize
# tokenize
# 0.17508813161
# normalize
# tokenize
# 0.175235017626
# normalize
# tokenize
# 0.175381903643
# normalize
# tokenize
# 0.175528789659
# normalize
# tokenize
# 0.175675675676
# normalize
# tokenize
# 0.175822561692
# normalize
# tokenize
# 0.175969447709
# normalize
# tokenize
# 0.176116333725
# normalize
# tokenize
# 0.176263219741
# normalize
# tokenize
# 0.176410105758
# normalize
# tokenize
# 0.176556991774
# normalize
# tokenize
# 0.176703877791
# normalize
# tokenize
# 0.176850763807
# normalize
# tokenize
# 0.176997649824
# normalize
# tokenize
# 0.17714453584
# normalize
# tokenize
# 0.177291421857
# normalize
# tokenize
# 0.177438307873
# normalize
# tokenize
# 0.17758519389
# normalize
# tokenize
# 0.177732079906
# normalize
# tokenize
# 0.177878965922
# normalize
# tokenize
# 0.178025851939
# normalize
# tokenize
# 0.178172737955
# normalize
# tokenize
# 0.178319623972
# normalize
# tokenize
# 0.178466509988
# normalize
# tokenize
# 0.178613396005
# normalize
# tokenize
# 0.178760282021
# normalize
# tokenize
# 0.178907168038
# normalize
# tokenize
# 0.179054054054
# normalize
# tokenize
# 0.179200940071
# normalize
# tokenize
# 0.179347826087
# normalize
# tokenize
# 0.179494712103
# normalize
# tokenize
# 0.17964159812
# normalize
# tokenize
# 0.179788484136
# normalize
# tokenize
# 0.179935370153
# normalize
# tokenize
# 0.180082256169
# normalize
# tokenize
# 0.180229142186
# normalize
# tokenize
# 0.180376028202
# normalize
# tokenize
# 0.180522914219
# normalize
# tokenize
# 0.180669800235
# normalize
# tokenize
# 0.180816686251
# normalize
# tokenize
# 0.180963572268
# normalize
# tokenize
# 0.181110458284
# normalize
# tokenize
# 0.181257344301
# normalize
# tokenize
# 0.181404230317
# normalize
# tokenize
# 0.181551116334
# normalize
# tokenize
# 0.18169800235
# normalize
# tokenize
# 0.181844888367
# normalize
# tokenize
# 0.181991774383
# normalize
# tokenize
# 0.1821386604
# normalize
# tokenize
# 0.182285546416
# normalize
# tokenize
# 0.182432432432
# normalize
# tokenize
# 0.182579318449
# normalize
# tokenize
# 0.182726204465
# normalize
# tokenize
# 0.182873090482
# normalize
# tokenize
# 0.183019976498
# normalize
# tokenize
# 0.183166862515
# normalize
# tokenize
# 0.183313748531
# normalize
# tokenize
# 0.183460634548
# normalize
# tokenize
# 0.183607520564
# normalize
# tokenize
# 0.18375440658
# normalize
# tokenize
# 0.183901292597
# normalize
# tokenize
# 0.184048178613
# normalize
# tokenize
# 0.18419506463
# normalize
# tokenize
# 0.184341950646
# normalize
# tokenize
# 0.184488836663
# normalize
# tokenize
# 0.184635722679
# normalize
# tokenize
# 0.184782608696
# normalize
# tokenize
# 0.184929494712
# normalize
# tokenize
# 0.185076380729
# normalize
# tokenize
# 0.185223266745
# normalize
# tokenize
# 0.185370152761
# normalize
# tokenize
# 0.185517038778
# normalize
# tokenize
# 0.185663924794
# normalize
# tokenize
# 0.185810810811
# normalize
# tokenize
# 0.185957696827
# normalize
# tokenize
# 0.186104582844
# normalize
# tokenize
# 0.18625146886
# normalize
# tokenize
# 0.186398354877
# normalize
# tokenize
# 0.186545240893
# normalize
# tokenize
# 0.18669212691
# normalize
# tokenize
# 0.186839012926
# normalize
# tokenize
# 0.186985898942
# normalize
# tokenize
# 0.187132784959
# normalize
# tokenize
# 0.187279670975
# normalize
# tokenize
# 0.187426556992
# normalize
# tokenize
# 0.187573443008
# normalize
# tokenize
# 0.187720329025
# normalize
# tokenize
# 0.187867215041
# normalize
# tokenize
# 0.188014101058
# normalize
# tokenize
# 0.188160987074
# normalize
# tokenize
# 0.18830787309
# normalize
# tokenize
# 0.188454759107
# normalize
# tokenize
# 0.188601645123
# normalize
# tokenize
# 0.18874853114
# normalize
# tokenize
# 0.188895417156
# normalize
# tokenize
# 0.189042303173
# normalize
# tokenize
# 0.189189189189
# normalize
# tokenize
# 0.189336075206
# normalize
# tokenize
# 0.189482961222
# normalize
# tokenize
# 0.189629847239
# normalize
# tokenize
# 0.189776733255
# normalize
# tokenize
# 0.189923619271
# normalize
# tokenize
# 0.190070505288
# normalize
# tokenize
# 0.190217391304
# normalize
# tokenize
# 0.190364277321
# normalize
# tokenize
# 0.190511163337
# normalize
# tokenize
# 0.190658049354
# normalize
# tokenize
# 0.19080493537
# normalize
# tokenize
# 0.190951821387
# normalize
# tokenize
# 0.191098707403
# normalize
# tokenize
# 0.19124559342
# normalize
# tokenize
# 0.191392479436
# normalize
# tokenize
# 0.191539365452
# normalize
# tokenize
# 0.191686251469
# normalize
# tokenize
# 0.191833137485
# normalize
# tokenize
# 0.191980023502
# normalize
# tokenize
# 0.192126909518
# normalize
# tokenize
# 0.192273795535
# normalize
# tokenize
# 0.192420681551
# normalize
# tokenize
# 0.192567567568
# normalize
# tokenize
# 0.192714453584
# normalize
# tokenize
# 0.1928613396
# normalize
# tokenize
# 0.193008225617
# normalize
# tokenize
# 0.193155111633
# normalize
# tokenize
# 0.19330199765
# normalize
# tokenize
# 0.193448883666
# normalize
# tokenize
# 0.193595769683
# normalize
# tokenize
# 0.193742655699
# normalize
# tokenize
# 0.193889541716
# normalize
# tokenize
# 0.194036427732
# normalize
# tokenize
# 0.194183313749
# normalize
# tokenize
# 0.194330199765
# normalize
# tokenize
# 0.194477085781
# normalize
# tokenize
# 0.194623971798
# normalize
# tokenize
# 0.194770857814
# normalize
# tokenize
# 0.194917743831
# normalize
# tokenize
# 0.195064629847
# normalize
# tokenize
# 0.195211515864
# normalize
# tokenize
# 0.19535840188
# normalize
# tokenize
# 0.195505287897
# normalize
# tokenize
# 0.195652173913
# normalize
# tokenize
# 0.195799059929
# normalize
# tokenize
# 0.195945945946
# normalize
# tokenize
# 0.196092831962
# normalize
# tokenize
# 0.196239717979
# normalize
# tokenize
# 0.196386603995
# normalize
# tokenize
# 0.196533490012
# normalize
# tokenize
# 0.196680376028
# normalize
# tokenize
# 0.196827262045
# normalize
# tokenize
# 0.196974148061
# normalize
# tokenize
# 0.197121034078
# normalize
# tokenize
# 0.197267920094
# normalize
# tokenize
# 0.19741480611
# normalize
# tokenize
# 0.197561692127
# normalize
# tokenize
# 0.197708578143
# normalize
# tokenize
# 0.19785546416
# normalize
# tokenize
# 0.198002350176
# normalize
# tokenize
# 0.198149236193
# normalize
# tokenize
# 0.198296122209
# normalize
# tokenize
# 0.198443008226
# normalize
# tokenize
# 0.198589894242
# normalize
# tokenize
# 0.198736780259
# normalize
# tokenize
# 0.198883666275
# normalize
# tokenize
# 0.199030552291
# normalize
# tokenize
# 0.199177438308
# normalize
# tokenize
# 0.199324324324
# normalize
# tokenize
# 0.199471210341
# normalize
# tokenize
# 0.199618096357
# normalize
# tokenize
# 0.199764982374
# normalize
# tokenize
# 0.19991186839
# normalize
# tokenize
# 0.200058754407
# normalize
# tokenize
# 0.200205640423
# normalize
# tokenize
# 0.200352526439
# normalize
# tokenize
# 0.200499412456
# normalize
# tokenize
# 0.200646298472
# normalize
# tokenize
# 0.200793184489
# normalize
# tokenize
# 0.200940070505
# normalize
# tokenize
# 0.201086956522
# normalize
# tokenize
# 0.201233842538
# normalize
# tokenize
# 0.201380728555
# normalize
# tokenize
# 0.201527614571
# normalize
# tokenize
# 0.201674500588
# normalize
# tokenize
# 0.201821386604
# normalize
# tokenize
# 0.20196827262
# normalize
# tokenize
# 0.202115158637
# normalize
# tokenize
# 0.202262044653
# normalize
# tokenize
# 0.20240893067
# normalize
# tokenize
# 0.202555816686
# normalize
# tokenize
# 0.202702702703
# normalize
# tokenize
# 0.202849588719
# normalize
# tokenize
# 0.202996474736
# normalize
# tokenize
# 0.203143360752
# normalize
# tokenize
# 0.203290246769
# normalize
# tokenize
# 0.203437132785
# normalize
# tokenize
# 0.203584018801
# normalize
# tokenize
# 0.203730904818
# normalize
# tokenize
# 0.203877790834
# normalize
# tokenize
# 0.204024676851
# normalize
# tokenize
# 0.204171562867
# normalize
# tokenize
# 0.204318448884
# normalize
# tokenize
# 0.2044653349
# normalize
# tokenize
# 0.204612220917
# normalize
# tokenize
# ...
# 0.931110458284
# normalize
# tokenize
# 0.931257344301
# normalize
# tokenize
# 0.931404230317
# normalize
# tokenize
# 0.931551116334
# normalize
# tokenize
# 0.93169800235
# normalize
# tokenize
# 0.931844888367
# normalize
# tokenize
# 0.931991774383
# normalize
# tokenize
# 0.9321386604
# normalize
# tokenize
# 0.932285546416
# normalize
# tokenize
# 0.932432432432
# normalize
# tokenize
# 0.932579318449
# normalize
# tokenize
# 0.932726204465
# normalize
# tokenize
# 0.932873090482
# normalize
# tokenize
# 0.933019976498
# normalize
# tokenize
# 0.933166862515
# normalize
# tokenize
# 0.933313748531
# normalize
# tokenize
# 0.933460634548
# normalize
# tokenize
# 0.933607520564
# normalize
# tokenize
# 0.93375440658
# normalize
# tokenize
# 0.933901292597
# normalize
# tokenize
# 0.934048178613
# normalize
# tokenize
# 0.93419506463
# normalize
# tokenize
# 0.934341950646
# normalize
# tokenize
# 0.934488836663
# normalize
# tokenize
# 0.934635722679
# normalize
# tokenize
# 0.934782608696
# normalize
# tokenize
# 0.934929494712
# normalize
# tokenize
# 0.935076380729
# normalize
# tokenize
# 0.935223266745
# normalize
# tokenize
# 0.935370152761
# normalize
# tokenize
# 0.935517038778
# normalize
# tokenize
# 0.935663924794
# normalize
# tokenize
# 0.935810810811
# normalize
# tokenize
# 0.935957696827
# normalize
# tokenize
# 0.936104582844
# normalize
# tokenize
# 0.93625146886
# normalize
# tokenize
# 0.936398354877
# normalize
# tokenize
# 0.936545240893
# normalize
# tokenize
# 0.93669212691
# normalize
# tokenize
# 0.936839012926
# normalize
# tokenize
# 0.936985898942
# normalize
# tokenize
# 0.937132784959
# normalize
# tokenize
# 0.937279670975
# normalize
# tokenize
# 0.937426556992
# normalize
# tokenize
# 0.937573443008
# normalize
# tokenize
# 0.937720329025
# normalize
# tokenize
# 0.937867215041
# normalize
# tokenize
# 0.938014101058
# normalize
# tokenize
# 0.938160987074
# normalize
# tokenize
# 0.93830787309
# normalize
# tokenize
# 0.938454759107
# normalize
# tokenize
# 0.938601645123
# normalize
# tokenize
# 0.93874853114
# normalize
# tokenize
# 0.938895417156
# normalize
# tokenize
# 0.939042303173
# normalize
# tokenize
# 0.939189189189
# normalize
# tokenize
# 0.939336075206
# normalize
# tokenize
# 0.939482961222
# normalize
# tokenize
# 0.939629847239
# normalize
# tokenize
# 0.939776733255
# normalize
# tokenize
# 0.939923619271
# normalize
# tokenize
# 0.940070505288
# normalize
# tokenize
# 0.940217391304
# normalize
# tokenize
# 0.940364277321
# normalize
# tokenize
# 0.940511163337
# normalize
# tokenize
# 0.940658049354
# normalize
# tokenize
# 0.94080493537
# normalize
# tokenize
# 0.940951821387
# normalize
# tokenize
# 0.941098707403
# normalize
# tokenize
# 0.94124559342
# normalize
# tokenize
# 0.941392479436
# normalize
# tokenize
# 0.941539365452
# normalize
# tokenize
# 0.941686251469
# normalize
# tokenize
# 0.941833137485
# normalize
# tokenize
# 0.941980023502
# normalize
# tokenize
# 0.942126909518
# normalize
# tokenize
# 0.942273795535
# normalize
# tokenize
# 0.942420681551
# normalize
# tokenize
# 0.942567567568
# normalize
# tokenize
# 0.942714453584
# normalize
# tokenize
# 0.9428613396
# normalize
# tokenize
# 0.943008225617
# normalize
# tokenize
# 0.943155111633
# normalize
# tokenize
# 0.94330199765
# normalize
# tokenize
# 0.943448883666
# normalize
# tokenize
# 0.943595769683
# normalize
# tokenize
# 0.943742655699
# normalize
# tokenize
# 0.943889541716
# normalize
# tokenize
# 0.944036427732
# normalize
# tokenize
# 0.944183313749
# normalize
# tokenize
# 0.944330199765
# normalize
# tokenize
# 0.944477085781
# normalize
# tokenize
# 0.944623971798
# normalize
# tokenize
# 0.944770857814
# normalize
# tokenize
# 0.944917743831
# normalize
# tokenize
# 0.945064629847
# normalize
# tokenize
# 0.945211515864
# normalize
# tokenize
# 0.94535840188
# normalize
# tokenize
# 0.945505287897
# normalize
# tokenize
# 0.945652173913
# normalize
# tokenize
# 0.945799059929
# normalize
# tokenize
# 0.945945945946
# normalize
# tokenize
# 0.946092831962
# normalize
# tokenize
# 0.946239717979
# normalize
# tokenize
# 0.946386603995
# normalize
# tokenize
# 0.946533490012
# normalize
# tokenize
# 0.946680376028
# normalize
# tokenize
# 0.946827262045
# normalize
# tokenize
# 0.946974148061
# normalize
# tokenize
# 0.947121034078
# normalize
# tokenize
# 0.947267920094
# normalize
# tokenize
# 0.94741480611
# normalize
# tokenize
# 0.947561692127
# normalize
# tokenize
# 0.947708578143
# normalize
# tokenize
# 0.94785546416
# normalize
# tokenize
# 0.948002350176
# normalize
# tokenize
# 0.948149236193
# normalize
# tokenize
# 0.948296122209
# normalize
# tokenize
# 0.948443008226
# normalize
# tokenize
# 0.948589894242
# normalize
# tokenize
# 0.948736780259
# normalize
# tokenize
# 0.948883666275
# normalize
# tokenize
# 0.949030552291
# normalize
# tokenize
# 0.949177438308
# normalize
# tokenize
# 0.949324324324
# normalize
# tokenize
# 0.949471210341
# normalize
# tokenize
# 0.949618096357
# normalize
# tokenize
# 0.949764982374
# normalize
# tokenize
# 0.94991186839
# normalize
# tokenize
# 0.950058754407
# normalize
# tokenize
# 0.950205640423
# normalize
# tokenize
# 0.950352526439
# normalize
# tokenize
# 0.950499412456
# normalize
# tokenize
# 0.950646298472
# normalize
# tokenize
# 0.950793184489
# normalize
# tokenize
# 0.950940070505
# normalize
# tokenize
# 0.951086956522
# normalize
# tokenize
# 0.951233842538
# normalize
# tokenize
# 0.951380728555
# normalize
# tokenize
# 0.951527614571
# normalize
# tokenize
# 0.951674500588
# normalize
# tokenize
# 0.951821386604
# normalize
# tokenize
# 0.95196827262
# normalize
# tokenize
# 0.952115158637
# normalize
# tokenize
# 0.952262044653
# normalize
# tokenize
# 0.95240893067
# normalize
# tokenize
# 0.952555816686
# normalize
# tokenize
# 0.952702702703
# normalize
# tokenize
# 0.952849588719
# normalize
# tokenize
# 0.952996474736
# normalize
# tokenize
# 0.953143360752
# normalize
# tokenize
# 0.953290246769
# normalize
# tokenize
# 0.953437132785
# normalize
# tokenize
# 0.953584018801
# normalize
# tokenize
# 0.953730904818
# normalize
# tokenize
# 0.953877790834
# normalize
# tokenize
# 0.954024676851
# normalize
# tokenize
# 0.954171562867
# normalize
# tokenize
# 0.954318448884
# normalize
# tokenize
# 0.9544653349
# normalize
# tokenize
# 0.954612220917
# normalize
# tokenize
# 0.954759106933
# normalize
# tokenize
# 0.954905992949
# normalize
# tokenize
# 0.955052878966
# normalize
# tokenize
# 0.955199764982
# normalize
# tokenize
# 0.955346650999
# normalize
# tokenize
# 0.955493537015
# normalize
# tokenize
# 0.955640423032
# normalize
# tokenize
# 0.955787309048
# normalize
# tokenize
# 0.955934195065
# normalize
# tokenize
# 0.956081081081
# normalize
# tokenize
# 0.956227967098
# normalize
# tokenize
# 0.956374853114
# normalize
# tokenize
# 0.95652173913
# normalize
# tokenize
# 0.956668625147
# normalize
# tokenize
# 0.956815511163
# normalize
# tokenize
# 0.95696239718
# normalize
# tokenize
# 0.957109283196
# normalize
# tokenize
# 0.957256169213
# normalize
# tokenize
# 0.957403055229
# normalize
# tokenize
# 0.957549941246
# normalize
# tokenize
# 0.957696827262
# normalize
# tokenize
# 0.957843713278
# normalize
# tokenize
# 0.957990599295
# normalize
# tokenize
# 0.958137485311
# normalize
# tokenize
# 0.958284371328
# normalize
# tokenize
# 0.958431257344
# normalize
# tokenize
# 0.958578143361
# normalize
# tokenize
# 0.958725029377
# normalize
# tokenize
# 0.958871915394
# normalize
# tokenize
# 0.95901880141
# normalize
# tokenize
# 0.959165687427
# normalize
# tokenize
# 0.959312573443
# normalize
# tokenize
# 0.959459459459
# normalize
# tokenize
# 0.959606345476
# normalize
# tokenize
# 0.959753231492
# normalize
# tokenize
# 0.959900117509
# normalize
# tokenize
# 0.960047003525
# normalize
# tokenize
# 0.960193889542
# normalize
# tokenize
# 0.960340775558
# normalize
# tokenize
# 0.960487661575
# normalize
# tokenize
# 0.960634547591
# normalize
# tokenize
# 0.960781433608
# normalize
# tokenize
# 0.960928319624
# normalize
# tokenize
# 0.96107520564
# normalize
# tokenize
# 0.961222091657
# normalize
# tokenize
# 0.961368977673
# normalize
# tokenize
# 0.96151586369
# normalize
# tokenize
# 0.961662749706
# normalize
# tokenize
# 0.961809635723
# normalize
# tokenize
# 0.961956521739
# normalize
# tokenize
# 0.962103407756
# normalize
# tokenize
# 0.962250293772
# normalize
# tokenize
# 0.962397179788
# normalize
# tokenize
# 0.962544065805
# normalize
# tokenize
# 0.962690951821
# normalize
# tokenize
# 0.962837837838
# normalize
# tokenize
# 0.962984723854
# normalize
# tokenize
# 0.963131609871
# normalize
# tokenize
# 0.963278495887
# normalize
# tokenize
# 0.963425381904
# normalize
# tokenize
# 0.96357226792
# normalize
# tokenize
# 0.963719153937
# normalize
# tokenize
# 0.963866039953
# normalize
# tokenize
# 0.964012925969
# normalize
# tokenize
# 0.964159811986
# normalize
# tokenize
# 0.964306698002
# normalize
# tokenize
# 0.964453584019
# normalize
# tokenize
# 0.964600470035
# normalize
# tokenize
# 0.964747356052
# normalize
# tokenize
# 0.964894242068
# normalize
# tokenize
# 0.965041128085
# normalize
# tokenize
# 0.965188014101
# normalize
# tokenize
# 0.965334900118
# normalize
# tokenize
# 0.965481786134
# normalize
# tokenize
# 0.96562867215
# normalize
# tokenize
# 0.965775558167
# normalize
# tokenize
# 0.965922444183
# normalize
# tokenize
# 0.9660693302
# normalize
# tokenize
# 0.966216216216
# normalize
# tokenize
# 0.966363102233
# normalize
# tokenize
# 0.966509988249
# normalize
# tokenize
# 0.966656874266
# normalize
# tokenize
# 0.966803760282
# normalize
# tokenize
# 0.966950646298
# normalize
# tokenize
# 0.967097532315
# normalize
# tokenize
# 0.967244418331
# normalize
# tokenize
# 0.967391304348
# normalize
# tokenize
# 0.967538190364
# normalize
# tokenize
# 0.967685076381
# normalize
# tokenize
# 0.967831962397
# normalize
# tokenize
# 0.967978848414
# normalize
# tokenize
# 0.96812573443
# normalize
# tokenize
# 0.968272620447
# normalize
# tokenize
# 0.968419506463
# normalize
# tokenize
# 0.968566392479
# normalize
# tokenize
# 0.968713278496
# normalize
# tokenize
# 0.968860164512
# normalize
# tokenize
# 0.969007050529
# normalize
# tokenize
# 0.969153936545
# normalize
# tokenize
# 0.969300822562
# normalize
# tokenize
# 0.969447708578
# normalize
# tokenize
# 0.969594594595
# normalize
# tokenize
# 0.969741480611
# normalize
# tokenize
# 0.969888366627
# normalize
# tokenize
# 0.970035252644
# normalize
# tokenize
# 0.97018213866
# normalize
# tokenize
# 0.970329024677
# normalize
# tokenize
# 0.970475910693
# normalize
# tokenize
# 0.97062279671
# normalize
# tokenize
# 0.970769682726
# normalize
# tokenize
# 0.970916568743
# normalize
# tokenize
# 0.971063454759
# normalize
# tokenize
# 0.971210340776
# normalize
# tokenize
# 0.971357226792
# normalize
# tokenize
# 0.971504112808
# normalize
# tokenize
# 0.971650998825
# normalize
# tokenize
# 0.971797884841
# normalize
# tokenize
# 0.971944770858
# normalize
# tokenize
# 0.972091656874
# normalize
# tokenize
# 0.972238542891
# normalize
# tokenize
# 0.972385428907
# normalize
# tokenize
# 0.972532314924
# normalize
# tokenize
# 0.97267920094
# normalize
# tokenize
# 0.972826086957
# normalize
# tokenize
# 0.972972972973
# normalize
# tokenize
# 0.973119858989
# normalize
# tokenize
# 0.973266745006
# normalize
# tokenize
# 0.973413631022
# normalize
# tokenize
# 0.973560517039
# normalize
# tokenize
# 0.973707403055
# normalize
# tokenize
# 0.973854289072
# normalize
# tokenize
# 0.974001175088
# normalize
# tokenize
# 0.974148061105
# normalize
# tokenize
# 0.974294947121
# normalize
# tokenize
# 0.974441833137
# normalize
# tokenize
# 0.974588719154
# normalize
# tokenize
# 0.97473560517
# normalize
# tokenize
# 0.974882491187
# normalize
# tokenize
# 0.975029377203
# normalize
# tokenize
# 0.97517626322
# normalize
# tokenize
# 0.975323149236
# normalize
# tokenize
# 0.975470035253
# normalize
# tokenize
# 0.975616921269
# normalize
# tokenize
# 0.975763807286
# normalize
# tokenize
# 0.975910693302
# normalize
# tokenize
# 0.976057579318
# normalize
# tokenize
# 0.976204465335
# normalize
# tokenize
# 0.976351351351
# normalize
# tokenize
# 0.976498237368
# normalize
# tokenize
# 0.976645123384
# normalize
# tokenize
# 0.976792009401
# normalize
# tokenize
# 0.976938895417
# normalize
# tokenize
# 0.977085781434
# normalize
# tokenize
# 0.97723266745
# normalize
# tokenize
# 0.977379553467
# normalize
# tokenize
# 0.977526439483
# normalize
# tokenize
# 0.977673325499
# normalize
# tokenize
# 0.977820211516
# normalize
# tokenize
# 0.977967097532
# normalize
# tokenize
# 0.978113983549
# normalize
# tokenize
# 0.978260869565
# normalize
# tokenize
# 0.978407755582
# normalize
# tokenize
# 0.978554641598
# normalize
# tokenize
# 0.978701527615
# normalize
# tokenize
# 0.978848413631
# normalize
# tokenize
# 0.978995299647
# normalize
# tokenize
# 0.979142185664
# normalize
# tokenize
# 0.97928907168
# normalize
# tokenize
# 0.979435957697
# normalize
# tokenize
# 0.979582843713
# normalize
# tokenize
# 0.97972972973
# normalize
# tokenize
# 0.979876615746
# normalize
# tokenize
# 0.980023501763
# normalize
# tokenize
# 0.980170387779
# normalize
# tokenize
# 0.980317273796
# normalize
# tokenize
# 0.980464159812
# normalize
# tokenize
# 0.980611045828
# normalize
# tokenize
# 0.980757931845
# normalize
# tokenize
# 0.980904817861
# normalize
# tokenize
# 0.981051703878
# normalize
# tokenize
# 0.981198589894
# normalize
# tokenize
# 0.981345475911
# normalize
# tokenize
# 0.981492361927
# normalize
# tokenize
# 0.981639247944
# normalize
# tokenize
# 0.98178613396
# normalize
# tokenize
# 0.981933019976
# normalize
# tokenize
# 0.982079905993
# normalize
# tokenize
# 0.982226792009
# normalize
# tokenize
# 0.982373678026
# normalize
# tokenize
# 0.982520564042
# normalize
# tokenize
# 0.982667450059
# normalize
# tokenize
# 0.982814336075
# normalize
# tokenize
# 0.982961222092
# normalize
# tokenize
# 0.983108108108
# normalize
# tokenize
# 0.983254994125
# normalize
# tokenize
# 0.983401880141
# normalize
# tokenize
# 0.983548766157
# normalize
# tokenize
# 0.983695652174
# normalize
# tokenize
# 0.98384253819
# normalize
# tokenize
# 0.983989424207
# normalize
# tokenize
# 0.984136310223
# normalize
# tokenize
# 0.98428319624
# normalize
# tokenize
# 0.984430082256
# normalize
# tokenize
# 0.984576968273
# normalize
# tokenize
# 0.984723854289
# normalize
# tokenize
# 0.984870740306
# normalize
# tokenize
# 0.985017626322
# normalize
# tokenize
# 0.985164512338
# normalize
# tokenize
# 0.985311398355
# normalize
# tokenize
# 0.985458284371
# normalize
# tokenize
# 0.985605170388
# normalize
# tokenize
# 0.985752056404
# normalize
# tokenize
# 0.985898942421
# normalize
# tokenize
# 0.986045828437
# normalize
# tokenize
# 0.986192714454
# normalize
# tokenize
# 0.98633960047
# normalize
# tokenize
# 0.986486486486
# normalize
# tokenize
# 0.986633372503
# normalize
# tokenize
# 0.986780258519
# normalize
# tokenize
# 0.986927144536
# normalize
# tokenize
# 0.987074030552
# normalize
# tokenize
# 0.987220916569
# normalize
# tokenize
# 0.987367802585
# normalize
# tokenize
# 0.987514688602
# normalize
# tokenize
# 0.987661574618
# normalize
# tokenize
# 0.987808460635
# normalize
# tokenize
# 0.987955346651
# normalize
# tokenize
# 0.988102232667
# normalize
# tokenize
# 0.988249118684
# normalize
# tokenize
# 0.9883960047
# normalize
# tokenize
# 0.988542890717
# normalize
# tokenize
# 0.988689776733
# normalize
# tokenize
# 0.98883666275
# normalize
# tokenize
# 0.988983548766
# normalize
# tokenize
# 0.989130434783
# normalize
# tokenize
# 0.989277320799
# normalize
# tokenize
# 0.989424206816
# normalize
# tokenize
# 0.989571092832
# normalize
# tokenize
# 0.989717978848
# normalize
# tokenize
# 0.989864864865
# normalize
# tokenize
# 0.990011750881
# normalize
# tokenize
# 0.990158636898
# normalize
# tokenize
# 0.990305522914
# normalize
# tokenize
# 0.990452408931
# normalize
# tokenize
# 0.990599294947
# normalize
# tokenize
# 0.990746180964
# normalize
# tokenize
# 0.99089306698
# normalize
# tokenize
# 0.991039952996
# normalize
# tokenize
# 0.991186839013
# normalize
# tokenize
# 0.991333725029
# normalize
# tokenize
# 0.991480611046
# normalize
# tokenize
# 0.991627497062
# normalize
# tokenize
# 0.991774383079
# normalize
# tokenize
# 0.991921269095
# normalize
# tokenize
# 0.992068155112
# normalize
# tokenize
# 0.992215041128
# normalize
# tokenize
# 0.992361927145
# normalize
# tokenize
# 0.992508813161
# normalize
# tokenize
# 0.992655699177
# normalize
# tokenize
# 0.992802585194
# normalize
# tokenize
# 0.99294947121
# normalize
# tokenize
# 0.993096357227
# normalize
# tokenize
# 0.993243243243
# normalize
# tokenize
# 0.99339012926
# normalize
# tokenize
# 0.993537015276
# normalize
# tokenize
# 0.993683901293
# normalize
# tokenize
# 0.993830787309
# normalize
# tokenize
# 0.993977673325
# normalize
# tokenize
# 0.994124559342
# normalize
# tokenize
# 0.994271445358
# normalize
# tokenize
# 0.994418331375
# normalize
# tokenize
# 0.994565217391
# normalize
# tokenize
# 0.994712103408
# normalize
# tokenize
# 0.994858989424
# normalize
# tokenize
# 0.995005875441
# normalize
# tokenize
# 0.995152761457
# normalize
# tokenize
# 0.995299647474
# normalize
# tokenize
# 0.99544653349
# normalize
# tokenize
# 0.995593419506
# normalize
# tokenize
# 0.995740305523
# normalize
# tokenize
# 0.995887191539
# normalize
# tokenize
# 0.996034077556
# normalize
# tokenize
# 0.996180963572
# normalize
# tokenize
# 0.996327849589
# normalize
# tokenize
# 0.996474735605
# normalize
# tokenize
# 0.996621621622
# normalize
# tokenize
# 0.996768507638
# normalize
# tokenize
# 0.996915393655
# normalize
# tokenize
# 0.997062279671
# normalize
# tokenize
# 0.997209165687
# normalize
# tokenize
# 0.997356051704
# normalize
# tokenize
# 0.99750293772
# normalize
# tokenize
# 0.997649823737
# normalize
# tokenize
# 0.997796709753
# normalize
# tokenize
# 0.99794359577
# normalize
# tokenize
# 0.998090481786
# normalize
# tokenize
# 0.998237367803
# normalize
# tokenize
# 0.998384253819
# normalize
# tokenize
# 0.998531139835
# normalize
# tokenize
# 0.998678025852
# normalize
# tokenize
# 0.998824911868
# normalize
# tokenize
# 0.998971797885
# normalize
# tokenize
# 0.999118683901
# normalize
# tokenize
# 0.999265569918
# normalize
# tokenize
# 0.999412455934
# normalize
# tokenize
# 0.999559341951
# normalize
# tokenize
# 0.999706227967
# normalize
# tokenize
# 0.999853113984
# normalize
# tokenize
# indexing has been finished
# <Top 0 Results for Term('content', u'\xf8\xaa') runtime=8.39233398438e-05>

# %% [markdown]
# ####

# %%
# Out:
# <Top 0 Results for And([Term('content', u'\xf8\xb3\xf8\xaa\xf8'), Term('content', u'\xf8\xb2')]) runtime=0.000255107879639>
# []

# %%
#Experiment: SE2
from hazm import *
from pre_rec import precision_recall
import codecs

documents_dir = "./Poems"
destination_dir = "./Poems_SE2"
all_files = os.listdir(documents_dir)
all_files = all_files[0:500]
print(len(all_files))
for i in range(len(all_files)):
    file = all_files[i]
    print(float(i)/len(all_files))
    source_file = documents_dir+"/"+file
    with codecs.open(source_file, 'r', "utf-8") as f:
        file_content = f.read().replace('\n', ' ')
        with codecs.open(destination_dir+file, 'w', "utf-8") as f2:
            f2.write(file_content)
# Out:
# 500
# 0.0
# 0.002
# 0.004
# 0.006
# 0.008
# 0.01
# 0.012
# 0.014
# 0.016
# 0.018
# 0.02
# 0.022
# 0.024
# 0.026
# 0.028
# 0.03
# 0.032
# 0.034
# 0.036
# 0.038
# 0.04
# 0.042
# 0.044
# 0.046
# 0.048
# 0.05
# 0.052
# 0.054
# 0.056
# 0.058
# 0.06
# 0.062
# 0.064
# 0.066
# 0.068
# 0.07
# 0.072
# 0.074
# 0.076
# 0.078
# 0.08
# 0.082
# 0.084
# 0.086
# 0.088
# 0.09
# 0.092
# 0.094
# 0.096
# 0.098
# 0.1
# 0.102
# 0.104
# 0.106
# 0.108
# 0.11
# 0.112
# 0.114
# 0.116
# 0.118
# 0.12
# 0.122
# 0.124
# 0.126
# 0.128
# 0.13
# 0.132
# 0.134
# 0.136
# 0.138
# 0.14
# 0.142
# 0.144
# 0.146
# 0.148
# 0.15
# 0.152
# 0.154
# 0.156
# 0.158
# 0.16
# 0.162
# 0.164
# 0.166
# 0.168
# 0.17
# 0.172
# 0.174
# 0.176
# 0.178
# 0.18
# 0.182
# 0.184
# 0.186
# 0.188
# 0.19
# 0.192
# 0.194
# 0.196
# 0.198
# 0.2
# 0.202
# 0.204
# 0.206
# 0.208
# 0.21
# 0.212
# 0.214
# 0.216
# 0.218
# 0.22
# 0.222
# 0.224
# 0.226
# 0.228
# 0.23
# 0.232
# 0.234
# 0.236
# 0.238
# 0.24
# 0.242
# 0.244
# 0.246
# 0.248
# 0.25
# 0.252
# 0.254
# 0.256
# 0.258
# 0.26
# 0.262
# 0.264
# 0.266
# 0.268
# 0.27
# 0.272
# 0.274
# 0.276
# 0.278
# 0.28
# 0.282
# 0.284
# 0.286
# 0.288
# 0.29
# 0.292
# 0.294
# 0.296
# 0.298
# 0.3
# 0.302
# 0.304
# 0.306
# 0.308
# 0.31
# 0.312
# 0.314
# 0.316
# 0.318
# 0.32
# 0.322
# 0.324
# 0.326
# 0.328
# 0.33
# 0.332
# 0.334
# 0.336
# 0.338
# 0.34
# 0.342
# 0.344
# 0.346
# 0.348
# 0.35
# 0.352
# 0.354
# 0.356
# 0.358
# 0.36
# 0.362
# 0.364
# 0.366
# 0.368
# 0.37
# 0.372
# 0.374
# 0.376
# 0.378
# 0.38
# 0.382
# 0.384
# 0.386
# 0.388
# 0.39
# 0.392
# 0.394
# 0.396
# 0.398
# 0.4
# 0.402
# 0.404
# 0.406
# 0.408
# 0.41
# 0.412
# 0.414
# 0.416
# 0.418
# 0.42
# 0.422
# 0.424
# 0.426
# 0.428
# 0.43
# 0.432
# 0.434
# 0.436
# 0.438
# 0.44
# 0.442
# 0.444
# 0.446
# 0.448
# 0.45
# 0.452
# 0.454
# 0.456
# 0.458
# 0.46
# 0.462
# 0.464
# 0.466
# 0.468
# 0.47
# 0.472
# 0.474
# 0.476
# 0.478
# 0.48
# 0.482
# 0.484
# 0.486
# 0.488
# 0.49
# 0.492
# 0.494
# 0.496
# 0.498
# 0.5
# 0.502
# 0.504
# 0.506
# 0.508
# 0.51
# 0.512
# 0.514
# 0.516
# 0.518
# 0.52
# 0.522
# 0.524
# 0.526
# 0.528
# 0.53
# 0.532
# 0.534
# 0.536
# 0.538
# 0.54
# 0.542
# 0.544
# 0.546
# 0.548
# 0.55
# 0.552
# 0.554
# 0.556
# 0.558
# 0.56
# 0.562
# 0.564
# 0.566
# 0.568
# 0.57
# 0.572
# 0.574
# 0.576
# 0.578
# 0.58
# 0.582
# 0.584
# 0.586
# 0.588
# 0.59
# 0.592
# 0.594
# 0.596
# 0.598
# 0.6
# 0.602
# 0.604
# 0.606
# 0.608
# 0.61
# 0.612
# 0.614
# 0.616
# 0.618
# 0.62
# 0.622
# 0.624
# 0.626
# 0.628
# 0.63
# 0.632
# 0.634
# 0.636
# 0.638
# 0.64
# 0.642
# 0.644
# 0.646
# 0.648
# 0.65
# 0.652
# 0.654
# 0.656
# 0.658
# 0.66
# 0.662
# 0.664
# 0.666
# 0.668
# 0.67
# 0.672
# 0.674
# 0.676
# 0.678
# 0.68
# 0.682
# 0.684
# 0.686
# 0.688
# 0.69
# 0.692
# 0.694
# 0.696
# 0.698
# 0.7
# 0.702
# 0.704
# 0.706
# 0.708
# 0.71
# 0.712
# 0.714
# 0.716
# 0.718
# 0.72
# 0.722
# 0.724
# 0.726
# 0.728
# 0.73
# 0.732
# 0.734
# 0.736
# 0.738
# 0.74
# 0.742
# 0.744
# 0.746
# 0.748
# 0.75
# 0.752
# 0.754
# 0.756
# 0.758
# 0.76
# 0.762
# 0.764
# 0.766
# 0.768
# 0.77
# 0.772
# 0.774
# 0.776
# 0.778
# 0.78
# 0.782
# 0.784
# 0.786
# 0.788
# 0.79
# 0.792
# 0.794
# 0.796
# 0.798
# 0.8
# 0.802
# 0.804
# 0.806
# 0.808
# 0.81
# 0.812
# 0.814
# 0.816
# 0.818
# 0.82
# 0.822
# 0.824
# 0.826
# 0.828
# 0.83
# 0.832
# 0.834
# 0.836
# 0.838
# 0.84
# 0.842
# 0.844
# 0.846
# 0.848
# 0.85
# 0.852
# 0.854
# 0.856
# 0.858
# 0.86
# 0.862
# 0.864
# 0.866
# 0.868
# 0.87
# 0.872
# 0.874
# 0.876
# 0.878
# 0.88
# 0.882
# 0.884
# 0.886
# 0.888
# 0.89
# 0.892
# 0.894
# 0.896
# 0.898
# 0.9
# 0.902
# 0.904
# 0.906
# 0.908
# 0.91
# 0.912
# 0.914
# 0.916
# 0.918
# 0.92
# 0.922
# 0.924
# 0.926
# 0.928
# 0.93
# 0.932
# 0.934
# 0.936
# 0.938
# 0.94
# 0.942
# 0.944
# 0.946
# 0.948
# 0.95
# 0.952
# 0.954
# 0.956
# 0.958
# 0.96
# 0.962
# 0.964
# 0.966
# 0.968
# 0.97
# 0.972
# 0.974
# 0.976
# 0.978
# 0.98
# 0.982
# 0.984
# 0.986
# 0.988
# 0.99
# 0.992
# 0.994
# 0.996
# 0.998

# %%
sum_precision = 0
sum_recall = 0

for i in range(len(test_file_names)):
    print("processing file "+str(i))
    file = test_file_names[i]
    with codecs.open("Queries/"+file.split("\n")[0], 'r', "utf-8") as f:
        query = f.read().replace("\n", " ")
    results = SE.Search(query)
    pre,rec = precision_recall(results, Relevantdocs[i].split("\n")[0])
    sum_precision += pre
    sum_recall += rec
experiment_precision = sum_precision / len(test_file_names)
experiment_recall = sum_recall / len(test_file_names)
# Out:
# processing file 0
# <Top 0 Results for And([Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0622\u0646'), Term('content', u'\u0637\u0628\u06cc\u0628'), Term('content', u'\u0631\u0627'), Term('content', u'\u0628\u0631'), Term('content', u'\u0628\u06cc\u0645\u0627\u0631'), Term('content', u'\u062a\u0627'), Term('content', u'\u062d\u0627\u0644'), Term('content', u'\u0627\u0648'), Term('content', u'\u0628\u0628\u06cc\u0646\u062f'), Term('content', u'\u062e\u0644\u0648\u062a'), Term('content', u'\u0637\u0644\u0628\u06cc\u062f\u0646'), Term('content', u'\u0648\u0644\u06cc'), Term('content', u'\u0627\u0632'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u062f\u0631\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0631\u0646\u062c'), Term('content', u'\u06a9\u0646\u06cc\u0632\u06a9'), Term('content', u'\u0645\u0644\u0627\u0642\u0627\u062a'), Term('content', u'\u0628\u0627'), Term('content', u'\u06a9\u0647'), Term('content', u'\u062f\u0631'), Term('content', u'\u062e\u0648\u0627\u0628\u0634'), Term('content', u'\u0646\u0645\u0648\u062f\u0646\u062f'), Term('content', u'\u0638\u0627\u0647\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0639\u062c\u0632'), Term('content', u'\u062d\u06a9\u06cc\u0645\u0627\u0646'), Term('content', u'\u0645\u0639\u0627\u0644\u062c\u0647'), Term('content', u'\u0631\u0648\u06cc'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u062f\u0631\u06af\u0627\u0647'), Term('content', u'\u0627\u0644\u0647'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0648\u0644\u06cc\u06cc'), Term('content', u'\u0631\u0627\u0639\u0627\u0634\u0642'), Term('content', u'\u0631\u0646\u062c\u0648\u0631'), Term('content', u'\u062a\u062f\u0628\u06cc\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0635\u062d\u062a')]) runtime=0.226071119308>
# processing file 1
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0632\u0647\u0631'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u0632\u0631\u06af\u0631'), Term('content', u'\u0628\u0647'), Term('content', u'\u0627\u0634\u0627\u0631\u062a'), Term('content', u'\u0627\u0644\u0647\u06cc'), Term('content', u'\u0628\u0648\u062f'), Term('content', u'\u0646\u0647'), Term('content', u'\u0647\u0648\u0627\u06cc'), Term('content', u'\u0646\u0641\u0633'), Term('content', u'\u062a\u0627\u0645\u0644'), Term('content', u'\u0641\u0627\u0633\u062f'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0631\u0633\u0648\u0644\u0627\u0646'), Term('content', u'\u0633\u0645\u0631\u0642\u0646\u062f'), Term('content', u'\u0622\u0648\u0631\u062f\u0646')]) runtime=0.0441269874573>
# processing file 2
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0632\u0647\u0631'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u0632\u0631\u06af\u0631'), Term('content', u'\u0628\u0647'), Term('content', u'\u0627\u0634\u0627\u0631\u062a'), Term('content', u'\u0627\u0644\u0647\u06cc'), Term('content', u'\u0628\u0648\u062f'), Term('content', u'\u0646\u0647'), Term('content', u'\u0647\u0648\u0627\u06cc'), Term('content', u'\u0646\u0641\u0633'), Term('content', u'\u062a\u0627\u0645\u0644'), Term('content', u'\u0641\u0627\u0633\u062f'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u0631\u0633\u0648\u0644\u0627\u0646'), Term('content', u'\u0633\u0645\u0631\u0642\u0646\u062f'), Term('content', u'\u0622\u0648\u0631\u062f\u0646')]) runtime=0.0438499450684>
# processing file 3
# <Top 0 Results for And([Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u0628\u0642\u0627\u0644'), Term('content', u'\u0637\u0648\u0637\u06cc'), Term('content', u'\u0631\u0648\u063a\u0646'), Term('content', u'\u0631\u06cc\u062e\u062a\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u062f\u06a9\u0627\u0646')]) runtime=0.0158860683441>
# processing file 4
# <Top 0 Results for And([Term('content', u'\u062f\u0627\u0633\u062a\u0627\u0646'), Term('content', u'\u0622\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647'), Term('content', u'\u062c\u0647\u0648\u062f'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0646\u0635\u0631\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u0645\u06cc'), Term('content', u'\u06a9\u0634\u062a'), Term('content', u'\u0627\u0632'), Term('content', u'\u0628\u0647\u0631'), Term('content', u'\u062a\u0639\u0635\u0628'), Term('content', u'\u0622\u0645\u0648\u062e\u062a\u0646'), Term('content', u'\u0648\u0632\u06cc\u0631'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u062a\u0644\u0628\u06cc\u0633'), Term('content', u'\u0628\u0627\u0646\u0635\u0627\u0631\u06cc'), Term('content', u'\u0642\u0628\u0648\u0644'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0646\u0635\u0627\u0631\u06cc'), Term('content', u'\u0645\u062a\u0627\u0628\u0639\u062a'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u062d\u0633\u062f'), Term('content', u'\u0641\u0647\u0645'), Term('content', u'\u062d\u0627\u0630\u0642\u0627\u0646'), Term('content', u'\u067e\u06cc\u063a\u0627\u0645'), Term('content', u'\u0634\u0627\u0647'), Term('content', u'\u067e\u0646\u0647\u0627\u0646'), Term('content', u'\u0628\u0627'), Term('content', u'\u062f\u0648\u0627\u0632\u062f\u0647'), Term('content', u'\u0633\u0628\u0637'), Term('content', u'\u062a\u062e\u0644\u06cc\u0637'), Term('content', u'\u062f\u0631'), Term('content', u'\u0627\u062d\u06a9\u0627\u0645'), Term('content', u'\u0627\u0646\u062c\u06cc\u0644'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u0627\u06cc\u0646'), Term('content', u'\u0627\u062e\u062a\u0644\u0627\u0641\u0627\u062a'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0631\u0648\u0634'), Term('content', u'\u0627\u0633\u062a'), Term('content', u'\u0646\u06cc'), Term('content', u'\u062d\u0642\u06cc\u0642\u062a'), Term('content', u'\u0631\u0627\u0647')]) runtime=0.218152999878>
# processing file 5
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u062e\u0633\u0627\u0631\u062a'), Term('content', u'\u0648\u0632\u06cc\u0631'), Term('content', u'\u062f\u0631\u06cc\u0646'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u062f\u06cc\u06af\u0631'), Term('content', u'\u0627\u0646\u06af\u06cc\u062e\u062a\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u0627\u0636\u0644\u0627\u0644'), Term('content', u'\u0642\u0648\u0645'), Term('content', u'\u062f\u0641\u0639'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0645\u0631\u06cc\u062f\u0627\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u062e\u0644\u0648\u062a'), Term('content', u'\u0628\u0634\u06a9\u0646'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u0646\u0645\u06cc'), Term('content', u'\u0634\u06a9\u0646\u0645'), Term('content', u'\u0627\u0639\u062a\u0631\u0627\u0636'), Term('content', u'\u0646\u0648\u0645\u06cc\u062f'), Term('content', u'\u0627\u0632'), Term('content', u'\u0631\u0641\u0636'), Term('content', u'\u0648\u0644\u06cc'), Term('content', u'\u0639\u0647\u062f'), Term('content', u'\u0633\u0627\u062e\u062a\u0646'), Term('content', u'\u0647\u0631'), Term('content', u'\u06cc\u06a9'), Term('content', u'\u0627\u0645\u06cc\u0631'), Term('content', u'\u062c\u062f\u0627\u062c\u062f\u0627'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u062e\u0648\u06cc\u0634\u062a\u0646')]) runtime=0.096715927124>
# processing file 6
# <Top 0 Results for And([Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u062a\u0648\u06a9\u0644'), Term('content', u'\u062a\u0631\u06a9'), Term('content', u'\u062c\u0647\u062f'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0646\u062e\u0686\u06cc\u0631\u0627\u0646'), Term('content', u'\u0628\u0634\u06cc\u0631'), Term('content', u'\u062a\u0631\u062c\u06cc\u062d'), Term('content', u'\u0646\u0647\u0627\u062f\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u0628\u0631'), Term('content', u'\u0627\u06a9\u062a\u0633\u0627\u0628'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u062a\u0633\u0644\u06cc\u0645'), Term('content', u'\u0627\u062c\u062a\u0647\u0627\u062f'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0641\u0648\u0627\u06cc\u062f'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0645\u0642\u0631\u0631'), Term('content', u'\u0634\u062f\u0646')]) runtime=0.037474155426>
# processing file 7
# <Top 0 Results for And([Term('content', u'\u0627\u0646\u06a9\u0627\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0646\u062e\u0686\u06cc\u0631\u0627\u0646'), Term('content', u'\u0628\u0631'), Term('content', u'\u062e\u0631\u06af\u0648\u0634'), Term('content', u'\u062f\u0631'), Term('content', u'\u062a\u0627\u062e\u06cc\u0631'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u0627\u0639\u062a\u0631\u0627\u0636'), Term('content', u'\u0633\u062e\u0646'), Term('content', u'\u0630\u06a9\u0631'), Term('content', u'\u062f\u0627\u0646\u0634'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0641\u0636\u06cc\u0644\u062a'), Term('content', u'\u0645\u0646\u0627\u0641\u0639'), Term('content', u'\u062f\u0627\u0646\u0633\u062a\u0646'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0637\u0644\u0628\u06cc\u062f\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u0633\u0631'), Term('content', u'\u0627\u0646\u062f\u06cc\u0634\u0647'), Term('content', u'\u0627\u0648'), Term('content', u'\u0645\u0646\u0639'), Term('content', u'\u0631\u0627\u0632'), Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u0632\u06cc\u0627\u0641\u062a'), Term('content', u'\u062a\u0627\u0648\u06cc\u0644'), Term('content', u'\u0631\u06a9\u06cc\u06a9'), Term('content', u'\u0645\u06af\u0633'), Term('content', u'\u062a\u0648\u0644\u06cc\u062f\u0646'), Term('content', u'\u062f\u06cc\u0631'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0647\u0645'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u0639\u0630\u0631')]) runtime=0.230801820755>
# processing file 8
# <Top 0 Results for And([Term('content', u'\u067e\u0627'), Term('content', u'\u0648\u0627\u067e\u0633'), Term('content', u'\u06a9\u0634\u06cc\u062f\u0646'), Term('content', u'\u062e\u0631\u06af\u0648\u0634'), Term('content', u'\u0627\u0632'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u0686\u0648\u0646'), Term('content', u'\u0646\u0632\u062f\u06cc\u06a9'), Term('content', u'\u0686\u0627\u0647'), Term('content', u'\u0631\u0633\u06cc\u062f'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u067e\u0627\u06cc'), Term('content', u'\u0646\u0638\u0631'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0639\u06a9\u0633'), Term('content', u'\u062e\u0648\u062f'), Term('content', u'\u0631\u0627'), Term('content', u'\u0622\u0646'), Term('content', u'\u0645\u0698\u062f\u0647'), Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u0633\u0648\u06cc'), Term('content', u'\u0646\u062e\u0686\u06cc\u0631\u0627\u0646'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0641\u062a\u0627\u062f'), Term('content', u'\u062c\u0645\u0639'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u06af\u0631\u062f'), Term('content', u'\u062b\u0646\u0627'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0627\u0648'), Term('content', u'\u067e\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0628\u062f\u06cc\u0646'), Term('content', u'\u0634\u0627\u062f'), Term('content', u'\u0645\u0634\u0648\u06cc\u062f')]) runtime=0.237798929214>
# processing file 9
# <Top 0 Results for And([Term('content', u'\u0647\u062f\u0647\u062f'), Term('content', u'\u0633\u0644\u06cc\u0645\u0627\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u0686\u0648\u0646'), Term('content', u'\u0642\u0636\u0627'), Term('content', u'\u0622\u06cc\u062f'), Term('content', u'\u0686\u0634\u0645\u0647\u0627\u06cc'), Term('content', u'\u0631\u0648\u0634\u0646'), Term('content', u'\u0628\u0633\u062a\u0647'), Term('content', u'\u0634\u0648\u062f'), Term('content', u'\u0637\u0639\u0646\u0647'), Term('content', u'\u0632\u0627\u063a'), Term('content', u'\u062f\u0639\u0648\u06cc'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0631\u0627')]) runtime=0.087651014328>
# processing file 10
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0628\u0627\u0632\u0631\u06af\u0627\u0646'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0637\u0648\u0637\u06cc'), Term('content', u'\u0645\u062d\u0628\u0648\u0633'), Term('content', u'\u0627\u0648'), Term('content', u'\u0631\u0627'), Term('content', u'\u067e\u06cc\u063a\u0627\u0645'), Term('content', u'\u062f\u0627\u062f'), Term('content', u'\u0628\u0647'), Term('content', u'\u0637\u0648\u0637\u06cc\u0627\u0646'), Term('content', u'\u0647\u0646\u062f\u0648\u0633\u062a\u0627\u0646'), Term('content', u'\u0647\u0646\u06af\u0627\u0645'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u062a\u062c\u0627\u0631\u062a'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u062e\u0648\u0627\u062c\u0647'), Term('content', u'\u062f\u0631'), Term('content', u'\u062f\u0634\u062a'), Term('content', u'\u0631\u0633\u0627\u0646\u06cc\u062f\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u0622\u0646'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0628\u0627'), Term('content', u'\u0622\u0646\u0686'), Term('content', u'\u062f\u06cc\u062f'), Term('content', u'\u0634\u0646\u06cc\u062f\u0646'), Term('content', u'\u062d\u0631\u06a9\u062a'), Term('content', u'\u0645\u0631\u062f\u0646'), Term('content', u'\u0642\u0641\u0635'), Term('content', u'\u0646\u0648\u062d\u0647'), Term('content', u'\u0628\u0631'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0628\u0631\u0648\u0646'), Term('content', u'\u0627\u0646\u062f\u0627\u062e\u062a\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u062a\u0627\u062c\u0631'), Term('content', u'\u0642\u0641\u0633'), Term('content', u'\u067e\u0631\u06cc\u062f\u0646'), Term('content', u'\u0645\u0631\u062f\u0647'), Term('content', u'\u0648\u062f\u0627\u0639'), Term('content', u'\u06a9\u0631\u062f\u0646')]) runtime=0.216504096985>
# processing file 11
# <Top 0 Results for And([Term('content', u'\u06a9\u0628\u0648\u062f\u06cc'), Term('content', u'\u0632\u062f\u0646'), Term('content', u'\u0642\u0632\u0648\u06cc\u0646\u06cc'), Term('content', u'\u0628\u0631'), Term('content', u'\u0634\u0627\u0646\u0647'), Term('content', u'\u06af\u0627\u0647'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u067e\u0634\u06cc\u0645\u0627\u0646'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0648'), Term('content', u'\u0628\u0647'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u0632\u062e\u0645'), Term('content', u'\u0633\u0648\u0632\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u06af\u0631\u06af'), Term('content', u'\u0631\u0648\u0628\u0627\u0647'), Term('content', u'\u062f\u0631'), Term('content', u'\u062e\u062f\u0645\u062a'), Term('content', u'\u0634\u06a9\u0627\u0631'), Term('content', u'\u0627\u0645\u062a\u062d\u0627\u0646'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u067e\u06cc\u0634'), Term('content', u'\u0622\u06cc'), Term('content', u'\u0627\u06cc'), Term('content', u'\u0628\u062e\u0634'), Term('content', u'\u06a9\u0646'), Term('content', u'\u0635\u06cc\u062f\u0647\u0627'), Term('content', u'\u0645\u06cc\u0627\u0646'), Term('content', u'\u0645\u0627'), Term('content', u'\u0627\u062f\u0628'), Term('content', u'\u0642\u0633\u0645\u062a'), Term('content', u'\u0628\u06cc'), Term('content', u'\u0627\u062f\u0628\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0647'), Term('content', u'\u0628\u0648\u062f')]) runtime=0.245807170868>
# processing file 12
# <Top 0 Results for And([Term('content', u'\u062e\u062f\u0648'), Term('content', u'\u0627\u0646\u062f\u0627\u062e\u062a\u0646'), Term('content', u'\u062e\u0635\u0645'), Term('content', u'\u062f\u0631'), Term('content', u'\u0631\u0648\u06cc'), Term('content', u'\u0627\u0645\u06cc\u0631'), Term('content', u'\u0627\u0644\u0645\u0624\u0645\u0646\u06cc\u0646'), Term('content', u'\u0639\u0644\u06cc'), Term('content', u'\u06a9\u0631\u0645'), Term('content', u'\u0627\u0644\u0644\u0647'), Term('content', u'\u0648\u062c\u0647\u0647'), Term('content', u'\u0627\u0645\u06cc\u0631\u0627\u0644\u0645\u0624\u0645\u0646\u06cc\u0646'), Term('content', u'\u0634\u0645\u0634\u06cc\u0631'), Term('content', u'\u0627\u0632'), Term('content', u'\u062f\u0633\u062a'), Term('content', u'\u0633\u0624\u0627\u0644'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0622\u0646'), Term('content', u'\u06a9\u0627\u0641\u0631'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0628\u0631'), Term('content', u'\u0686\u0648\u0646'), Term('content', u'\u0645\u0646\u06cc'), Term('content', u'\u0645\u0638\u0641\u0631'), Term('content', u'\u0634\u062f\u06cc'), Term('content', u'\u0627\u0646\u062f\u0627\u062e\u062a\u06cc'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u0627\u0641\u06a9\u0646\u062f\u0646'), Term('content', u'\u0686\u0647'), Term('content', u'\u0628\u0648\u062f\u0647'), Term('content', u'\u0627\u0633\u062a'), Term('content', u'\u062d\u0627\u0644\u062a'), Term('content', u'\u067e\u06cc\u063a\u0627\u0645\u0628\u0631'), Term('content', u'\u0635\u0644\u06cc'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0633\u0644\u0645'), Term('content', u'\u0628\u0647'), Term('content', u'\u06af\u0648\u0634'), Term('content', u'\u0631\u06a9\u0627\u0628\u062f\u0627\u0631'), Term('content', u'\u0627\u0644\u0645\u0648\u0645\u0646\u06cc\u0646'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u062a\u0648'), Term('content', u'\u062e\u0648\u0627\u0647\u062f'), Term('content', u'\u0628\u0648\u062f\u0646'), Term('content', u'\u062e\u0628\u0631\u062a'), Term('content', u'\u06a9\u0631\u062f\u0645'), Term('content', u'\u0628\u0627\u0632\u06af\u0634\u062a\u0646'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u0645\u0633\u0627\u0645\u062d\u062a'), Term('content', u'\u0627\u0648'), Term('content', u'\u0628\u0627'), Term('content', u'\u062e\u0648\u0646\u06cc'), Term('content', u'\u062e\u0648\u06cc\u0634'), Term('content', u'\u0627\u0641\u062a\u0627\u062f\u0646'), Term('content', u'\u0647\u0631'), Term('content', u'\u0628\u0627\u0631\u06cc'), Term('content', u'\u067e\u06cc\u0634'), Term('content', u'\u0627\u06cc'), Term('content', u'\u0645\u0631\u0627'), Term('content', u'\u0628\u06a9\u0634'), Term('content', u'\u0627\u0632\u06cc\u0646'), Term('content', u'\u0642\u0636\u0627'), Term('content', u'\u0628\u0631\u0647\u0627\u0646')]) runtime=0.387382030487>
# processing file 13
# <Top 0 Results for And([Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0645\u0635\u0637\u0641\u06cc'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u0628\u0647'), Term('content', u'\u0639\u06cc\u0627\u062f\u062a'), Term('content', u'\u0635\u062d\u0627\u0628\u06cc'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0641\u0627\u06cc\u062f\u0647')]) runtime=0.0124371051788>
# processing file 14
# <Top 0 Results for And([Term('content', u'\u0635\u06cc\u062f'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u06cc\u0631'), Term('content', u'\u0622\u0646'), Term('content', u'\u062e\u0631'), Term('content', u'\u0631\u0627'), Term('content', u'\u062a\u0634\u0646\u0647'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u06a9\u0648\u0634\u0634'), Term('content', u'\u0631\u0641\u062a'), Term('content', u'\u0628\u0647'), Term('content', u'\u0686\u0634\u0645\u0647'), Term('content', u'\u062a\u0627'), Term('content', u'\u0622\u0628'), Term('content', u'\u062e\u0648\u0631\u062f'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062c\u06af\u0631\u0628\u0646\u062f'), Term('content', u'\u062f\u0644'), Term('content', u'\u06af\u0631\u062f\u0647'), Term('content', u'\u0631\u0648\u0628\u0627\u0647'), Term('content', u'\u062e\u0648\u0631\u062f\u0647'), Term('content', u'\u0628\u0648\u062f'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0644\u0637\u06cc\u0641\u062a\u0631\u0633\u062a'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u06a9\u0631\u062f'), Term('content', u'\u062c\u06af\u0631'), Term('content', u'\u0646\u06cc\u0627\u0641\u062a'), Term('content', u'\u0631\u0648\u0628\u0647'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f'), Term('content', u'\u06a9\u0648'), Term('content', u'\u06af\u0641\u062a'), Term('content', u'\u0627\u06af\u0631'), Term('content', u'\u0627\u0648'), Term('content', u'\u0628\u0648\u062f\u06cc'), Term('content', u'\u0622\u0646\u0686\u0646\u0627\u0646'), Term('content', u'\u0633\u06cc\u0627\u0633\u062a\u06cc'), Term('content', u'\u062f\u06cc\u062f\u0647'), Term('content', u'\u0631\u0648\u0632'), Term('content', u'\u0647\u0632\u0627\u0631'), Term('content', u'\u062d\u06cc\u0644\u0647'), Term('content', u'\u062c\u0627\u0646'), Term('content', u'\u0628\u0631\u062f\u0647'), Term('content', u'\u0628\u0631'), Term('content', u'\u062a\u0648'), Term('content', u'\u0622\u0645\u062f\u06cc'), Term('content', u'\u0644\u0648\u06a9\u0646\u0627'), Term('content', u'\u0646\u0633\u0645\u0639'), Term('content', u'\u0646\u0639\u0642\u0644'), Term('content', u'\u0645\u0627\u06a9\u0646\u0627'), Term('content', u'\u0641\u06cc'), Term('content', u'\u0627\u0635\u062d\u0627\u0628'), Term('content', u'\u0627\u0644\u0633\u0639\u06cc\u0631')]) runtime=0.345555067062>
# processing file 15
# <Top 0 Results for And([Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u0622\u0646'), Term('content', u'\u0632\u0646'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u06af\u0641\u062a'), Term('content', u'\u0634\u0648\u0647\u0631'), Term('content', u'\u0631\u0627'), Term('content', u'\u06af\u0648\u0634\u062a'), Term('content', u'\u06af\u0631\u0628\u0647'), Term('content', u'\u062e\u0648\u0631\u062f'), Term('content', u'\u0628\u0647'), Term('content', u'\u062a\u0631\u0627\u0632\u0648'), Term('content', u'\u0628\u0631'), Term('content', u'\u06a9\u0634\u06cc\u062f'), Term('content', u'\u0646\u06cc\u0645'), Term('content', u'\u0645\u0646'), Term('content', u'\u0628\u0631\u0622\u0645\u062f'), Term('content', u'\u0627\u06cc'), Term('content', u'\u0628\u0648\u062f'), Term('content', u'\u0627\u0641\u0632\u0648\u0646'), Term('content', u'\u0627\u06af\u0631'), Term('content', u'\u0627\u06cc\u0646'), Term('content', u'\u06af\u0648\u0634\u062a\u0633\u062a'), Term('content', u'\u06a9\u0648'), Term('content', u'\u0627\u0633\u062a')]) runtime=0.24286198616>
# processing file 16
# <Top 0 Results for And([Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0645\u0631\u062f'), Term('content', u'\u063a\u0645\u0627\u0632'), Term('content', u'\u0646\u0645\u0648\u062f\u0646'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u06a9\u0646\u06cc\u0632\u06a9'), Term('content', u'\u0645\u0635\u0648\u0631'), Term('content', u'\u062f\u0631'), Term('content', u'\u06a9\u0627\u063a\u0630'), Term('content', u'\u0639\u0627\u0634\u0642'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u062e\u0644\u06cc\u0641\u0647'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0628\u0631'), Term('content', u'\u0622\u0646'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0627\u0645\u06cc\u0631\u06cc'), Term('content', u'\u0631\u0627'), Term('content', u'\u0628\u0627'), Term('content', u'\u0633\u067e\u0627\u0647'), Term('content', u'\u06af\u0631\u0627\u0646'), Term('content', u'\u0628\u062f\u0631'), Term('content', u'\u0645\u0648\u0635\u0644'), Term('content', u'\u0642\u062a\u0644'), Term('content', u'\u0648\u06cc\u0631\u0627\u0646\u06cc'), Term('content', u'\u0628\u0633\u06cc\u0627\u0631'), Term('content', u'\u0628\u0647\u0631'), Term('content', u'\u0627\u06cc\u0646'), Term('content', u'\u063a\u0631\u0636'), Term('content', u'\u0627\u06cc\u062b\u0627\u0631'), Term('content', u'\u0635\u0627\u062d\u0628'), Term('content', u'\u0628\u062f\u06cc\u0646'), Term('content', u'\u062a\u0627'), Term('content', u'\u062e\u0648\u0646'), Term('content', u'\u0631\u06cc\u0632'), Term('content', u'\u0645\u0633\u0644\u0645\u0627\u0646\u0627\u0646'), Term('content', u'\u0628\u06cc\u0634\u062a\u0631'), Term('content', u'\u0646\u0634\u0648\u062f'), Term('content', u'\u067e\u0634\u06cc\u0645\u0627\u0646'), Term('content', u'\u0633\u0631\u0644\u0634\u06a9\u0631'), Term('content', u'\u0627\u0632'), Term('content', u'\u062e\u06cc\u0627\u0646\u062a'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u06a9\u0631\u062f'), Term('content', u'\u0633\u0648\u06af\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0627\u0648'), Term('content', u'\u0628\u0647'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0646\u06af\u0648\u06cc\u062f'), Term('content', u'\u0622\u0646\u0686'), Term('content', u'\u0631\u0641\u062a'), Term('content', u'\u062d\u062c\u062a'), Term('content', u'\u0645\u0646\u06a9\u0631\u0627\u0646'), Term('content', u'\u0622\u062e\u0631\u062a'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0636\u0639\u0641'), Term('content', u'\u0632\u06cc\u0631\u0627'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u062f\u06cc\u0646'), Term('content', u'\u0645\u06cc'), Term('content', u'\u06af\u0631\u062f\u062f'), Term('content', u'\u063a\u06cc\u0631'), Term('content', u'\u0646\u0645\u06cc'), Term('content', u'\u0628\u06cc\u0646\u06cc\u0645'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u062e\u0648\u0628'), Term('content', u'\u0631\u0648\u06cc'), Term('content', u'\u0628\u0631\u0627\u06cc'), Term('content', u'\u062c\u0645\u0627\u0639'), Term('content', u'\u062e\u0646\u062f\u0647'), Term('content', u'\u06af\u0631\u0641\u062a\u0646'), Term('content', u'\u0634\u0647\u0648\u062a'), Term('content', u'\u0642\u0648\u062a'), Term('content', u'\u0627\u0645\u06cc\u0631'), Term('content', u'\u0641\u0647\u0645'), Term('content', u'\u0641\u0627\u0634'), Term('content', u'\u0631\u0627\u0632'), Term('content', u'\u0632\u062e\u0645'), Term('content', u'\u0634\u0645\u0634\u06cc\u0631'), Term('content', u'\u0627\u06a9\u0631\u0627\u0647'), Term('content', u'\u0631\u0627\u0633\u062a'), Term('content', u'\u06af\u0648'), Term('content', u'\u0633\u0628\u0628'), Term('content', u'\u06af\u0631'), Term('content', u'\u0646\u0647'), Term('content', u'\u0628\u06a9\u0634\u0645\u062a')]) runtime=0.433156013489>
# processing file 17
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0647\u062f\u0647\u062f'), Term('content', u'\u0633\u0644\u06cc\u0645\u0627\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u0686\u0648\u0646'), Term('content', u'\u0642\u0636\u0627'), Term('content', u'\u0622\u06cc\u062f'), Term('content', u'\u0686\u0634\u0645\u0647\u0627\u06cc'), Term('content', u'\u0631\u0648\u0634\u0646'), Term('content', u'\u0628\u0633\u062a\u0647'), Term('content', u'\u0634\u0648\u062f'), Term('content', u'\u0637\u0639\u0646\u0647'), Term('content', u'\u0632\u0627\u063a'), Term('content', u'\u062f\u0639\u0648\u06cc'), Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0631\u0627')]) runtime=0.0778019428253>
# processing file 18
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u062e\u0648\u0631\u0646\u062f\u06af\u0627\u0646'), Term('content', u'\u067e\u06cc\u0644'), Term('content', u'\u0628\u0686\u0647'), Term('content', u'\u0627\u0632'), Term('content', u'\u062d\u0631\u0635'), Term('content', u'\u062a\u0631\u06a9'), Term('content', u'\u0646\u0635\u06cc\u062d\u062a'), Term('content', u'\u0646\u0627\u0635\u062d'), Term('content', u'\u0628\u0642\u06cc\u0647'), Term('content', u'\u0645\u062a\u0639\u0631\u0636\u0627\u0646'), Term('content', u'\u0628\u0686\u06af\u0627\u0646'), Term('content', u'\u0628\u0627\u0632\u06af\u0634\u062a\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a')]) runtime=0.0282559394836>
# processing file 19
# <Top 0 Results for And([Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0627\u0647\u0644'), Term('content', u'\u0633\u0628\u0627'), Term('content', u'\u0637\u0627\u063a\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0646\u0639\u0645\u062a'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u062f\u0631'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0634\u0648\u0645\u06cc'), Term('content', u'\u0637\u063a\u06cc\u0627\u0646'), Term('content', u'\u06a9\u0641\u0631\u0627\u0646'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0641\u0636\u06cc\u0644\u062a'), Term('content', u'\u0634\u06a9\u0631'), Term('content', u'\u0648\u0641\u0627'), Term('content', u'\u062c\u0645\u0639'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0622\u0641\u062a'), Term('content', u'\u0647\u0631'), Term('content', u'\u0635\u0628\u0627\u062d\u06cc'), Term('content', u'\u0628\u0631'), Term('content', u'\u0635\u0648\u0645\u0639\u0647'), Term('content', u'\u0639\u06cc\u0633\u06cc'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u0634\u0641\u0627'), Term('content', u'\u0628\u0647'), Term('content', u'\u062f\u0639\u0627\u06cc'), Term('content', u'\u0627\u0648'), Term('content', u'\u0628\u0627\u0642\u06cc')]) runtime=0.108058929443>
# processing file 20
# <Top 0 Results for And([Term('content', u'\u067e\u0630\u06cc\u0631\u0627'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0633\u062e\u0646'), Term('content', u'\u0628\u0627\u0637\u0644'), Term('content', u'\u062f\u0631'), Term('content', u'\u062f\u0644'), Term('content', u'\u0628\u0627\u0637\u0644\u0627\u0646'), Term('content', u'\u062c\u0633\u062a\u0646'), Term('content', u'\u0622\u0646'), Term('content', u'\u062f\u0631\u062e\u062a'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0647\u0631'), Term('content', u'\u06a9\u0647'), Term('content', u'\u0645\u06cc\u0648\u0647'), Term('content', u'\u062e\u0648\u0631\u062f'), Term('content', u'\u0646\u0645\u06cc\u0631\u062f'), Term('content', u'\u0634\u0631\u062d'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u06cc\u062e'), Term('content', u'\u0633\u0631'), Term('content', u'\u0628\u0627'), Term('content', u'\u0637\u0627\u0644\u0628'), Term('content', u'\u0645\u0642\u0644\u062f')]) runtime=0.133988857269>
# processing file 21
# <Top 0 Results for And([Term('content', u'\u0628\u0642\u06cc\u0647'), Term('content', u'\u062f\u0627\u0633\u062a\u0627\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u062e\u0648\u0627\u062c\u0647'), Term('content', u'\u0628\u0647'), Term('content', u'\u062f\u0639\u0648\u062a'), Term('content', u'\u0631\u0648\u0633\u062a\u0627\u06cc\u06cc'), Term('content', u'\u0633\u0648\u06cc'), Term('content', u'\u062f\u0647'), Term('content', u'\u0631\u0648\u0627\u0646'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0642\u0648\u0645\u0634'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0627\u062f\u06cc\u062f\u0647'), Term('content', u'\u0646\u0627\u0634\u0646\u0627\u062e\u062a\u0647'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0631\u0627')]) runtime=0.0429859161377>
# processing file 22
# <Top 0 Results for And([Term('content', u'\u0628\u0642\u06cc\u0647'), Term('content', u'\u0639\u0645\u0627\u0631\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0633\u0644\u06cc\u0645\u0627\u0646'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u0645\u0633\u062c\u062f'), Term('content', u'\u0627\u0642\u0635\u06cc'), Term('content', u'\u0631\u0627'), Term('content', u'\u0628\u0647'), Term('content', u'\u062a\u0639\u0644\u06cc\u0645'), Term('content', u'\u0648\u062d\u06cc'), Term('content', u'\u062e\u062f\u0627'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u062d\u06a9\u0645\u062a\u0647\u0627\u06cc\u06cc'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0627\u0648'), Term('content', u'\u062f\u0627\u0646\u062f'), Term('content', u'\u0645\u0639\u0627\u0648\u0646\u062a'), Term('content', u'\u0645\u0644\u0627\u06cc\u06a9\u0647'), Term('content', u'\u062f\u06cc\u0648'), Term('content', u'\u067e\u0631\u06cc'), Term('content', u'\u0622\u062f\u0645\u06cc'), Term('content', u'\u0622\u0634\u06a9\u0627\u0631\u0627'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0628\u0631'), Term('content', u'\u0645\u0642\u0627\u0645'), Term('content', u'\u062a\u0634\u0628\u0647'), Term('content', u'\u06a9\u0627\u0631\u0647\u0627\u06cc'), Term('content', u'\u0641\u0631\u0642'), Term('content', u'\u0638\u0627\u0647\u0631'), Term('content', u'\u0645\u06cc\u0627\u0646'), Term('content', u'\u0647\u0631'), Term('content', u'\u062f\u0648'), Term('content', u'\u062e\u0648\u06cc\u0634\u062a\u0646'), Term('content', u'\u0628\u0646'), Term('content', u'\u062f\u0627\u0648\u062f'), Term('content', u'\u0646\u0627\u0645'), Term('content', u'\u062f\u0631\u0622\u0645\u062f\u0646'), Term('content', u'\u0631\u0648\u0632'), Term('content', u'\u062f\u0631'), Term('content', u'\u0628\u0639\u062f'), Term('content', u'\u0627\u0632'), Term('content', u'\u062a\u0645\u0627\u0645'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0639\u0628\u0627\u062f\u062a'), Term('content', u'\u0627\u0631\u0634\u0627\u062f'), Term('content', u'\u0639\u0627\u0628\u062f\u0627\u0646'), Term('content', u'\u0645\u0639\u062a\u06a9\u0641\u0627\u0646'), Term('content', u'\u0631\u0633\u062a\u0646'), Term('content', u'\u0639\u0642\u0627\u0642\u06cc\u0631'), Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u062e\u0631\u0648\u0628'), Term('content', u'\u06af\u0648\u0634\u0647'), Term('content', u'\u063a\u0645\u06af\u06cc\u0646'), Term('content', u'\u0622\u0646'), Term('content', u'\u0686\u0648\u0646'), Term('content', u'\u0633\u062e\u0646'), Term('content', u'\u0622\u0645\u062f'), Term('content', u'\u0628\u0627'), Term('content', u'\u062e\u0627\u0635\u06cc\u062a'), Term('content', u'\u062e\u0648\u062f'), Term('content', u'\u0628\u06af\u0641\u062a'), Term('content', u'\u0628\u06cc\u0627\u0646'), Term('content', u'\u0622\u0646\u06a9'), Term('content', u'\u062d\u0635\u0648\u0644'), Term('content', u'\u0639\u0644\u0645'), Term('content', u'\u0645\u0627\u0644'), Term('content', u'\u062c\u0627\u0647'), Term('content', u'\u0628\u062f\u06af\u0648\u0647\u0631\u0627\u0646'), Term('content', u'\u0641\u0636\u06cc\u062d\u062a'), Term('content', u'\u0627\u0648\u0633\u062a'), Term('content', u'\u0634\u0645\u0634\u06cc\u0631\u06cc\u0633\u062a'), Term('content', u'\u0627\u0641\u062a\u0627\u062f\u0633\u062a'), Term('content', u'\u062f\u0633\u062a'), Term('content', u'\u0631\u0627\u0647'), Term('content', u'\u0632\u0646')]) runtime=0.351254940033>
# processing file 23
# <Top 0 Results for And([Term('content', u'\u0639\u0634\u0631\u062a'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u062f\u0631'), Term('content', u'\u0645\u0631\u063a\u0632\u0627\u0631'), Term('content', u'\u0633\u06cc\u0627\u0633\u062a'), Term('content', u'\u0647\u0631\u0645\u0632'), Term('content', u'\u0634\u0641\u06cc\u0639'), Term('content', u'\u0627\u0646\u06af\u06cc\u062e\u062a\u0646'), Term('content', u'\u067e\u06cc\u0631\u0627\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u067e\u06cc\u0634'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u0628\u0647'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u0646\u06cc\u0627\u06cc'), Term('content', u'\u062e\u0648\u06cc\u0634'), Term('content', u'\u0627\u0646\u0648\u0634\u06cc\u0631\u0648\u0627\u0646'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u0627\u067e\u0648\u0631'), Term('content', u'\u0627\u0632'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u0634\u0628\u062f\u06cc\u0632'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0627\u0631\u0645\u0646'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u0646\u0645\u0648\u062f\u0646'), Term('content', u'\u0635\u0648\u0631\u062a'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u0627\u0648\u0644'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0633\u0648\u0645'), Term('content', u'\u067e\u06cc\u062f\u0627'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u062a\u0631\u062a\u06cc\u0628'), Term('content', u'\u06a9\u0648\u0634\u06a9'), Term('content', u'\u0628\u0631\u0627\u06cc'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u0645\u0647\u06cc\u0646'), Term('content', u'\u0628\u0627\u0646\u0648'), Term('content', u'\u0645\u062c\u0644\u0633'), Term('content', u'\u0628\u0632\u0645'), Term('content', u'\u0628\u0627\u0632'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062f\u06cc\u06af\u0631'), Term('content', u'\u0622\u06af\u0627\u0647\u06cc'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u0628\u0631'), Term('content', u'\u062a\u062e\u062a'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0628\u062c\u0627\u06cc'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u06af\u0631\u06cc\u062e\u062a\u0646'), Term('content', u'\u0628\u0647\u0631\u0627\u0645'), Term('content', u'\u0686\u0648\u0628\u06cc\u0646')]) runtime=0.15687084198>
# processing file 24
# <Top 0 Results for And([Term('content', u'\u06af\u0631\u06cc\u062e\u062a\u0646'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u0645\u0647\u06cc\u0646'), Term('content', u'\u0628\u0627\u0646\u0648'), Term('content', u'\u0628\u0647'), Term('content', u'\u0645\u062f\u0627\u06cc\u0646'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0631\u0627'), Term('content', u'\u062f\u0631'), Term('content', u'\u0686\u0634\u0645\u0647'), Term('content', u'\u0633\u0627\u0631'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0645\u0634\u06af\u0648\u06cc'), Term('content', u'\u0628\u0647\u0645'), Term('content', u'\u0634\u06a9\u0627\u0631\u06af\u0627\u0647'), Term('content', u'\u0627\u0646\u062f\u0631\u0632'), Term('content', u'\u0633\u0648\u06af\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0628\u0647\u0627\u0631'), Term('content', u'\u0639\u06cc\u0634'), Term('content', u'\u0634\u06cc\u0631\u06a9\u0634\u062a\u0646'), Term('content', u'\u0628\u0632\u0645\u06af\u0627\u0647'), Term('content', u'\u0627\u0641\u0633\u0627\u0646\u0647'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0634\u0627\u067e\u0648\u0631'), Term('content', u'\u062f\u062e\u062a\u0631\u0627\u0646'), Term('content', u'\u0633\u0631\u0627\u0626\u06cc'), Term('content', u'\u062f\u0647'), Term('content', u'\u062f\u062e\u062a\u0631'), Term('content', u'\u0645\u0631\u0627\u062f'), Term('content', u'\u0637\u0644\u0628\u06cc\u062f\u0646'), Term('content', u'\u0645\u0627\u0646\u0639'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0648'), Term('content', u'\u062e\u0634\u0645'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u067e\u06cc\u0634'), Term('content', u'\u0631\u0648\u0645'), Term('content', u'\u067e\u06cc\u0648\u0646\u062f'), Term('content', u'\u0628\u0627'), Term('content', u'\u0645\u0631\u06cc\u0645'), Term('content', u'\u062c\u0646\u06af'), Term('content', u'\u0628\u0647\u0631\u0627\u0645'), Term('content', u'\u0628\u0631'), Term('content', u'\u062a\u062e\u062a'), Term('content', u'\u0646\u0634\u0633\u062a\u0646'), Term('content', u'\u0645\u062f\u0627\u0626\u0646'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0646\u0627\u0644\u06cc\u062f\u0646'), Term('content', u'\u062c\u062f\u0627\u0626\u06cc'), Term('content', u'\u0648\u0635\u06cc\u062a'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u067e\u0627\u062f\u0634\u0627\u0647\u06cc'), Term('content', u'\u062c\u0627\u06cc'), Term('content', u'\u0622\u06af\u0647\u06cc'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u0686\u0648\u0628\u06cc\u0646'), Term('content', u'\u0628\u0632\u0645'), Term('content', u'\u0622\u0631\u0627\u0626\u06cc'), Term('content', u'\u0634\u0641\u0627\u0639\u062a'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0637\u0644\u0628')]) runtime=0.20050907135>
# processing file 25
# <Top 0 Results for And([Term('content', u'\u0632\u0627\u0631\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0641\u0631\u0647\u0627\u062f'), Term('content', u'\u0627\u0632'), Term('content', u'\u0639\u0634\u0642'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u0622\u06af\u0627\u0647\u06cc'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0631\u0627\u06cc'), Term('content', u'\u0632\u062f\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u06a9\u0627\u0631'), Term('content', u'\u0645\u0646\u0627\u0638\u0631\u0647'), Term('content', u'\u0628\u0627'), Term('content', u'\u06a9\u0648\u0647'), Term('content', u'\u06a9\u0646\u062f\u0646'), Term('content', u'\u0627\u0648'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u0628\u06cc\u0633\u062a\u0648\u0646'), Term('content', u'\u0633\u0642\u0637'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0633\u0628'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0646\u0632\u062f'), Term('content', u'\u06a9\u0634\u062a\u0646'), Term('content', u'\u0645\u06a9\u0631')]) runtime=0.135005950928>
# processing file 26
# <Top 0 Results for And([Term('content', u'\u0628\u0627\u0632\u06af\u0634\u062a\u0646'), Term('content', u'\u062e\u0633\u0631\u0648'), Term('content', u'\u0627\u0632'), Term('content', u'\u0642\u0635\u0631'), Term('content', u'\u0634\u06cc\u0631\u06cc\u0646'), Term('content', u'\u067e\u0634\u06cc\u0645\u0627\u0646'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u063a\u0632\u0644'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0646\u06a9\u06cc\u0633\u0627'), Term('content', u'\u0632\u0628\u0627\u0646'), Term('content', u'\u0633\u0631\u0648\u062f'), Term('content', u'\u0628\u0627\u0631\u0628\u062f'), Term('content', u'\u0646\u06cc\u06a9\u0633\u0627'), Term('content', u'\u0628\u06cc\u0631\u0648\u0646'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062e\u0631\u06af\u0627\u0647')]) runtime=0.0237021446228>
# processing file 27
# <Top 0 Results for And([Term('content', u'\u0639\u0627\u0634\u0642'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u06cc\u06a9\u062f\u06cc\u06af\u0631'), Term('content', u'\u062f\u0631'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0639\u0634\u0642'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u062e\u0648\u0627\u0633\u062a\u0627\u0631\u06cc'), Term('content', u'\u0632\u0627\u0631\u06cc'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u062e\u0627\u0646\u0647'), Term('content', u'\u06a9\u0639\u0628\u0647'), Term('content', u'\u067e\u0646\u062f'), Term('content', u'\u062f\u0627\u062f\u0646')]) runtime=0.0804288387299>
# processing file 28
# <Top 0 Results for And([Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0646\u0648\u0641\u0644'), Term('content', u'\u0628\u0647'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u062c\u0646\u06af'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0628\u0627'), Term('content', u'\u0642\u0628\u06cc\u0644\u0647'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0639\u062a\u0627\u0628'), Term('content', u'\u0645\u0635\u0627\u0641'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0631\u0647\u0627\u0646\u06cc\u062f\u0646'), Term('content', u'\u0622\u0647\u0648\u0627\u0646'), Term('content', u'\u0631\u0627')]) runtime=0.0411520004272>
# processing file 29
# ...
# processing file 37
# <Top 0 Results for And([Term('content', u'\u062f\u0631'), Term('content', u'\u0635\u0641\u062a'), Term('content', u'\u0632\u06cc\u0628\u0627\u06cc\u06cc'), Term('content', u'\u0632\u0644\u06cc\u062e\u0627'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u0631\u0627'), Term('content', u'\u0628\u06cc\u062f\u0627\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u0646\u0647\u0641\u062a\u0646'), Term('content', u'\u0627\u0646\u062f\u0648\u0647'), Term('content', u'\u062e\u0648\u062f'), Term('content', u'\u067e\u0631\u0633\u062a\u0627\u0631\u0627\u0646'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u062f\u0627\u06cc\u0647'), Term('content', u'\u062d\u0627\u0644'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0628\u0647'), Term('content', u'\u0633\u0648\u0645'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0631\u0633\u0648\u0644\u0627\u0646'), Term('content', u'\u0634\u0627\u0647\u0627\u0646'), Term('content', u'\u0686\u0646\u062f\u06cc\u0646'), Term('content', u'\u06a9\u0634\u0648\u0631'), Term('content', u'\u062e\u0648\u0627\u0633\u062a\u06af\u0627\u0631\u06cc'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0631\u0633\u0648\u0644'), Term('content', u'\u0633\u0648\u06cc'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u062c\u0627\u0646\u0628'), Term('content', u'\u0639\u0632\u06cc\u0632'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0634\u06a9\u0627\u0641'), Term('content', u'\u062e\u06cc\u0645\u0647'), Term('content', u'\u062f\u0631\u0622\u0645\u062f\u0646'), Term('content', u'\u0646\u062b\u0627\u0631'), Term('content', u'\u0627\u0641\u0634\u0627\u0646\u062f\u0646'), Term('content', u'\u0645\u0635\u0631\u06cc\u0627\u0646'), Term('content', u'\u0628\u0631'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0639\u0645\u0631'), Term('content', u'\u06af\u0630\u0631\u0627\u0646\u062f\u0646'), Term('content', u'\u0645\u0641\u0627\u0631\u0642\u062a')]) runtime=0.15943813324>
# processing file 38
# <Top 0 Results for And([Term('content', u'\u0622\u063a\u0627\u0632'), Term('content', u'\u062d\u0633\u062f\u0628\u0631\u062f\u0646'), Term('content', u'\u0628\u0631\u0627\u062f\u0631\u0627\u0646'), Term('content', u'\u0628\u0631'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u06a9\u0647'), Term('content', u'\u0622\u0641\u062a\u0627\u0628'), Term('content', u'\u0645\u0627\u0647'), Term('content', u'\u06cc\u0627\u0632\u062f\u0647'), Term('content', u'\u0633\u062a\u0627\u0631\u0647'), Term('content', u'\u0627\u0648'), Term('content', u'\u0631\u0627'), Term('content', u'\u0633\u062c\u062f\u0647'), Term('content', u'\u0645\u06cc'), Term('content', u'\u0628\u0631\u0646\u062f'), Term('content', u'\u062f\u0631\u062e\u0648\u0627\u0633\u062a'), Term('content', u'\u0627\u0632'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0628\u0627'), Term('content', u'\u062e\u0648\u062f'), Term('content', u'\u0628\u0647'), Term('content', u'\u0635\u062d\u0631\u0627'), Term('content', u'\u0628\u0631\u062f\u0646'), Term('content', u'\u062c\u0627\u0647'), Term('content', u'\u0627\u0641\u06af\u0646\u062f\u0646\u0634'), Term('content', u'\u0628\u06cc\u0631\u0648\u0646'), Term('content', u'\u0622\u0648\u0631\u062f\u0646'), Term('content', u'\u06a9\u0627\u0631\u0648\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u0686\u0627\u0647'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u062a\u0645\u0646\u0627'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0634\u0628\u0627\u0646\u06cc')]) runtime=0.224760770798>
# processing file 39
# <Top 0 Results for And([Term('content', u'\u0634\u0631\u062d'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u0642\u0635\u0647'), Term('content', u'\u0645\u062d\u0646\u062a'), Term('content', u'\u0631\u0627\u0647'), Term('content', u'\u0632\u062d\u0645\u062a'), Term('content', u'\u0686\u0627\u0647'), Term('content', u'\u0631\u0627'), Term('content', u'\u0628\u0631\u0627\u06cc'), Term('content', u'\u0632\u0644\u06cc\u062e\u0627'), Term('content', u'\u062f\u06cc\u062f\u0646'), Term('content', u'\u062e\u0631\u06cc\u062f\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u0627\u0636\u0639\u0627\u0641'), Term('content', u'\u062f\u0631'), Term('content', u'\u062d\u0631\u0627\u062c'), Term('content', u'\u062e\u062f\u0645\u062a\u06af\u0627\u0631\u06cc'), Term('content', u'\u0646\u0645\u0648\u062f\u0646'), Term('content', u'\u0645\u0637\u0627\u0644\u0628\u0647'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0648\u0635\u0627\u0644'), Term('content', u'\u0627\u0633\u062a\u063a\u0646\u0627'), Term('content', u'\u0627\u0632'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0628\u0627\u063a'), Term('content', u'\u0639\u0631\u0636\u0647'), Term('content', u'\u06a9\u0646\u06cc\u0632\u0627\u0646'), Term('content', u'\u062c\u0645\u0627\u0644'), Term('content', u'\u062e\u0648\u06cc\u0634'), Term('content', u'\u0628\u0631'), Term('content', u'\u06cc\u06a9\u062a\u0627\u067e\u0631\u0633\u062a'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u062a\u0636\u0631\u0639'), Term('content', u'\u067e\u06cc\u0634'), Term('content', u'\u062f\u0627\u06cc\u0647'), Term('content', u'\u0631\u0627\u0647\u0646\u0645\u0627\u06cc\u06cc'), Term('content', u'\u0627\u0648'), Term('content', u'\u0633\u0627\u062e\u062a\u0646'), Term('content', u'\u0639\u0645\u0627\u0631\u062a'), Term('content', u'\u0648\u0635\u0641'), Term('content', u'\u0622\u0631\u0627\u06cc\u0634'), Term('content', u'\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0639\u0632\u06cc\u0632'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0647\u0645\u0627\u0646'), Term('content', u'\u062f\u0645'), Term('content', u'\u0633\u0627\u0644'), Term('content', u'\u06af\u0648\u0627\u0647\u06cc'), Term('content', u'\u0637\u0641\u0644'), Term('content', u'\u0634\u06cc\u0631\u062e\u0648\u0627\u0631\u0647'), Term('content', u'\u0628\u06cc'), Term('content', u'\u06af\u0646\u0627\u0647\u06cc'), Term('content', u'\u0632\u0628\u0627\u0646'), Term('content', u'\u0637\u0639\u0646\u0647'), Term('content', u'\u06af\u0634\u0627\u062f\u0646'), Term('content', u'\u0632\u0646\u0627\u0646'), Term('content', u'\u062a\u06cc\u063a'), Term('content', u'\u063a\u06cc\u0631\u062a'), Term('content', u'\u0639\u0634\u0642'), Term('content', u'\u062f\u0633\u062a'), Term('content', u'\u0628\u0631\u06cc\u062f\u0646')]) runtime=0.238229036331>
# processing file 40
# <Top 0 Results for And([Term('content', u'\u0628\u0647'), Term('content', u'\u0632\u0646\u062f\u0627\u0646'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u06cc\u0648\u0633\u0641'), Term('content', u'\u0627\u062d\u0633\u0627\u0646'), Term('content', u'\u0632\u0646\u062f\u0627\u0646\u06cc\u0627\u0646'), Term('content', u'\u062a\u0639\u0628\u06cc\u0631'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u0627\u06cc\u0634\u0627\u0646'), Term('content', u'\u0634\u0627\u0647'), Term('content', u'\u0645\u0635\u0631'), Term('content', u'\u0631\u0627'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0628\u06cc\u0631\u0648\u0646'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u0648\u0641\u0627\u062a'), Term('content', u'\u0639\u0632\u06cc\u0632'), Term('content', u'\u062a\u0646\u0647\u0627\u06cc\u06cc'), Term('content', u'\u0632\u0644\u06cc\u062e\u0627'), Term('content', u'\u0627\u0628\u062a\u0644\u0627\u06cc'), Term('content', u'\u0645\u062d\u0646\u062a'), Term('content', u'\u0641\u0631\u0627\u0642'), Term('content', u'\u0628\u0639\u062f'), Term('content', u'\u0627\u0644\u062a\u0641\u0627\u062a'), Term('content', u'\u0646\u06a9\u0631\u062f\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u06a9\u0641\u0631'), Term('content', u'\u0648\u06cc'), Term('content', u'\u067e\u0633'), Term('content', u'\u062a\u0648\u062d\u06cc\u062f'), Term('content', u'\u0639\u0642\u062f'), Term('content', u'\u0646\u06a9\u0627\u062d'), Term('content', u'\u0628\u0633\u062a\u0646'), Term('content', u'\u0628\u0627'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0647\u0644\u0627\u06a9'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0645\u0641\u0627\u0631\u0642\u062a')]) runtime=0.157819986343>
# processing file 41
# <Top 0 Results for And([Term('content', u'\u0646\u0627\u0645\u0647'), Term('content', u'\u0646\u0648\u0634\u062a\u0646'), Term('content', u'\u0644\u06cc\u0644\u06cc'), Term('content', u'\u0628\u0647'), Term('content', u'\u0645\u062c\u0646\u0648\u0646'), Term('content', u'\u0628\u06cc\u0645\u0627\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0634\u0648\u0647\u0631'), Term('content', u'\u0648\u0641\u0627\u062a'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0648\u06cc'), Term('content', u'\u0634\u06a9\u0633\u062a\u0646'), Term('content', u'\u06a9\u0627\u0633\u0647'), Term('content', u'\u0631\u0627'), Term('content', u'\u0631\u0642\u0635'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0627\u0632'), Term('content', u'\u0630\u0648\u0642'), Term('content', u'\u0622\u0646'), Term('content', u'\u0627\u06af\u0631'), Term('content', u'\u0628\u0627'), Term('content', u'\u062f\u06cc\u06af\u0631\u0627\u0646\u0634'), Term('content', u'\u0628\u0648\u062f'), Term('content', u'\u0645\u06cc\u0644\u06cc'), Term('content', u'\u062f\u0631'), Term('content', u'\u0627\u0646\u062a\u0638\u0627\u0631'), Term('content', u'\u0627\u06cc\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0622\u0634\u06cc\u0627\u0646'), Term('content', u'\u0645\u0631\u063a'), Term('content', u'\u0628\u0631'), Term('content', u'\u0633\u0631'), Term('content', u'\u0645\u0631\u06af'), Term('content', u'\u0648\u0635\u0641'), Term('content', u'\u062e\u0632\u0627\u0646')]) runtime=0.302055835724>
# processing file 42
# <Top 0 Results for And([Term('content', u'\u0627\u062e\u062a\u0644\u0627\u0641'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u062f\u0631'), Term('content', u'\u0686\u06af\u0648\u0646\u06af\u06cc'), Term('content', u'\u0634\u06a9\u0644'), Term('content', u'\u067e\u06cc\u0644')]) runtime=0.0194799900055>
# processing file 43
# <Top 0 Results for And([Term('content', u'\u062c\u0648\u0627\u0628'), Term('content', u'\u0641\u0631\u0639\u0648\u0646'), Term('content', u'\u0645\u0648\u0633\u06cc'), Term('content', u'\u0631\u0627'), Term('content', u'\u0648\u062d\u06cc'), Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0627\u0644\u0633\u0644\u0627\u0645'), Term('content', u'\u0645\u0647\u0644\u062a'), Term('content', u'\u062f\u0627\u062f\u0646'), Term('content', u'\u062a\u0627'), Term('content', u'\u0633\u0627\u062d\u0631\u0627\u0646'), Term('content', u'\u062c\u0645\u0639'), Term('content', u'\u06a9\u0646\u062f'), Term('content', u'\u0627\u0632'), Term('content', u'\u0645\u062f\u0627\u06cc\u0646'), Term('content', u'\u0641\u0631\u0633\u062a\u0627\u062f\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u062f\u0631'), Term('content', u'\u0637\u0644\u0628'), Term('content', u'\u062e\u0648\u0627\u0646\u062f\u0646'), Term('content', u'\u0622\u0646'), Term('content', u'\u062f\u0648'), Term('content', u'\u0633\u0627\u062d\u0631'), Term('content', u'\u067e\u062f\u0631'), Term('content', u'\u06af\u0648\u0631'), Term('content', u'\u067e\u0631\u0633\u06cc\u062f\u0646'), Term('content', u'\u0631\u0648\u0627\u0646'), Term('content', u'\u062d\u0642\u06cc\u0642\u062a'), Term('content', u'\u06af\u0641\u062a\u0646'), Term('content', u'\u0645\u0631\u062f\u0647'), Term('content', u'\u0628\u0627'), Term('content', u'\u0641\u0631\u0632\u0646\u062f\u0627\u0646'), Term('content', u'\u062e\u0648\u062f')]) runtime=0.297371149063>
# processing file 44
# <Top 0 Results for And([Term('content', u'\u0631\u0646\u062c\u0648\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0627\u0648\u0633\u062a\u0627\u062f'), Term('content', u'\u0628\u0647'), Term('content', u'\u0648\u0647\u0645'), Term('content', u'\u062f\u0631'), Term('content', u'\u062c\u0627\u0645\u0647'), Term('content', u'\u062e\u0648\u0627\u0628'), Term('content', u'\u0627\u0641\u062a\u0627\u062f\u0646'), Term('content', u'\u0627\u0633\u062a\u0627\u062f'), Term('content', u'\u0646\u0627\u0644\u06cc\u062f\u0646'), Term('content', u'\u0627\u0648'), Term('content', u'\u0627\u0632'), Term('content', u'\u0631\u0646\u062c\u0648\u0631\u06cc'), Term('content', u'\u062f\u0648\u0645'), Term('content', u'\u0628\u0627\u0631'), Term('content', u'\u0627\u0641\u06a9\u0646\u062f\u0646'), Term('content', u'\u06a9\u0648\u062f\u06a9\u0627\u0646'), Term('content', u'\u0631\u0627'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u0642\u0631\u0622\u0646'), Term('content', u'\u062e\u0648\u0627\u0646\u062f\u0646'), Term('content', u'\u0645\u0627'), Term('content', u'\u062f\u0631\u062f'), Term('content', u'\u0633\u0631'), Term('content', u'\u0627\u0641\u0632\u0627\u06cc\u062f'), Term('content', u'\u062e\u0644\u0627\u0635'), Term('content', u'\u06cc\u0627\u0641\u062a\u0646'), Term('content', u'\u0645\u06a9\u062a\u0628'), Term('content', u'\u0628\u062f\u06cc\u0646'), Term('content', u'\u0645\u06a9\u0631'), Term('content', u'\u0631\u0641\u062a\u0646'), Term('content', u'\u0645\u0627\u062f\u0631\u0627\u0646'), Term('content', u'\u0639\u06cc\u0627\u062f\u062a')]) runtime=0.223232984543>
# processing file 45
# <Top 0 Results for And([Term('content', u'\u0627\u0645\u062a\u062d\u0627\u0646'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u062e\u0648\u0627\u062c\u0647'), Term('content', u'\u0644\u0642\u0645\u0627\u0646'), Term('content', u'\u0632\u06cc\u0631\u06a9\u06cc'), Term('content', u'\u0631\u0627'), Term('content', u'\u0638\u0627\u0647\u0631'), Term('content', u'\u0634\u062f\u0646'), Term('content', u'\u0641\u0636\u0644'), Term('content', u'\u067e\u06cc\u0634'), Term('content', u'\u06a9\u0646\u0646\u062f\u06af\u0627\u0646')]) runtime=0.0299999713898>
# processing file 46
# <Top 0 Results for And([Term('content', u'\u0622\u0645\u062f\u0646'), Term('content', u'\u062f\u0648\u0633\u062a\u0627\u0646'), Term('content', u'\u0628\u0647'), Term('content', u'\u0628\u06cc\u0645\u0627\u0631\u0633\u062a\u0627\u0646'), Term('content', u'\u062c\u0647\u062a'), Term('content', u'\u067e\u0631\u0633\u0634'), Term('content', u'\u0630\u0627\u0627\u0644\u0646\u0648\u0646'), Term('content', u'\u0645\u0635\u0631\u06cc'), Term('content', u'\u0631\u062d\u0645\u0629'), Term('content', u'\u0627\u0644\u0644\u0647'), Term('content', u'\u0639\u0644\u06cc\u0647'), Term('content', u'\u0641\u0647\u0645'), Term('content', u'\u06a9\u0631\u062f\u0646'), Term('content', u'\u0645\u0631\u06cc\u062f\u0627\u0646'), Term('content', u'\u06a9\u06cc'), Term('content', u'\u062f\u06cc\u0648\u0627\u0646\u0647'), Term('content', u'\u0646\u0634\u062f'), Term('content', u'\u0642\u0627\u0635\u062f'), Term('content', u'\u06a9\u0631\u062f\u0647'), Term('content', u'\u0627\u0633\u062a'), Term('content', u'\u0631\u062c\u0648\u0639'), Term('content', u'\u062d\u06a9\u0627\u06cc\u062a')]) runtime=0.0510430335999>

# %%
experiment_precision
# Out:
# 0.010638297872340425

# %%
with open("RelevanceAssesment/RelevanceAssesment.txt") as f:
    lines = f.readlines()
test_file_names = ["test_persian.txt"]


sum_precision = 0
sum_recall = 0

for i in range(len(test_file_names)):
    print("processing file "+str(i))
    file = test_file_names[0]
    with codecs.open(file, 'r', "utf-8") as f:
        query = f.read().replace("\n", " ")
        if "N" in experiment:
                #print("normalize")
            normalizer = Normalizer()
            query = normalizer.normalize(query)
        #if "T"  in experiment:
            #print("tokenize")
            #query = word_tokenize(query)
            #query = " ".join(query)
        if "R" in experiment:
            stopwords = []
            with codecs.open("Stopwords/Stopwords.txt", 'r', "utf-8") as f:
                lines = f.readlines()
            for line in lines:
                stopwords.append(line.split('\n')[0])
            #print("Remove StopWords")
            query = query.split(" ")
            #stopwords = stopwords.split(" ")
            query_temp = []
            for word in query:
                if not word in stopwords:
                    query_temp.append(word)
                else:
                    print("word",word)
            print(len(query))
            print("chaged to")
            print(len(query_temp))
            
            query = query_temp
            query = " ".join(query)
            
    
    results = SE.Search(query)
    pre,rec = precision_recall(results, Relevantdocs[i].split("\n")[0].split(" "))
    sum_precision += pre
    sum_recall += rec
experiment_precision = sum_precision / len(test_file_names)
experiment_recall = sum_recall / len(test_file_names)
# Out:
# processing file 0
# ('word', u'\u0627\u06cc')
# ('word', u'\u0648')
# 6
# chaged to
# 4
# <Top 0 Results for Term('content', u'\u0639\u0634\u0642\u0633\u0644\u0627\u0645\u062f\u0631\u0648\u062f') runtime=0.000173091888428>

# %%
print(type(query_temp))
print(type(query))
print(len(query))
print(len(query_temp))
# Out:
# <type 'list'>
# <type 'list'>
# 10
# 5

# %%
result
